# %% [markdown]
# # Dielectric Function versus components
#
# Dielectric function versus Photon energy in different components

# %%
# Prework

from vmatplot.dielectric_function import plot_dielectric_function

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]

layout = "hor"
boundary = 24

# %%
# Graphene-BC₃ (Hollow)

components = [{"xx":"in-plane"},{"zz":"out-of-plane"},"xy"]

systems = [["(PBE)", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
           ["(HSE06 17 k-points)", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, True, "eV", boundary)

plt.savefig("Figures/5.58_dielectric_Graphene-BC3.pdf")

# %%
# Graphene-BC₃ (Hollow) alt

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]

systems = [["(PBE)", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
           ["(HSE06 17 k-points)", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, True, "eV", boundary)

plt.savefig("Figures_for_supplementary/proj1.9_alt.pdf")

# %%
# Graphene-Borophene (Top)

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]

systems = [["(PBE)", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
           ["(HSE06)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_dielectric_function("for Graphene-Borophene", systems, components, layout, True, "eV", boundary)

plt.savefig("Figures/5.57_dielectric_Graphene-Borophene.pdf")

# %%
# Graphene-B₄C₃ (Top)

components = [{"xx":"in-plane"},{"zz":"out-of-plane"},"xy"]

systems = [["(PBE)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
           ["(HSE06 17 k-points)", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-B₄C₃", systems, components, layout, True, "eV", boundary)

plt.savefig("Figures/5.59_dielectric_Graphene-B4C3.pdf")

# %%
# Graphene-B₄C₃ (Top) alt

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]

systems = [["(PBE)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
           ["(HSE06 17 k-points)", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-B₄C₃", systems, components, layout, True, "eV", boundary)

plt.savefig("Figures_for_supplementary/proj1.11_alt.pdf")
