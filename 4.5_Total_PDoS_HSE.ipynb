# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
# Prework

from vmatplot.PDoS import plot_totpdos

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["(HSE06)",    "4_PDoS/E_Graphene-BC3_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-BC₃ by HSE06", 6, 12, "Total", matters_dir)

# %%
# Graphene-Borophene (Top)

matters_dir = [["(GGA-PBE)",      "4_PDoS/F_Graphene-Borophene_PBE", "blue", 0.8, "dotted"],
               ["(HSE06)",    "4_PDoS/F_Graphene-Borophene_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-Borophene by HSE06", 6, 10, "Total", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["(GGA-PBE)",      "4_PDoS/G_Graphene-B4C3_PBE_K33", "blue", 0.8, "dotted"],
               ["(HSE06)",    "4_PDoS/G_Graphene-B4C3_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-B₄C₃ by HSE06", 6, 10, "Total", matters_dir)
