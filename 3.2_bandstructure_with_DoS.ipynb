# %% [markdown]
# # Bandstructure with DoS
#
# The band structure is demonstrated with Energy (in eV) versus K-point distance (in Å^2) with the Electronic density of state versus energy.

# %%
# Prework

from vmatplot.bandstructure_plotting import plot_bsDoS

# %%
# Graphene-BC₃ (Hollow)

bsDoS_list = [["bands", "PBE", "3_Bandstructure/E_Graphene-BC3_Hollow_PBE", "4_PDoS/E_Graphene-BC3_Hollow_PBE_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure/E_Graphene-BC3_Hollow_HSE", "4_PDoS/E_Graphene-BC3_Hollow_HSE", "orange"]]

plot_bsDoS("Graphene-BC₃ (Hollow)", 6, 10, bsDoS_list, "upper right")

# %%
# Graphene-Borophene (Top)

bsDoS_list = [["bands", "PBE", "3_Bandstructure/F_Graphene-Borophene_Top_PBE", "4_PDoS/F_Graphene-Borophene_Top_PBE_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure/F_Graphene-Borophene_Top_HSE", "4_PDoS/F_Graphene-Borophene_Top_HSE", "orange"]]

plot_bsDoS("Graphene-Borphene (Top)", 6, 10, bsDoS_list, "upper right")

# %%
# Graphene-B₄C₃ (Top)

bsDoS_list = [["bands", "PBE", "3_Bandstructure/G_Graphene-B4C3_Top_PBE", "4_PDoS/G_Graphene-B4C3_Top_PBE_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure/G_Graphene-B4C3_Top_HSE", "4_PDoS/G_Graphene-B4C3_Top_HSE", "orange"]]
 
plot_bsDoS("Graphene-B₄C₃ (Top)", 6, 10, bsDoS_list, "upper right")
