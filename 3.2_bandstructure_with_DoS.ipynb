# %% [markdown]
# # Bandstructure with DoS
#
# The band structure is demonstrated with Energy (in eV) versus K-point distance (in Å^2) with the Electronic density of state versus energy.

# %%
# Prework

from vmatplot.bandstructure_plotting import plot_bsDoS

# %%
# Graphene-BC₃ (Hollow)

bsDoS_list = [["bands", "PBE", "3_Bandstructure_PBE/E_Graphene-BC3_Hollow", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure_HSE06/E_Graphene-BC3_Hollow", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "orange"]]

plot_bsDoS("Graphene-BC₃ (Hollow)", 6, 10, bsDoS_list, "upper right")

# %%
# Graphene-Borophene (Top)

bsDoS_list = [["bands", "PBE", "3_Bandstructure_PBE/F_Graphene-Borophene_Top", "4_PDoS_PBE/F_Graphene-Borophene_Top_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure_HSE06/F_Graphene-Borophene_Top", "4_PDoS_HSE06/F_Graphene-Borophene_Top_K25", "orange"]]

plot_bsDoS("Graphene-Borphene (Top)", 6, 10, bsDoS_list, "upper right")

# %%
# Graphene-B₄C₃ (Top)

bsDoS_list = [["bands", "PBE", "3_Bandstructure_PBE/G_Graphene-B4C3_Top", "4_PDoS_PBE/G_Graphene-B4C3_Top_K33","orbital"],
              ["bands", "HSE06", "3_Bandstructure_HSE06/G_Graphene-B4C3_Top", "4_PDoS_HSE06/G_Graphene-B4C3_Top", "orange"]]
 
plot_bsDoS("Graphene-B₄C₃ (Top)", 6, 10, bsDoS_list, "upper right")
