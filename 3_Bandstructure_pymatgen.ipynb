# %% [markdown]
# # Bandstructure
#
# The band structure is demonstrated with Energy (in eV) versus K-point distance (in Å).

# %%
#### Single layer BC3 PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Single_A_BC3/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Single_A_BC3/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for BC₃ (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Single layer Borophene PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Single_B_Borophene/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Single_B_Borophene/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Borophene (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Single layer B4C3 PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Single_C_B4C3/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Single_C_B4C3/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for B₄C₃ (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Single layer B4C3 PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Single_D_Graphene_small/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Single_D_Graphene_small/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Biolayer Graphene-BC3 Hollow PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/E_Graphene-BC3_Hollow/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/E_Graphene-BC3_Hollow/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - BC₃ Hollow (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Biolayer Graphene-Borophene Top PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/F_Graphene-Borophene_Top/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/F_Graphene-Borophene_Top/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - Borophene Top (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Biolayer Graphene-B4C3 Top PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/G_Graphene-B4C3_Top/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/G_Graphene-B4C3_Top/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - B₄C₃ Top (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
