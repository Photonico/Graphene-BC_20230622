# %% [markdown]
# # Dielectric Function versus K-points
#
# Dielectric function versus Photon energy in different kpoints

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["11 kpoints", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K11_N128", "Yellow"],
                   ["17 kpoints", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N128", "Green"]]

plot_dielectric_function_XZ("Graphene-B₄C₃ (Top) with GGA-PBE", dielectric_list, 20)
