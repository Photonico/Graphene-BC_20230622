# %% [markdown]
# # Dielectric Function versus K-points and algorithms
#
# Dielectric function versus Photon energy in different kpoints and algorithms (GGA-PBE, HSE06)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block

dielectric_list = [["(11 kpoints)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K11_N128", "Yellow"],
                   ["(17 kpoints)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "Green"],
                #    ["(25 kpoints)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K25_N128", "Blue"],
                  ]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) with GGA-PBE", dielectric_list, 8, 32)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import plot_dielectric_function_XZ_block

dielectric_list = [["(PBE)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                   ["(HSE06)", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) comparison GGA-PBE and HSE06", dielectric_list, 6, 24)
