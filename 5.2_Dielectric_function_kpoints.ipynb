# %% [markdown]
# # Dielectric Function versus algorithms and K-points
#
# Dielectric function versus Photon energy in different kpoints and algorithms (GGA-PBE, HSE06)

# %%
# Prework

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block

# import matplotlib.pyplot as plt

# %%
# Graphene-Borophene with HSE06 versus accuracy configurations

dielectric_list = [
                #    ["(Fast Config)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Fast", "blue", 0.8, 4.0],
                   ["(Normal EDIFF = 1E-4)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-4", "violet", 0.9, 3.2],
                   ["(Normal EDIFF = 1E-5)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-5", "purple", 1.0, 2.4],
                #    ["(Normal EDIFF = 1E-6)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-6", "wine", 1.0, 1.6],
                   ["(Accurate EDIFF = 1E-6)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange", 1.0, 0.8]]

plot_dielectric_function_XZ_block("for Graphene-Borophene (Top) with HSE06", dielectric_list, 8, 32)

# plt.savefig("Figures/S5.2.pdf")

# %%
# Graphene-B₄C₃ (Top) with GGA-PBE versus accuracy configurations

dielectric_list = [["(25 kpoints Normal)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Normal", "blue", 0.6, 4.4],
                   ["(25 kpoints Exact)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Exact", "yellow"],
                  ]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) with GGA-PBE", dielectric_list, 8, 32)

# %%
# Graphene-B₄C₃ (Top) with GGA-PBE versus k-points

dielectric_list = [["(11 kpoints)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K11", "orange"],
                   ["(17 kpoints)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128", "blue"],
                   ["(25 kpoints Exact)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Exact", "violet"],
                   ["(65 kpoints Normal)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "Purple"],
                  ]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) with GGA-PBE", dielectric_list, 8, 32)
