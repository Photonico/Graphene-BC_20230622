# %% [markdown]
# # Dielectric Function versus algorithms and K-points
#
# Dielectric function versus Photon energy in different kpoints and algorithms (GGA-PBE, HSE06)

# %%
# Prework

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block

# import matplotlib.pyplot as plt

# %%
# Graphene-Borophene with HSE06 versus accuracy configurations

dielectric_list = [["(GGA-PBE)", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "grey"],
                   ["(HSE06 17 k-points)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K17", "green"],
                #    ["(Fast Config)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Fast", "blue", 0.8, 4.0],
                   ["(HSE06 Normal EDIFF = 1E-4)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-4", "violet", 0.9, 3.2],
                   ["(HSE06 Normal EDIFF = 1E-5)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-5", "purple", 1.0, 2.4],
                #    ["(HSE06 65 k-points Normal EDIFF = 1E-6)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Normal_EDIFF-6", "wine", 1.0, 1.6],
                   ["(HSE06 Accurate EDIFF = 1E-6)", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange", 1.0, 0.8]]

plot_dielectric_function_XZ_block("for Graphene-Borophene in 65 k-points", dielectric_list, 8, 32)

# plt.savefig("Figures/S5.2.pdf")

# %%
# Graphene-B₄C₃ (Top) with GGA-PBE versus accuracy configurations

dielectric_list = [["(25 k-points Normal)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Normal", "blue", 0.6, 4.4],
                   ["(25 k-points Exact)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Exact", "yellow"],
                  ]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) by GGA-PBE", dielectric_list, 8, 32)

# %%
# Graphene-B₄C₃ (Top) with GGA-PBE versus k-points

dielectric_list = [["(11 k-points)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K11", "orange"],
                   ["(17 k-points)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128", "blue"],
                   ["(25 k-points Exact)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K25_Exact", "violet"],
                   ["(65 k-points Normal)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "Purple"],
                  ]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) by GGA-PBE", dielectric_list, 8, 32)
