# %% [markdown]
# # Bandgap

# %%
# Single layer BC3

from Store.bandgap import read_bandgap

system_PBE = "Single layer BC3 (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Single_A_BC3/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Single layer BC3 (PBE)
# HOMO band: -3.791800;
# LUMO band: -3.157700;
# Band gap: 0.634100.

# %%
# Single layer Borophene

from Store.bandgap import read_bandgap

system_PBE = "Single layer Borophene (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Single_B_Borophene/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Single layer Borophene (PBE)
# HOMO band: -1.730000;
# LUMO band: -2.286800;
# Band gap: -0.556800.

# %%
# Single layer B4C3

from Store.bandgap import read_bandgap

system_PBE = "Single layer B4C3 (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Single_C_B4C3/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Single layer B4C3 (PBE)
# HOMO band: -2.855900;
# LUMO band: -1.209400;
# Band gap: 1.646500.

# %%
# Single layer Graphene

from Store.bandgap import read_bandgap

system_PBE = "Single layer Graphene (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Single_D_Graphene_small/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Single layer Graphene (PBE)
# HOMO band: -2.262400;
# LUMO band: -2.243900;
# Band gap: 0.018500.

# %%
# Bilayer Graphene - BC3 Hollow

from Store.bandgap import read_bandgap

system_PBE = "Bilayer Graphene - BC3 Hollow (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Twin_A3_Graphene-BC3_Hollow/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene - BC3 Top (PBE)
# HOMO band: -0.936600;
# LUMO band: -0.918100;
# Band gap: 0.018500.

# %%
# Bilayer Graphene - Borophene Top

from Store.bandgap import read_bandgap

system_PBE = "Bilayer Graphene - Borophene Top (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Twin_B1_Graphene-Borophene_Top/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene - Borophene Hollow 1 (PBE)
# HOMO band: -0.311000;
# LUMO band: -0.510900;
# Band gap: -0.199900.

# %%
# Bilayer Graphene - B4C3 Top

from Store.bandgap import read_bandgap

system_PBE = "Bilayer Graphene - B4C3 Top (PBE)"
gap_PBE = read_bandgap("3_Bandstructure_PBE/Twin_C1_Graphene-B4C3_Top/OUTCAR")

print(f"Matter: {system_PBE}")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene - B4C3 Top (PBE)
# HOMO band: -0.331300;
# LUMO band: -0.314600;
# Band gap: 0.016700.
