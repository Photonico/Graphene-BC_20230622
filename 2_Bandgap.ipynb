# %% [markdown]
# # Bandgap

# %%
from Store.bandgap import read_bandgap

system = "Single layer BC3 (PBE)"
gap = read_bandgap("3_Bandstructure_PBE\Single_A_BC3\OUTCAR")

print(f"HOMO band of {system}: {gap[1]:.6f};")
print(f"LUMO band of {system}: {gap[2]:.6f};")
print(f"Band gap of {system}: {gap[0]:.6f}.")
# Out:
# HOMO band of Single layer BC3 (PBE): -3.791800;
# LUMO band of Single layer BC3 (PBE): -3.157700;
# Band gap of Single layer BC3 (PBE): 0.634100.
