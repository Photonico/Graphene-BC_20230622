# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# BC₃

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["BC₃ (65 kpt)", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
                   ["Borophene (65 kpt)", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
                   ["B₄C₃ (65 kpt)", "5_Dielectric_function/C_B4C3_PBE_K65","violet"],
                   ["Graphene (129 kpt)", "5_Dielectric_function/D_Graphene_PBE_K129", "grey"]]

plot_dielectric_function_XZ("Monolayers", dielectric_list, 8, 24)

# %%
# BC₃

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["BC₃ (65 kpt)", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
                   ["Borophene (65 kpt)", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
                   ["B₄C₃ (65 kpt)", "5_Dielectric_function/C_B4C3_PBE_K65","violet"],
                   ["Graphene (129 kpt)", "5_Dielectric_function/D_Graphene_PBE_K129", "grey"]]

plot_dielectric_function_XZ("Monolayers", dielectric_list, 24, 24)
