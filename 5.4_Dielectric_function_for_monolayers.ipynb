# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# Monolayers

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_row

dielectric_list = [["BC₃ (65 k-points)", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
                   ["Borophene (65 k-points)", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
                   ["B₄C₃ (65 k-points)", "5_Dielectric_function/C_B4C3_PBE_K65","violet"],
                   ["Graphene (129 k-points)", "5_Dielectric_function/D_Graphene_PBE_K129", "grey"]]

plot_dielectric_function_XZ_row("Monolayers by GGA-PBE ", dielectric_list, 8, 24)

# %%
from vmatplot.dielectric_function_plotting import  *

def plot_dielectric_function_XZ_zoom(title, dielectric_list=None,
                                     inplane_energy_boundary_1=(None, None), outplane_energy_boundary_1=(None, None),
                                     inplane_energy_boundary_2=(None, None), outplane_energy_boundary_2=(None, None)):
    return 0
