# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# Prework

from vmatplot.dielectric_function_plotting import plot_dielectric_function_XXZZ_block

import matplotlib.pyplot as plt

# %%
# Monolayers

dielectric_list = [["BC₃ (65 k-points)", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
                   ["Borophene (65 k-points)", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
                   ["B₄C₃ (65 k-points)", "5_Dielectric_function/C_B4C3_PBE_K65","violet"],
                   ["Graphene (129 k-points)", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]

plot_dielectric_function_XXZZ_block("for Monolayers by GGA-PBE", dielectric_list, "ev", 32)

plt.savefig("Figures/S5.4.1_monolayer_dielectric.pdf")

plot_dielectric_function_XXZZ_block("for Monolayers by GGA-PBE (zoomed)", dielectric_list, "ev", 12)

plt.savefig("Figures/S5.4.2_monolayer_zoomed_dielectric.pdf")
