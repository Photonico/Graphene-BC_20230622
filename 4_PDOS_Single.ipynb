# %% [markdown]
# # PDOS for single layer matters
#
# Projected electronic density versus energy

# %%
#### 1.1 Single layer: BC3

from Store.PDOS_extracting import pdos_total_extracting, pdos_element_extracting
from Store.PDOS_plotting import pdos_element_plotting, pdos_total_plotting

pdos_BC3 = pdos_total_extracting("Single_BC3/4_PDOS/vasprun.xml")
pdos_total_plotting(pdos_BC3, "BC₃", 8)

pdos_BC3_B = pdos_element_extracting("Single_BC3/4_PDOS/vasprun.xml","B")
pdos_element_plotting(pdos_BC3_B, "Boron in BC₃", 4)

pdos_BC3_C = pdos_element_extracting("Single_BC3/4_PDOS/vasprun.xml","C")
pdos_element_plotting(pdos_BC3_C, "Carbon in BC₃", 4)

# %%
#### 1.1 Single layer: BC3 - Comparsing

from Store.PDOS_extracting import pdos_element_extracting
from Store.PDOS_comparing import pdos_duo_element

pdos_BC3_B = pdos_element_extracting("Single_BC3/4_PDOS/vasprun.xml","B")
pdos_BC3_C = pdos_element_extracting("Single_BC3/4_PDOS/vasprun.xml","C")
pdos_duo_element("BC₃", "Boron", pdos_BC3_B, "Carbon", pdos_BC3_C, 3)

# %%
#### 1.2 Single layer: Graphene

from Store.PDOS_extracting import pdos_total_extracting
from Store.PDOS_plotting import pdos_total_plotting

pdos_Graphene = pdos_total_extracting("Single_Graphene/4_PDOS/vasprun.xml")
pdos_total_plotting(pdos_Graphene, "Graphene", 8)
