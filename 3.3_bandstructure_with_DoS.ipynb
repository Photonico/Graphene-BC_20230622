# %% [markdown]
# # Bandstructure with DoS
#
# The band structure is demonstrated with Energy (in eV) versus K-point distance (in Å^2) with the Electronic density of state versus energy.

# %%
from vmatplot.bandstructure_plotting import create_matters_bsDos, plot_bsDoS

bsDoS_list = [["bands", "PBE", "3_Bandstructure_PBE/A_BC3", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K65","orbital"],
              ["bands", "HSE06", "3_Bandstructure_HSE06/A_BC3", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "orange"]]
 
plot_bsDoS("Graphene-BC₃", 6, 10, bsDoS_list, "upper right")

# create_matters_bsDos
