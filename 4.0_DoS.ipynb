# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# Prework

from vmatplot.DoS import plot_dos

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["PBE", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K65", "blue"],
               ["HSE06", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "orange"]]

plot_dos("Graphene-BC₃ (Hollow)", 6, 10, "total", matters_dir)

# %%
# Graphene-Borophene (Top)

matters_dir = [["PBE (25 Kpoints)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K25", "blue", 0.3],
               ["PBE (33 Kpoints)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K33", "blue", 0.6],
               ["PBE (65 Kpoints)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K65", "blue", 1.0],
               ["HSE06 (25 Kpoints)", "4_PDoS_HSE06/F_Graphene-Borophene_Top_K25", "orange"]]

plot_dos("Graphene-Borophene (Top)", 6, 9, "total", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["PBE", "4_PDoS_PBE/G_Graphene-B4C3_Top_K65", "orbital"],
               ["HSE06", "4_PDoS_HSE06/G_Graphene-B4C3_Top", "orange"]]

plot_dos("Graphene-B₄C₃ (Top)", 6, 10, "total", matters_dir)

# %%
matters_dir = [["HSE06 (25 Kpoints)", "4_PDoS_HSE06/F_Graphene-Borophene_Top_K25", "orange"]]

plot_dos("Graphene-Borophene (Top)", 6, 9, "total", matters_dir)
