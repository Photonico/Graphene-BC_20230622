# %% [markdown]
# # Lattice plotting merger
#
# Total energy versus lattice constant
#
# ## Article information
#
# Title: Electronic and optical properties of Graphene-Boron-based bilayers: BC3, Borophene, B4C3

# %%
# Prework

from vmatplot.lattice_plotting import plot_free_energy_lattice

lattice_list_1 = [[None, "0_Lattice/A_BC3/free_energy_lattice.dat", "0_Lattice_Reference/A_BC3", "blue", 11]]
lattice_list_2 = [[None, "0_Lattice/B_Borophene/free_energy_lattice.dat", "0_Lattice_Reference/B_Borophene_2", "green", 11]]

plot_free_energy_lattice(2, "test", lattice_list_1, lattice_list_2, "m1", "m2")
