# %% [markdown]
# # Lattice plotting merger
#
# Total energy versus lattice constant
#
# ## Article information
#
# Title: Electronic and optical properties of Graphene-Boron-based bilayers: BC3, Borophene, B4C3

# %%
# Prework

from vmatplot.lattice_plotting import plot_free_energy_lattice
import matplotlib.pyplot as plt

# %%
# Monolayers

lattice_list_1 = [["", "0_Lattice/A_BC3/free_energy_lattice.dat", "0_Lattice_Reference/A_BC3", "blue", 11],]
lattice_list_2 = [["", "0_Lattice/B_Borophene/free_energy_lattice.dat", "0_Lattice_Reference/B_Borophene_2", "green", 11]]
lattice_list_3 = [["", "0_Lattice/C_B4C3/free_energy_lattice.dat", "0_Lattice_Reference/C_B4C3", "violet", 11]]
lattice_list_4 = [["", "0_Lattice/D_Graphene/free_energy_lattice.dat", "0_Lattice_Reference/D_Graphene", "grey", 11]]

plot_free_energy_lattice(4, "", lattice_list_1, lattice_list_2, lattice_list_3, lattice_list_4, "BC₃", "Borophene", "B₄C₃", "Graphene")

plt.savefig("Figures/1.21_lattice_monolayers.pdf")

# %%
# Bilayers

lattice_list_1 = [["Top", "0_Lattice/E_Graphene-BC3_Top/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Top", "blue", 11],
                  ["Bridge", "0_Lattice/E_Graphene-BC3_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Bridge", "green", 11],
                  ["Hollow", "0_Lattice/E_Graphene-BC3_Hollow/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Hollow", "violet", 11]]
lattice_list_2 = [["Top", "0_Lattice/F_Graphene-Borophene_Top/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Top", "blue", 11],
                  ["Bridge", "0_Lattice/F_Graphene-Borophene_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Bridge", "green", 11],
                  ["Hollow 1", "0_Lattice/F_Graphene-Borophene_Hollow1/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Hollow1", "violet", 11],
                  ["Hollow 2", "0_Lattice/F_Graphene-Borophene_Hollow2/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Hollow2", "wine", 11]]
lattice_list_3 = [["Top", "0_Lattice/G_Graphene-B4C3_Top/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Top", "blue", 11],
                  ["Bridge", "0_Lattice/G_Graphene-B4C3_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Bridge", "green", 11],
                  ["Hollow 1", "0_Lattice/G_Graphene-B4C3_Hollow1/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Hollow1", "violet", 11],
                  ["Hollow 2", "0_Lattice/G_Graphene-B4C3_Hollow2/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Hollow2", "wine", 11]]

plot_free_energy_lattice(3, "", lattice_list_1, lattice_list_2, lattice_list_3, "Graphene-BC₃", "Graphene-Borophene", "Graphene-B₄C₃")

plt.savefig("Figures/1.22_lattice_bilayers.pdf")
