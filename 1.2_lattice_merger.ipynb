# %% [markdown]
# # Lattice plotting merger
#
# Total energy versus lattice constant
#
# ## Article information
#
# Title: Electronic and optical properties of Graphene-Boron-based bilayers: BC3, Borophene, B4C3

# %%
# Prework

from vmatplot.lattice_plotting import plot_free_energy_lattice, plot_free_energy_lattice_double

lattice_list = [[None,"0_Lattice/A_BC3/free_energy_lattice.dat", "0_Lattice_Reference/A_BC3", "blue", 11],
                [None,"0_Lattice/B_Borophene/free_energy_lattice.dat", "0_Lattice_Reference/B_Borophene_2", "green", 11]]

plot_free_energy_lattice(2, "test", lattice_list, "m1", "m2")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       3 from vmatplot.lattice_plotting import plot_free_energy_lattice, plot_free_energy_lattice_double
#       5 lattice_list = [[None,"0_Lattice/A_BC3/free_energy_lattice.dat", "0_Lattice_Reference/A_BC3", "blue", 11],
#       6                 [None,"0_Lattice/B_Borophene/free_energy_lattice.dat", "0_Lattice_Reference/B_Borophene_2", "green", 11]]
# ----> 8 plot_free_energy_lattice(2, "test", lattice_list, "m1", "m2")
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\lattice_plotting.py:184, in plot_free_energy_lattice(subfigures_amount, *args)
#     182     return plot_free_energy_lattice_single(*args)
#     183 elif subfigures_amount == 2:
# --> 184     return plot_free_energy_lattice_double(*args)
#     185 # elif subfigures_amount == 3:
#     186 #     return plot_free_energy_lattice_triple(*args)
#     187 # elif subfigures_amount == 4:
#     188 #     return plot_free_energy_lattice_quadruple(*args)
#     189 # help information
#     190 else:
#     191     print(help_info)
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\lattice_plotting.py:128, in plot_free_energy_lattice_double(suptitle, lattice_list, subtitle_1, subtitle_2, lattice_range_1, lattice_range_2)
#     126 current_label = lattice_info[0]
#     127 # fitted curve
# --> 128 selection_fitted = extract_part(lattice_info[2][0],lattice_info[2][1],lattice_ranges[supplot_index][0],lattice_ranges[supplot_index][1])
#     129 fitted_lattice, fitted_free_energy = fit_eos(selection_fitted[0], selection_fitted[1])
#     130 colors = color_sampling(lattice_info[4])
#
# TypeError: 'NoneType' object is not subscriptable
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
