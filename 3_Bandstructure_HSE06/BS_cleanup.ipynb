# %%
# Bandstrcutre cleanup

import os

# List of files and directories to delete
files_to_delete = [
    "CHG", "CHGCAR", "CONTCAR", "DOSCAR", "EIGENVAL", "IBZKPT",
    "OUTCAR", "OSZICAR", "output.txt", "PCDAT", "PROCAR", "REPORT",
    "vasp_usyd.sh", "vasp.log", "vasp.out", "vaspout.h5",
    "XDATCAR"
]

# Start from the current directory and search files and directories recursively
for dirpath, dirnames, filenames in os.walk(os.getcwd()):
    if "lattice_source" in dirnames:
        dirnames.remove("lattice_source")
    for filename in filenames:
        if filename in files_to_delete:
            file_path = os.path.join(dirpath, filename)
            try:
                os.remove(file_path)
                print(f"Deleted {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

print("Cleanup complete.")
# Out:
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Single_B_Borophene\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Single_C_B4C3\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Single_D_Graphene_small\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_A1_Graphene-BC3_Top\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_A2_Graphene-BC3_Bridge\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_A3_Graphene-BC3_Hollow\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_B1_Graphene-Borophene_Top\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_B2_Graphene-Borophene_Bridge\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_B3_Graphene-Borophene_Hollow_1\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_B4_Graphene-Borophene_Hollow_2\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_C1_Graphene-B4C3_Top\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_C2_Graphene-B4C3_Bridge\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_C3_Graphene-B4C3_Hollow_1\vasprun.xml
# Deleted c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_Bandstructure_HSE06\Twin_C4_Graphene-B4C3_Hollow_2\vasprun.xml
# Cleanup complete.
