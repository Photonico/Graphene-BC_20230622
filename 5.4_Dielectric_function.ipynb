# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# Graphene-BC₃ (Hollow)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]]

plot_dielectric_function_XZ("Graphene-Borophene (Top)", dielectric_list, 6, 24)

# %%
# Graphene-Borophene (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"]]

plot_dielectric_function_XZ("for Graphene-Borophene (Top)", dielectric_list, 6, 24)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"]]

plot_dielectric_function_XZ("for Graphene-B₄C₃ (Top)", dielectric_list, 6, 24)

# %%
# Dielectric function

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block
import matplotlib.pyplot as plt

dielectric_list = [["Graphene-B₄C₃ (Top)", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                   ["Graphene-Borophene (Top)", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                   ["Graphene-BC₃ (Hollow)", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                   ]

plot_dielectric_function_XZ_block("", dielectric_list, 6, 40)
plt.savefig("Figures/5_dielectric_function.pdf")
