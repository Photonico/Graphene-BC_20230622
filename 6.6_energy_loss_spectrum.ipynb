# %% [markdown]
# # Energy loss spectrum
#
# The energy loss spectrum is a measure of the energy loss experienced by electrons due to photon interactions within a system.
#
# We define the energy loss spectrum of a system as:
#
# $$ L(\omega) = \frac{\varepsilon_I(\omega)}{\varepsilon^2_R(\omega)+\varepsilon_I^2(\omega)} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.energy_loss_spectrum import plot_energy_loss_XZ

import matplotlib.pyplot as plt

# %%
# Energy loss spectrum GGA-PBE and HSE06

matters_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                ["HSE06", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_energy_loss_XZ("for Graphene-B₄C₃ comparison GGA-PBE and HSE06", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Energy loss spectrum in eV

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_energy_loss_XZ("", matters_list, "eV", 40, 40, (0.88, 10.16), (0.88, 10.16))

plt.savefig("Figures/6.6_energy_loss_spectrum.pdf")

# %%
# Energy loss spectrum in nm

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_energy_loss_XZ("", matters_list, "nm", 1000, 200, 400, 100)
