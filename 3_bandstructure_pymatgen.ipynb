# %%
# Bandstrcutre reference

# %%
# Plot Graphene bandstructure: basic information

from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.plotter import BSPlotter
import matplotlib.pyplot as plt

vasprun = Vasprun("3_Bandstructure_PBE/D_Graphene/vasprun.xml")

band_structure = vasprun.get_band_structure(kpoints_filename=None, efermi=None, line_mode=True)

bands = band_structure.bands

e_fermi = band_structure.efermi

kpoints = band_structure.kpoints
# Out:
# /home/lu/.local/lib/python3.11/site-packages/pymatgen/io/vasp/inputs.py:1837: UserWarning: POTCAR with symbol C and functional
# PBE has a SHA256 hash defined,
# but the computed hash differs.
# YOUR POTCAR FILE HAS BEEN CORRUPTED AND SHOULD NOT BE USED!
#   warnings.warn(

# %%
# Plot Graphene bandstructure: basic information

import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasprun_PBE = Vasprun("3_Bandstructure_PBE/D_Graphene/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/D_Graphene/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasprun_PBE = Vasprun("3_Bandstructure_HSE06/A_BC3/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_HSE06/A_BC3/KPOINTS_OPT"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for BC3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/B_Borophene/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/B_Borophene/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Borophene",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/lu/Repos/Graphene-BC 2023/3_bandstructure_pymatgen.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a> plot_data = plotter.bs_plot_data()
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a> plotter.get_plot(ylim=(-6, 6))
# ---> <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a> plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a> plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=27'>28</a> plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/C_B4C3/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/C_B4C3/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for B4C3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/lu/Repos/Graphene-BC 2023/3_bandstructure_pymatgen.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> vasprun_PBE = Vasprun("3_Bandstructure_PBE/C_B4C3/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
#       <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> kpoints_file = "3_Bandstructure_PBE/C_B4C3/KPOINTS"
#       <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> kpoints = Kpoints.from_file(kpoints_file)
#
# NameError: name 'Vasprun' is not defined

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/G_Graphene-B4C3_Top/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/G_Graphene-B4C3_Top/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene-B4C3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/lu/Repos/Graphene-BC 2023/3_bandstructure_pymatgen.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> vasprun_PBE = Vasprun("3_Bandstructure_PBE/G_Graphene-B4C3_Top/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
#       <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> kpoints_file = "3_Bandstructure_PBE/G_Graphene-B4C3_Top/KPOINTS"
#       <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandstructure_pymatgen.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> kpoints = Kpoints.from_file(kpoints_file)
#
# NameError: name 'Vasprun' is not defined

# %%
# py4vasp testing space

from py4vasp import *

calc = Calculation.from_path("3_Bandstructure_HSE06\A_BC3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_bandstructure_pymatgen.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_pymatgen.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # py4vasp testing space
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_pymatgen.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> from py4vasp import *
#       <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_pymatgen.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> calc = Calculation.from_path("3_Bandstructure_HSE06\A_BC3")
#
# ModuleNotFoundError: No module named 'py4vasp'
