# %% [markdown]
# ## Results
#
# ### Graphene - BC₃
#
# * Top (shift 0)
#   * Most stable Lattice constant: 5.044 (Å)
#   * Most stable distance:
#   * Minimal free energy: -142.27484692 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge (shift 1/12)
#   * Most stable Lattice constant: 5.044(Å)
#   * Most stable distance:
#   * Minimal free energy: -142.29046554 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow (shift 1/6)
#   * Most stable Lattice constant: 5.044(Å)
#   * Most stable distance:
#   * Minimal free energy: -142.2925088 (eV)
#   * B-C bond:
#   * C-C bond:
#
# ### Graphene - Borophene
#
# * Top  (shift 0)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.92712719 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge  (shift 1/12)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.92124473 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow_1  (shift 1/9)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.91420009(eV).
#   * B-C bond:
#   * C-C bond:
#
# * Hollow_2  (shift 1/6)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.90933841(eV).
#   * B-C bond:
#   * C-C bond:
#
# ### Graphene - B₄C₃
#
# * Top (shift -1/6)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.1380817 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge (shift -1/12)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.13482934 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow_1 (shift -1/18)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.13283516 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow_2 (shift 0)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.12438981 (eV)
#   * B-C bond:
#   * C-C bond:

# %%
#### Graphene - BC3

## Read data
import numpy as np
from Store.lattice_extracting import read_lattice_distance, read_lattice_distance_select
from Store.filter_segment import filter_segment
from Store.birch_murnaghan import fit_eos

Matter = "Graphene - BC₃"

## Lattice range
lattice_start = 5.020
lattice_range = 0.040
lattice_end = lattice_start + lattice_range

## Source data
# Top
lattice_Top_source, distance_Top_source, energy_Top_source = read_lattice_distance("0_Lattice_Twin/A1_Graphene-BC3_Top/lattice.dat")
# Bridge
lattice_Bridge_source, distance_Bridge_source, energy_Bridge_source = read_lattice_distance("0_Lattice_Twin/A2_Graphene-BC3_Bridge/lattice.dat")
# Hollow
lattice_Hollow_source, distance_Hollow_source, energy_Hollow_source = read_lattice_distance("0_Lattice_Twin/A3_Graphene-BC3_Hollow/lattice.dat")

## Discretized source data
divisor = 5
# Top
lattice_Top_dis, distance_Top_dis, energy_Top_dis = read_lattice_distance_select("0_Lattice_Twin/A1_Graphene-BC3_Top/lattice.dat",1000,divisor)
# Bridge
lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis = read_lattice_distance_select("0_Lattice_Twin/A2_Graphene-BC3_Bridge/lattice.dat",1000,divisor)
# Hollow
lattice_Hollow_dis, distance_Hollow_dis, energy_Hollow_dis = read_lattice_distance_select("0_Lattice_Twin/A3_Graphene-BC3_Hollow/lattice.dat",1000,divisor)

## Segment select
lattice_Top, distance_Top, energy_Top = filter_segment(lattice_Top_dis, distance_Top_dis, energy_Top_dis, lattice_start, lattice_end)
lattice_Bridge, distance_Bridge, energy_Bridge = filter_segment(lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis, lattice_start, lattice_end)
lattice_Hollow, distance_Hollow, energy_Hollow = filter_segment(lattice_Hollow_dis, distance_Hollow_dis, energy_Hollow_dis, lattice_start, lattice_end)

# Lattice range
lattice_range = max(max(lattice_Top), max(lattice_Bridge), max(lattice_Hollow))-min(min(lattice_Top), min(lattice_Bridge), min(lattice_Hollow))
# Energy range
energy_max = max(max(energy_Top), max(energy_Bridge), max(energy_Hollow))
energy_min = min(min(energy_Top), min(energy_Bridge), min(energy_Hollow))
energy_range = energy_max - energy_min

## Fit curve
# Top
energy_Top_fitted = fit_eos(lattice_Top_source, energy_Top_source)
# Bridge
energy_Bridge_fitted = fit_eos(lattice_Bridge_source, energy_Bridge_source)
# Hollow
energy_Hollow_fitted = fit_eos(lattice_Hollow_source, energy_Hollow_source)

## Extrema point of source data
# Top
energy_Top_min = np.min(energy_Top_source)
lattice_Top_min = lattice_Top_source[np.argmin(energy_Top_source)]
# Bridge
energy_Bridge_min = np.min(energy_Bridge_source)
lattice_Bridge_min = lattice_Bridge_source[np.argmin(energy_Bridge_source)]
# Hollow
energy_Hollow_min = np.min(energy_Hollow_source)
lattice_Hollow_min = lattice_Hollow_source[np.argmin(energy_Hollow_source)]

## Extrema point of fitted data
# Top
energy_Top_index = np.argmin(energy_Top_fitted)
fitted_lattice_Top_min = lattice_Top_source[energy_Top_index]
fitted_energy_Top_min = energy_Top_fitted[energy_Top_index]
# Bridge
energy_Bridge_index = np.argmin(energy_Bridge_fitted)
fitted_lattice_Bridge_min = lattice_Bridge_source[energy_Bridge_index]
fitted_energy_Bridge_min = energy_Bridge_fitted[energy_Bridge_index]
# Hollow
energy_Hollow_index = np.argmin(energy_Hollow_fitted)
fitted_lattice_Hollow_min = lattice_Hollow_source[energy_Hollow_index]
fitted_energy_Hollow_min = energy_Hollow_fitted[energy_Hollow_index]

print(f"Fitted extrema lattice of Top: {float(fitted_lattice_Top_min)}(Å), the corresponding energy is {float(fitted_energy_Top_min)}(eV).")
print(f"Fitted extrema lattice of Bridge: {float(fitted_lattice_Bridge_min)}(Å), the corresponding energy is {float(fitted_energy_Bridge_min)}(eV).")
print(f"Fitted extrema lattice of Hollow: {float(fitted_lattice_Hollow_min)}(Å), the corresponding energy is {float(fitted_energy_Hollow_min)}(eV).")

lattice_Top_array = np.array(lattice_Top_source)
start_Top = np.searchsorted(lattice_Top_array, lattice_start)
end_Top = np.searchsorted(lattice_Top_array, lattice_end)+1

lattice_Bridge_array = np.array(lattice_Bridge_source)
start_Bridge = np.searchsorted(lattice_Bridge_array, lattice_start)
end_Bridge = np.searchsorted(lattice_Bridge_array, lattice_end)+1

lattice_Hollow_array = np.array(lattice_Hollow_source)
start_Hollow = np.searchsorted(lattice_Hollow_array, lattice_start)
end_Hollow = np.searchsorted(lattice_Hollow_array, lattice_end)+1

## Selected point
selected_path = "1_Lattice_Selected/lattice.dat"
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[1:2]
    for line in lines:
        split_line = line.strip().split()
        lattice_selected_Top = float(split_line[2])
        energy_selected_Top = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[2:3]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Bridge = float(split_line[2])
        energy_selected_Bridge = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[3:4]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Hollow = float(split_line[2])
        energy_selected_Hollow = float(split_line[4])

print(f"Selected lattice of Top: {lattice_selected_Top}(Å), the corresponding energy is {energy_selected_Top}(eV).")
print(f"Selected lattice of Bridge: {lattice_selected_Bridge}(Å), the corresponding energy is {energy_selected_Bridge}(eV).")
print(f"Selected lattice of Hollow: {lattice_selected_Hollow}(Å), the corresponding energy is {energy_selected_Hollow}(eV).")

## Plot
import matplotlib.pyplot as plt

plt.figure(dpi=256, figsize=(10,6))
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)
plt.tick_params(direction="in", which="both", top=True, right=True, bottom=True, left=True)
plt.title(f"Free energy versus lattice for {Matter}"); plt.xlabel(r"Lattice constant (Å)"); plt.ylabel(r"Energy (eV)")

# Source data: Top
plt.scatter(lattice_Top, energy_Top, s=48, facecolors="#FFFFFF", edgecolors="#1473D2", label="Source data: Top", zorder=2)
plt.scatter(lattice_Top_min, energy_Top_min, s=96, facecolors="#FFFFFF", edgecolors="#1473D2", zorder=2)
# Source data: Bridge
plt.scatter(lattice_Bridge, energy_Bridge, s=48, facecolors="#FFFFFF", edgecolors="#288C3C", label="Source data: Bridge", zorder=2)
plt.scatter(lattice_Bridge_min, energy_Bridge_min, s=192, facecolors="#FFFFFF", edgecolors="#288C3C", zorder=2)
# Source data: Hollow
plt.scatter(lattice_Hollow, energy_Hollow, s=48, facecolors="#FFFFFF", edgecolors="#A59BF0", label="Source data: Hollow", zorder=2)
plt.scatter(lattice_Hollow_min, energy_Hollow_min, s=96, facecolors="#FFFFFF", edgecolors="#A59BF0", zorder=2)

# Fitted data: top
plt.plot(lattice_Top_source[start_Top: end_Top], energy_Top_fitted[start_Top: end_Top], color="#1473D2", label="Fitted data: Top", zorder=1)
# Fitted data: Bridge
plt.plot(lattice_Bridge_source[start_Bridge: end_Bridge], energy_Bridge_fitted[start_Bridge: end_Bridge], color="#288C3C", label="Fitted data: Bridge", zorder=1)
# # Fitted data: Hollow
plt.plot(lattice_Hollow_source[start_Hollow: end_Hollow], energy_Hollow_fitted[start_Hollow: end_Hollow], color="#A59BF0", label="Fitted data: Hollow", zorder=1)

# Selected point
plt.scatter(lattice_selected_Top, energy_selected_Top, s=48, color="#1473D2", zorder=4)
plt.scatter(lattice_selected_Bridge, energy_selected_Bridge, s=48, color="#288C3C", zorder=4)
plt.scatter(lattice_selected_Hollow, energy_selected_Hollow, s=48, color="#A59BF0", zorder=4)

plt.xlim(lattice_start-lattice_range*0.05, lattice_end+lattice_range*0.05)
plt.ylim(energy_min-energy_range*0.05,energy_max+energy_range*0.05)
plt.legend(loc="upper right")
# Out:
# Fitted extrema lattice of Top: 5.044(Å), the corresponding energy is -142.27485058086705(eV).
# Fitted extrema lattice of Bridge: 5.044(Å), the corresponding energy is -142.2897264562555(eV).
# Fitted extrema lattice of Hollow: 5.044(Å), the corresponding energy is -142.29250966564663(eV).
# Selected lattice of Top: 5.044(Å), the corresponding energy is -142.27484692(eV).
# Selected lattice of Bridge: 5.044(Å), the corresponding energy is -142.29046554(eV).
# Selected lattice of Hollow: 5.044(Å), the corresponding energy is -142.2925088(eV).

# %%
#### Graphene - Borophene

## Read data
import numpy as np
from Store.lattice_extracting import read_lattice_distance, read_lattice_distance_select
from Store.filter_segment import filter_segment
from Store.birch_murnaghan import fit_eos

Matter = "Graphene - Borophene"

## Lattice range
lattice_start = 4.955
lattice_range = 0.040
lattice_end = lattice_start + lattice_range

## Source data
# Top
lattice_Top_source, distance_Top_source, energy_Top_source = read_lattice_distance("0_Lattice_Twin/B1_Graphene-Borophene_Top/lattice.dat")
# Bridge
lattice_Bridge_source, distance_Bridge_source, energy_Bridge_source = read_lattice_distance("0_Lattice_Twin/B2_Graphene-Borophene_Bridge/lattice.dat")
# Hollow 1
lattice_Hollow_1_source, distance_Hollow_1_source, energy_Hollow_1_source = read_lattice_distance("0_Lattice_Twin/B3_Graphene-Borophene_Hollow_1/lattice.dat")
# Hollow 2
lattice_Hollow_2_source, distance_Hollow_2_source, energy_Hollow_2_source = read_lattice_distance("0_Lattice_Twin/B4_Graphene-Borophene_Hollow_2/lattice.dat")

## Discretized source data
divisor = 5
# Top
lattice_Top_dis, distance_Top_dis, energy_Top_dis = read_lattice_distance_select("0_Lattice_Twin/B1_Graphene-Borophene_Top/lattice.dat",1000,divisor)
# Bridge
lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis = read_lattice_distance_select("0_Lattice_Twin/B2_Graphene-Borophene_Bridge/lattice.dat",1000,divisor)
# Hollow 1
lattice_Hollow_1_dis, distance_Hollow_1_dis, energy_Hollow_1_dis = read_lattice_distance_select("0_Lattice_Twin/B3_Graphene-Borophene_Hollow_1/lattice.dat",1000,divisor)
# Hollow 2
lattice_Hollow_2_dis, distance_Hollow_2_dis, energy_Hollow_2_dis = read_lattice_distance_select("0_Lattice_Twin/B4_Graphene-Borophene_Hollow_2/lattice.dat",1000,divisor)

## Segment select
lattice_Top, distance_Top, energy_Top = filter_segment(lattice_Top_dis, distance_Top_dis, energy_Top_dis, lattice_start, lattice_end)
lattice_Bridge, distance_Bridge, energy_Bridge = filter_segment(lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis, lattice_start, lattice_end)
lattice_Hollow_1, distance_Hollow_1, energy_Hollow_1 = filter_segment(lattice_Hollow_1_dis, distance_Hollow_1_dis, energy_Hollow_1_dis, lattice_start, lattice_end)
lattice_Hollow_2, distance_Hollow_2, energy_Hollow_2 = filter_segment(lattice_Hollow_2_dis, distance_Hollow_2_dis, energy_Hollow_2_dis, lattice_start, lattice_end)

# Lattice range
lattice_range = max(max(lattice_Top), max(lattice_Bridge), max(lattice_Hollow_1), max(lattice_Hollow_2))-min(min(lattice_Top), min(lattice_Bridge), min(lattice_Hollow_1), min(lattice_Hollow_2))
# Energy range
energy_max = max(max(energy_Top), max(energy_Bridge), max(energy_Hollow_1), max(energy_Hollow_2))
energy_min = min(min(energy_Top), min(energy_Bridge), min(energy_Hollow_1), min(energy_Hollow_2))
energy_range = energy_max - energy_min

## Fit curve
# Top
energy_Top_fitted = fit_eos(lattice_Top_source, energy_Top_source)
# Bridge
energy_Bridge_fitted = fit_eos(lattice_Bridge_source, energy_Bridge_source)
# Hollow_1
energy_Hollow_1_fitted = fit_eos(lattice_Hollow_1_source, energy_Hollow_1_source)
# Hollow_2
energy_Hollow_2_fitted = fit_eos(lattice_Hollow_2_source, energy_Hollow_2_source)

## Extrema point of source data
# Top
energy_Top_min = np.min(energy_Top_source)
lattice_Top_min = lattice_Top_source[np.argmin(energy_Top_source)]
# Bridge
energy_Bridge_min = np.min(energy_Bridge_source)
lattice_Bridge_min = lattice_Bridge_source[np.argmin(energy_Bridge_source)]
# Hollow_1
energy_Hollow_1_min = np.min(energy_Hollow_1_source)
lattice_Hollow_1_min = lattice_Hollow_1_source[np.argmin(energy_Hollow_1_source)]
# Hollow_2
energy_Hollow_2_min = np.min(energy_Hollow_2_source)
lattice_Hollow_2_min = lattice_Hollow_2_source[np.argmin(energy_Hollow_2_source)]

## Extrema point of fitted data
# Top
energy_Top_index = np.argmin(energy_Top_fitted)
fitted_lattice_Top_min = lattice_Top_source[energy_Top_index]
fitted_energy_Top_min = energy_Top_fitted[energy_Top_index]
# Bridge
energy_Bridge_index = np.argmin(energy_Bridge_fitted)
fitted_lattice_Bridge_min = lattice_Bridge_source[energy_Bridge_index]
fitted_energy_Bridge_min = energy_Bridge_fitted[energy_Bridge_index]
# Hollow 1
energy_Hollow_1_index = np.argmin(energy_Hollow_1_fitted)
fitted_lattice_Hollow_1_min = lattice_Hollow_1_source[energy_Hollow_1_index]
fitted_energy_Hollow_1_min = energy_Hollow_1_fitted[energy_Hollow_1_index]
# Hollow 2
energy_Hollow_2_index = np.argmin(energy_Hollow_2_fitted)
fitted_lattice_Hollow_2_min = lattice_Hollow_2_source[energy_Hollow_2_index]
fitted_energy_Hollow_2_min = energy_Hollow_2_fitted[energy_Hollow_2_index]

print(f"Fitted extrema lattice of Top: {float(fitted_lattice_Top_min)}(Å), the corresponding energy is {float(fitted_energy_Top_min)}(eV).")
print(f"Fitted extrema lattice of Bridge: {float(fitted_lattice_Bridge_min)}(Å), the corresponding energy is {float(fitted_energy_Bridge_min)}(eV).")
print(f"Fitted extrema lattice of Hollow 1: {float(fitted_lattice_Hollow_1_min)}(Å), the corresponding energy is {float(fitted_energy_Hollow_1_min)}(eV).")
print(f"Fitted extrema lattice of Hollow 2: {float(fitted_lattice_Hollow_2_min)}(Å), the corresponding energy is {float(fitted_energy_Hollow_2_min)}(eV).")

lattice_Top_array = np.array(lattice_Top_source)
start_Top = np.searchsorted(lattice_Top_array, lattice_start)
end_Top = np.searchsorted(lattice_Top_array, lattice_end)+1

lattice_Bridge_array = np.array(lattice_Bridge_source)
start_Bridge = np.searchsorted(lattice_Bridge_array, lattice_start)
end_Bridge = np.searchsorted(lattice_Bridge_array, lattice_end)+1

lattice_Hollow_1_array = np.array(lattice_Hollow_1_source)
start_Hollow_1 = np.searchsorted(lattice_Hollow_1_array, lattice_start)
end_Hollow_1 = np.searchsorted(lattice_Hollow_1_array, lattice_end)+1

lattice_Hollow_2_array = np.array(lattice_Hollow_2_source)
start_Hollow_2 = np.searchsorted(lattice_Hollow_2_array, lattice_start)
end_Hollow_2 = np.searchsorted(lattice_Hollow_2_array, lattice_end)+1

## Selected point
selected_path = "1_Lattice_Selected/lattice.dat"
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[4:5]
    for line in lines:
        split_line = line.strip().split()
        lattice_selected_Top = float(split_line[2])
        energy_selected_Top = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[5:6]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Bridge = float(split_line[2])
        energy_selected_Bridge = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[6:7]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Hollow_1 = float(split_line[2])
        energy_selected_Hollow_1 = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[7:8]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Hollow_2 = float(split_line[2])
        energy_selected_Hollow_2 = float(split_line[4])

print(f"Selected lattice of Top: {lattice_selected_Top}(Å), the corresponding energy is {energy_selected_Top}(eV).")
print(f"Selected lattice of Bridge: {lattice_selected_Bridge}(Å), the corresponding energy is {energy_selected_Bridge}(eV).")
print(f"Selected lattice of Hollow 1: {lattice_selected_Hollow_1}(Å), the corresponding energy is {energy_selected_Hollow_1}(eV).")
print(f"Selected lattice of Hollow 2: {lattice_selected_Hollow_2}(Å), the corresponding energy is {energy_selected_Hollow_2}(eV).")

## Plot
import matplotlib.pyplot as plt

plt.figure(dpi=256, figsize=(10,6))
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)
plt.tick_params(direction="in", which="both", top=True, right=True, bottom=True, left=True)
plt.title(f"Free energy versus lattice for {Matter}"); plt.xlabel(r"Lattice constant (Å)"); plt.ylabel(r"Energy (eV)")

# Source data: Top
plt.scatter(lattice_Top, energy_Top, s=48, facecolors="#FFFFFF", edgecolors="#1473D2", label="Source data: Top", zorder=2)
plt.scatter(lattice_Top_min, energy_Top_min, s=96, facecolors="#FFFFFF", edgecolors="#1473D2", zorder=2)
# Source data: Bridge
plt.scatter(lattice_Bridge, energy_Bridge, s=48, facecolors="#FFFFFF", edgecolors="#288C3C", label="Source data: Bridge", zorder=2)
plt.scatter(lattice_Bridge_min, energy_Bridge_min, s=96, facecolors="#FFFFFF", edgecolors="#288C3C", zorder=2)
# Source data: Hollow 1
plt.scatter(lattice_Hollow_1, energy_Hollow_1, s=48, facecolors="#FFFFFF", edgecolors="#A59BF0", label="Source data: Hollow 1", zorder=2)
plt.scatter(lattice_Hollow_1_min, energy_Hollow_1_min, s=96, facecolors="#FFFFFF", edgecolors="#A59BF0", zorder=2)
# Source data: Hollow 2
plt.scatter(lattice_Hollow_2, energy_Hollow_2, s=48, facecolors="#FFFFFF", edgecolors="#8750AF", label="Source data: Hollow 2", zorder=2)
plt.scatter(lattice_Hollow_2_min, energy_Hollow_2_min, s=96, facecolors="#FFFFFF", edgecolors="#8750AF", zorder=2)

# Fitted data: top
plt.plot(lattice_Top_source[start_Top: end_Top], energy_Top_fitted[start_Top: end_Top], color="#1473D2", label="Fitted data: Top", zorder=1)
# Fitted data: Bridge
plt.plot(lattice_Bridge_source[start_Bridge: end_Bridge], energy_Bridge_fitted[start_Bridge: end_Bridge], color="#288C3C", label="Fitted data: Bridge", zorder=1)
# Fitted data: Hollow 1
plt.plot(lattice_Hollow_1_source[start_Hollow_1: end_Hollow_1], energy_Hollow_1_fitted[start_Hollow_1: end_Hollow_1], color="#A59BF0", label="Fitted data: Hollow 1", zorder=1)
# Fitted data: Hollow 2
plt.plot(lattice_Hollow_2_source[start_Hollow_2: end_Hollow_2], energy_Hollow_2_fitted[start_Hollow_2: end_Hollow_2], color="#8750AF", label="Fitted data: Hollow 2", zorder=1)

# Selected point
plt.scatter(lattice_selected_Top, energy_selected_Top, s=48, color="#1473D2", zorder=4)
plt.scatter(lattice_selected_Bridge, energy_selected_Bridge, s=48, color="#288C3C", zorder=4)
plt.scatter(lattice_selected_Hollow_1, energy_selected_Hollow_1, s=48, color="#A59BF0", zorder=4)
plt.scatter(lattice_selected_Hollow_2, energy_selected_Hollow_2, s=48, color="#8750AF", zorder=4)

plt.xlim(lattice_start-lattice_range*0.05, lattice_end+lattice_range*0.05)
plt.ylim(energy_min-energy_range*0.05,energy_max+energy_range*0.1)
plt.legend(loc="upper right")
# Out:
# Fitted extrema lattice of Top: 4.978(Å), the corresponding energy is -125.92722717774117(eV).
# Fitted extrema lattice of Bridge: 4.979(Å), the corresponding energy is -125.9175763375732(eV).
# Fitted extrema lattice of Hollow 1: 4.979(Å), the corresponding energy is -125.9124873169639(eV).
# Fitted extrema lattice of Hollow 2: 4.98(Å), the corresponding energy is -125.90942302442629(eV).
# Selected lattice of Top: 4.979(Å), the corresponding energy is -125.92712719(eV).
# Selected lattice of Bridge: 4.979(Å), the corresponding energy is -125.92124473(eV).
# Selected lattice of Hollow 1: 4.979(Å), the corresponding energy is -125.91420009(eV).
# Selected lattice of Hollow 2: 4.979(Å), the corresponding energy is -125.90933841(eV).

# %%
#### Graphene - B4C3

## Read data functions
import numpy as np
from Store.lattice_extracting import read_lattice_distance,  read_lattice_distance_select
from Store.filter_segment import filter_segment
from Store.birch_murnaghan import fit_eos

Matter = "Graphene - B₄C₃"

## Lattice range
lattice_start = 4.82
lattice_range = 0.040
lattice_end = lattice_start + lattice_range

## Source data
# Top
lattice_Top_source, distance_Top_source, energy_Top_source = read_lattice_distance("0_Lattice_Twin/C1_Graphene-B4C3_Top/lattice.dat")
# Bridge
lattice_Bridge_source, distance_Bridge_source, energy_Bridge_source = read_lattice_distance("0_Lattice_Twin/C2_Graphene-B4C3_Bridge/lattice.dat")
# Hollow 1
lattice_Hollow_1_source, distance_Hollow_1_source, energy_Hollow_1_source = read_lattice_distance("0_Lattice_Twin/C3_Graphene-B4C3_Hollow_1/lattice.dat")
# Hollow 2
lattice_Hollow_2_source, distance_Hollow_2_source, energy_Hollow_2_source = read_lattice_distance("0_Lattice_Twin/C4_Graphene-B4C3_Hollow_2/lattice.dat")

## Discretized source data
divisor = 5
# Top
lattice_Top_dis, distance_Top_dis, energy_Top_dis = read_lattice_distance_select("0_Lattice_Twin/C1_Graphene-B4C3_Top/lattice.dat",1000,divisor)
# Bridge
lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis = read_lattice_distance_select("0_Lattice_Twin/C2_Graphene-B4C3_Bridge/lattice.dat",1000,divisor)
# Hollow 1
lattice_Hollow_1_dis, distance_Hollow_1_dis, energy_Hollow_1_dis = read_lattice_distance_select("0_Lattice_Twin/C3_Graphene-B4C3_Hollow_1/lattice.dat",1000,divisor)
# Hollow 2
lattice_Hollow_2_dis, distance_Hollow_2_dis, energy_Hollow_2_dis = read_lattice_distance_select("0_Lattice_Twin/C4_Graphene-B4C3_Hollow_2/lattice.dat",1000,divisor)

## Segment select
lattice_Top, distance_Top, energy_Top = filter_segment(lattice_Top_dis, distance_Top_dis, energy_Top_dis, lattice_start, lattice_end)
lattice_Bridge, distance_Bridge, energy_Bridge = filter_segment(lattice_Bridge_dis, distance_Bridge_dis, energy_Bridge_dis, lattice_start, lattice_end)
lattice_Hollow_1, distance_Hollow_1, energy_Hollow_1 = filter_segment(lattice_Hollow_1_dis, distance_Hollow_1_dis, energy_Hollow_1_dis, lattice_start, lattice_end)
lattice_Hollow_2, distance_Hollow_2, energy_Hollow_2 = filter_segment(lattice_Hollow_2_dis, distance_Hollow_2_dis, energy_Hollow_2_dis, lattice_start, lattice_end)
# Lattice range
lattice_range = max(max(lattice_Top), max(lattice_Bridge), max(lattice_Hollow_1), max(lattice_Hollow_2))-min(min(lattice_Top), min(lattice_Bridge), min(lattice_Hollow_1), min(lattice_Hollow_2))
# Energy range
energy_max = max(max(energy_Top), max(energy_Bridge), max(energy_Hollow_1), max(energy_Hollow_2))
energy_min = min(min(energy_Top), min(energy_Bridge), min(energy_Hollow_1), min(energy_Hollow_2))
energy_range = energy_max - energy_min

## Fit curve
# Top
energy_Top_fitted = fit_eos(lattice_Top_source, energy_Top_source)
# Bridge
energy_Bridge_fitted = fit_eos(lattice_Bridge_source, energy_Bridge_source)
# Hollow_1
energy_Hollow_1_fitted = fit_eos(lattice_Hollow_1_source, energy_Hollow_1_source)
# Hollow_2
energy_Hollow_2_fitted = fit_eos(lattice_Hollow_2_source, energy_Hollow_2_source)

## Extrema point of source data
# Top
energy_Top_min = np.min(energy_Top_source)
lattice_Top_min = lattice_Top_source[np.argmin(energy_Top_source)]
# Bridge
energy_Bridge_min = np.min(energy_Bridge_source)
lattice_Bridge_min = lattice_Bridge_source[np.argmin(energy_Bridge_source)]
# Hollow_1
energy_Hollow_1_min = np.min(energy_Hollow_1_source)
lattice_Hollow_1_min = lattice_Hollow_1_source[np.argmin(energy_Hollow_1_source)]
# Hollow_2
energy_Hollow_2_min = np.min(energy_Hollow_2_source)
lattice_Hollow_2_min = lattice_Hollow_2_source[np.argmin(energy_Hollow_2_source)]

## Extrema point of fitted data
# Top
energy_Top_index = np.argmin(energy_Top_fitted)
fitted_lattice_Top_min = lattice_Top_source[energy_Top_index]
fitted_energy_Top_min = energy_Top_fitted[energy_Top_index]
# Bridge
energy_Bridge_index = np.argmin(energy_Bridge_fitted)
fitted_lattice_Bridge_min = lattice_Bridge_source[energy_Bridge_index]
fitted_energy_Bridge_min = energy_Bridge_fitted[energy_Bridge_index]
# Hollow 1
energy_Hollow_1_index = np.argmin(energy_Hollow_1_fitted)
fitted_lattice_Hollow_1_min = lattice_Hollow_1_source[energy_Hollow_1_index]
fitted_energy_Hollow_1_min = energy_Hollow_1_fitted[energy_Hollow_1_index]
# Hollow 2
energy_Hollow_2_index = np.argmin(energy_Hollow_2_fitted)
fitted_lattice_Hollow_2_min = lattice_Hollow_2_source[energy_Hollow_2_index]
fitted_energy_Hollow_2_min = energy_Hollow_2_fitted[energy_Hollow_2_index]

print(f"Fitted extrema lattice of Top: {float(fitted_lattice_Top_min)}(Å), the corresponding energy is {float(fitted_energy_Top_min)}(eV).")
print(f"Fitted extrema lattice of Bridge: {float(fitted_lattice_Bridge_min)}(Å), the corresponding energy is {float(fitted_energy_Bridge_min)}(eV).")
print(f"Fitted extrema lattice of Hollow 1: {float(fitted_lattice_Hollow_1_min)}(Å), the corresponding energy is {float(fitted_energy_Hollow_1_min)}(eV).")
print(f"Fitted extrema lattice of Hollow 2: {float(fitted_lattice_Hollow_2_min)}(Å), the corresponding energy is {float(fitted_energy_Hollow_2_min)}(eV).")

lattice_Top_array = np.array(lattice_Top_source)
start_Top = np.searchsorted(lattice_Top_array, lattice_start)
end_Top = np.searchsorted(lattice_Top_array, lattice_end)+1

lattice_Bridge_array = np.array(lattice_Bridge_source)
start_Bridge = np.searchsorted(lattice_Bridge_array, lattice_start)
end_Bridge = np.searchsorted(lattice_Bridge_array, lattice_end)+1

lattice_Hollow_1_array = np.array(lattice_Hollow_1_source)
start_Hollow_1 = np.searchsorted(lattice_Hollow_1_array, lattice_start)
end_Hollow_1 = np.searchsorted(lattice_Hollow_1_array, lattice_end)+1

lattice_Hollow_2_array = np.array(lattice_Hollow_2_source)
start_Hollow_2 = np.searchsorted(lattice_Hollow_2_array, lattice_start)
end_Hollow_2 = np.searchsorted(lattice_Hollow_2_array, lattice_end)+1

## Selected point
selected_path = "1_Lattice_Selected/lattice.dat"
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[8:9]
    for line in lines:
        split_line = line.strip().split()
        lattice_selected_Top = float(split_line[2])
        energy_selected_Top = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[9:10]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Bridge = float(split_line[2])
        energy_selected_Bridge = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[10:11]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Hollow_1 = float(split_line[2])
        energy_selected_Hollow_1 = float(split_line[4])
with open(selected_path, "r", encoding="utf-8") as f:
    lines = f.readlines()[11:12]
    for line in lines:    
        split_line = line.strip().split()
        lattice_selected_Hollow_2 = float(split_line[2])
        energy_selected_Hollow_2 = float(split_line[4])

print(f"Selected lattice of Top: {lattice_selected_Top}(Å), the corresponding energy is {energy_selected_Top}(eV).")
print(f"Selected lattice of Bridge: {lattice_selected_Bridge}(Å), the corresponding energy is {energy_selected_Bridge}(eV).")
print(f"Selected lattice of Hollow 1: {lattice_selected_Hollow_1}(Å), the corresponding energy is {energy_selected_Hollow_1}(eV).")
print(f"Selected lattice of Hollow 2: {lattice_selected_Hollow_2}(Å), the corresponding energy is {energy_selected_Hollow_2}(eV).")

## Plot
import matplotlib.pyplot as plt

plt.figure(dpi=256, figsize=(10,6))
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)
plt.tick_params(direction="in", which="both", top=True, right=True, bottom=True, left=True)
plt.title(f"Free energy versus lattice for {Matter}"); plt.xlabel(r"Lattice constant (Å)"); plt.ylabel(r"Energy (eV)")

# Source data: Top
plt.scatter(lattice_Top, energy_Top, s=48, facecolors="#FFFFFF", edgecolors="#1473D2", label="Source data: Top", zorder=3)
plt.scatter(lattice_Top_min, energy_Top_min, s=96, facecolors="#FFFFFF", edgecolors="#1473D2", zorder=4)
# Source data: Bridge
plt.scatter(lattice_Bridge, energy_Bridge, s=48, facecolors="#FFFFFF", edgecolors="#288C3C", label="Source data: Bridge", zorder=2)
plt.scatter(lattice_Bridge_min, energy_Bridge_min, s=182, facecolors="#FFFFFF", edgecolors="#288C3C", zorder=2)
# Source data: Hollow 1
plt.scatter(lattice_Hollow_1, energy_Hollow_1, s=48, facecolors="#FFFFFF", edgecolors="#A59BF0", label="Source data: Hollow 1", zorder=2)
plt.scatter(lattice_Hollow_1_min, energy_Hollow_1_min, s=96, facecolors="#FFFFFF", edgecolors="#A59BF0", zorder=2)
# Source data: Hollow 2
plt.scatter(lattice_Hollow_2, energy_Hollow_2, s=48, facecolors="#FFFFFF", edgecolors="#8750AF", label="Source data: Hollow 2", zorder=2)
plt.scatter(lattice_Hollow_2_min, energy_Hollow_2_min, s=96, facecolors="#FFFFFF", edgecolors="#8750AF", zorder=2)

# Fitted data: top
plt.plot(lattice_Top_source[start_Top: end_Top], energy_Top_fitted[start_Top: end_Top], color="#1473D2", label="Fitted data: Top", zorder=1)
# Fitted data: Bridge
plt.plot(lattice_Bridge_source[start_Bridge: end_Bridge], energy_Bridge_fitted[start_Bridge: end_Bridge], color="#288C3C", label="Fitted data: Bridge", zorder=1)
# Fitted data: Hollow 1
plt.plot(lattice_Hollow_1_source[start_Hollow_1: end_Hollow_1], energy_Hollow_1_fitted[start_Hollow_1: end_Hollow_1], color="#A59BF0", label="Fitted data: Hollow 1", zorder=1)
# Fitted data: Hollow 2
plt.plot(lattice_Hollow_2_source[start_Hollow_2: end_Hollow_2], energy_Hollow_2_fitted[start_Hollow_2: end_Hollow_2], color="#8750AF", label="Fitted data: Hollow 2", zorder=1)

# Selected point
plt.scatter(lattice_selected_Top, energy_selected_Top, s=48, color="#1473D2", zorder=4)
plt.scatter(lattice_selected_Bridge, energy_selected_Bridge, s=48, color="#288C3C", zorder=4)
plt.scatter(lattice_selected_Hollow_1, energy_selected_Hollow_1, s=48, color="#A59BF0", zorder=4)
plt.scatter(lattice_selected_Hollow_2, energy_selected_Hollow_2, s=48, color="#8750AF", zorder=4)

plt.xlim(lattice_start-lattice_range*0.05, lattice_end+lattice_range*0.05)
plt.ylim(energy_min-energy_range*0.05,energy_max+energy_range*0.05)
plt.legend(loc="upper right")
# Out:
# Fitted extrema lattice of Top: 4.846(Å), the corresponding energy is -127.13807372364(eV).
# Fitted extrema lattice of Bridge: 4.846(Å), the corresponding energy is -127.13587780383156(eV).
# Fitted extrema lattice of Hollow 1: 4.846(Å), the corresponding energy is -127.13282690029096(eV).
# Fitted extrema lattice of Hollow 2: 4.846(Å), the corresponding energy is -127.12439500113379(eV).
# Selected lattice of Top: 4.846(Å), the corresponding energy is -127.1380817(eV).
# Selected lattice of Bridge: 4.846(Å), the corresponding energy is -127.13482934(eV).
# Selected lattice of Hollow 1: 4.846(Å), the corresponding energy is -127.13283516(eV).
# Selected lattice of Hollow 2: 4.846(Å), the corresponding energy is -127.12438981(eV).
