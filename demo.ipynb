# %% [markdown]
# # Molecular Structure Plotting
#
# with `conda` virtual environment

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure()

plt.plot(x, y)

plt.title("Simple Matplotlib Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.show()
