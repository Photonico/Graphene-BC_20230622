# %% [markdown]
# # Lattice
#
# Total energy versus lattice constant

# %% [markdown]
# ## Results
#
# ### monolayer
#
# * BC₃
#   * Most stable Lattice constant: 5.169 Angstrom
#   * Minimal free energy: -67.90772805 eV
#   * B-C bond: 1.563 Angstrom
#   * C-C bond: 1.421 Angstrom
#   * LUMO band: -3.157700
#   * HOMO band: -3.791800
#   * Band gap: 0.634100
#
# * Borophene
#   * Most stable Lattice constant: 5.051 Angstrom
#   * Minimal free energy: -51.13565322 eV
#   * B-B bond: 1.689×4, 1.707×1, 1.672×2 Angstrom
#   * LUMO band: -2.286800
#   * HOMO band: -1.730000
#   * Band gap: -0.556800
#
# * B₄C₃
#   * Most stable Lattice constant: 4.690 Angstrom
#   * Minimal free energy: -52.83670852 eV
#   * B-B bond: 1.689×1 Angstrom
#   * B-C bond: 1.548×1, 1.592×2 Angstrom
#   * LUMO band: -1.209400
#   * HOMO band: -2.855900
#   * Band gap: 1.646500
#
# * Graphene
#   * Most stable Lattice constant: 2.467 Angstrom
#   * Minimal free energy: -18.63125049 eV
#   * C-C bond: 1.424 Angstrom
#   * LUMO band: -2.243900
#   * HOMO band: -2.262400
#   * Band gap: 0.018500
#
# ### Graphene - BC₃
#
# * Top (shift 0)
#   * Most stable Lattice constant: 5.044 (Å)
#   * Minimal free energy: -142.29250662 (eV)
#
# * Bridge (shift 1/12)
#   * Most stable Lattice constant: 5.044(Å)
#   * Minimal free energy: -142.29046554 (eV)
#
# * Hollow (shift 1/6) - Selected
#   * Most stable Lattice constant: 5.044(Å)
#   * Most stable distance: 3.375 (Å)
#   * Minimal free energy: -142.29386706 (eV)
#   * B-C bond:
#   * C-C bond:
#   * LUMO band: -0.918100
#   * HOMO band: -0.936600
#   * Band gap: 0.018500
#
# ### Graphene - Borophene
#
# * Top  (shift 0) - Selected
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance: 3.496 (Å)
#   * Minimal free energy: -125.92763502 (eV)
#   * B-C bond:
#   * C-C bond:
#   * LUMO band: -0.510900
#   * HOMO band: -0.311000
#   * Band gap: -0.199900
#
# * Bridge  (shift 1/12)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Minimal free energy: -125.92124473 (eV)
#
# * Hollow1  (shift 1/9)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Minimal free energy: -125.91420009(eV).
#
# * Hollow2  (shift 1/6)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Minimal free energy: -125.90933841(eV).
#
# ### Graphene - B₄C₃
#
# * Top (shift -1/6) - Selected
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance: 3.514 (Å)
#   * Minimal free energy: -127.14058195 (eV)
#   * B-C bond:
#   * C-C bond:
#   * LUMO band: -0.314600
#   * HOMO band: -0.331300
#   * Band gap: 0.016700
#
# * Bridge (shift -1/12)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Minimal free energy: -127.13482934 (eV)
#
# * Hollow1 (shift -1/18)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Minimal free energy: -127.13283516 (eV)
#
# * Hollow2 (shift 0)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Minimal free energy: -127.12438981 (eV)

# %%
# Overview

from Store.lattice import *
from Store.lattice_bilayer import *
from Store.lattice_plotting import *

BC3 = specify_lattice_free_energy("0_Lattice/selected/A_BC3_a5.169")
BC3_SCF = specify_lattice_free_energy("2_Self_Consistent/A_BC3_K41")
print(f"BC3 Lat: Lattice constant: {BC3[0]}, Free energy: {BC3[1]}" )
print(f"BC3 SCF: Lattice constant: {BC3_SCF[0]}, Free energy: {BC3_SCF[1]}" )

Borophene = specify_lattice_free_energy("0_Lattice/selected/B_Borophene_a5.051")
Borophene_SCF = specify_lattice_free_energy("2_Self_Consistent/B_Borophene_K41")
print(f"Borophene Lat: Lattice constant: {Borophene[0]}, Free energy: {Borophene[1]}" )
print(f"Borophene SCF: Lattice constant: {Borophene_SCF[0]}, Free energy: {Borophene_SCF[1]}" )

B4C3 = specify_lattice_free_energy("0_Lattice/selected/C_B4C3_a4.690")
B4C3_SCF = specify_lattice_free_energy("2_Self_Consistent/C_B4C3_K41")
print(f"B4C3 Lat: Lattice constant: {B4C3[0]}, Free energy: {B4C3[1]}" )
print(f"B4C3 SCF: Lattice constant: {B4C3_SCF[0]}, Free energy: {B4C3_SCF[1]}" )

Graphene = specify_lattice_free_energy("0_Lattice/selected/D_Graphene_a2.467")
Graphene_SCF = specify_lattice_free_energy("2_Self_Consistent/D_Graphene_K11")
print(f"Graphene Lat: Lattice constant: {Graphene[0]}, Free energy: {Graphene[1]}" )
print(f"Graphene SCF: Lattice constant: {Graphene_SCF[0]}, Free energy: {Graphene_SCF[1]}" )

Graphene_BC3_Hollow = specify_bilayer_lattice("0_Lattice/selected/E_Graphene-BC3_Hollow_a5.044_d3.768")
Graphene_BC3_Hollow_SCF = specify_bilayer_lattice("2_Self_Consistent/E_Graphene-BC3_Hollow_K41")
print(f"Graphene-BC₃ (Hollow) Lat: Lattice constant: {Graphene_BC3_Hollow[0]}, Interlayer spacing: {Graphene_BC3_Hollow[1]}, Free energy: {Graphene_BC3_Hollow[2]}")
print(f"Graphene-BC₃ (Hollow) SCF: Lattice constant: {Graphene_BC3_Hollow_SCF[0]}, Interlayer spacing: {Graphene_BC3_Hollow_SCF[1]}, Free energy: {Graphene_BC3_Hollow_SCF[2]}")


Graphene_Borophene_Top = specify_bilayer_lattice("0_Lattice/selected/F_Graphene-Borophene_Top_a4.979_d3.540")
Graphene_Borophene_Top_SCF = specify_bilayer_lattice("2_Self_Consistent/F_Graphene-Borophene_Top_K41")
print(f"Graphene-Borophene (Top) Lat: Lattice constant: {Graphene_Borophene_Top[0]}, Interlayer spacing: {Graphene_Borophene_Top[1]}, Free energy: {Graphene_Borophene_Top[2]}" )
print(f"Graphene-Borophene (Top) SCF: Lattice constant: {Graphene_Borophene_Top_SCF[0]}, Interlayer spacing: {Graphene_Borophene_Top_SCF[1]}, Free energy: {Graphene_Borophene_Top_SCF[2]}")


Graphene_BC3_B4C3 = specify_bilayer_lattice("0_Lattice/selected/G_Graphene-B4C3_Top_a4.846_d3.512")
Graphene_BC3_B4C3_SCF = specify_bilayer_lattice("2_Self_Consistent/G_Graphene-B4C3_Top_K41")
print(f"Graphene-B₄C₃ (Top) Lat: Lattice constant: {Graphene_BC3_B4C3[0]}, Interlayer spacing: {Graphene_BC3_B4C3[1]}, Free energy: {Graphene_BC3_B4C3[2]}")
print(f"Graphene-B₄C₃ (Top) SCF: Lattice constant: {Graphene_BC3_B4C3_SCF[0]}, Interlayer spacing: {Graphene_BC3_B4C3_SCF[1]}, Free energy: {Graphene_BC3_B4C3_SCF[2]}")
# Out:
# BC3 Lat: Lattice constant: 5.168999729659985, Free energy: -67.90772214
# BC3 SCF: Lattice constant: 5.168999729659985, Free energy: -67.90772805
# Borophene Lat: Lattice constant: 5.05099972762185, Free energy: -51.1382175
# Borophene SCF: Lattice constant: 5.05099972762185, Free energy: -51.13565322
# B4C3 Lat: Lattice constant: 4.6899998755097, Free energy: -52.83670482
# B4C3 SCF: Lattice constant: 4.6899998755097, Free energy: -52.83670852
# Graphene Lat: Lattice constant: 2.467000284804402, Free energy: -18.62498564
# Graphene SCF: Lattice constant: 2.466999851791696, Free energy: -18.63125049
# Graphene-BC₃ (Hollow) Lat: Lattice constant: 5.044000002867662, Interlayer spacing: 3.373819306252253, Free energy: -142.29250662
# Graphene-BC₃ (Hollow) SCF: Lattice constant: 5.044000002867662, Interlayer spacing: 3.3746896669288873, Free energy: -142.29386706
# ...

# %%
# BC3

plot_lattice_free_energy(1, "BC₃", 11, "0_Lattice/A_BC3/lattice_free_energy.dat", "blue", "0_Lattice/selected/A_BC3_a5.169")

# %%
# Borophene

plot_lattice_free_energy(1, "Borophene", 11, "0_Lattice/B_Borophene/lattice_free_energy.dat", "green", "0_Lattice/selected/B_Borophene_a5.051")

# %%
# B₄C₃

plot_lattice_free_energy(1, "B₄C₃", 11, "0_Lattice/C_B4C3/lattice_free_energy.dat", "violet", "0_Lattice/selected/C_B4C3_a4.690")

# %%
# Graphene

summarize_lattice_free_energy_directory("0_Lattice/D_Graphene")

plot_lattice_free_energy(1, "Graphene", 11, "0_Lattice/D_Graphene/lattice_free_energy.dat", "grey", "0_Lattice/selected/D_Graphene_a2.467")

# %%
# Graphene (Full size)

summarize_lattice_free_energy_directory("0_Lattice/D_Graphene_fullsize")

plot_lattice_free_energy(1, "Graphene (full size)", 11, "0_Lattice/D_Graphene_fullsize/lattice_free_energy.dat", "red", "0_Lattice/selected/D_Graphene_fullsize_a2.467")

# %%
# Graphene - BC3

plot_lattice_free_energy(3, "Graphene-BC₃", 11,
                         "Top", "0_Lattice/E_Graphene-BC3_Top/lattice_free_energy.dat", "blue", 
                         "Bridge", "0_Lattice/E_Graphene-BC3_Bridge/lattice_free_energy.dat", "green",
                         "Hollow", "0_Lattice/E_Graphene-BC3_Hollow/lattice_free_energy.dat", "violet",
                         "0_Lattice/selected/E_Graphene-BC3_Top_a5.044_d3.432",
                         "0_Lattice/selected/E_Graphene-BC3_Bridge_a5.044_d3.667",
                         "0_Lattice/selected/E_Graphene-BC3_Hollow_a5.044_d3.768")

# %%
# Graphene - Borophene

plot_lattice_free_energy(4, "Graphene-Borophene", 11,
                         "Top", "0_Lattice/F_Graphene-Borophene_Top/lattice_free_energy.dat", "blue", 
                         "Bridge", "0_Lattice/F_Graphene-Borophene_Bridge/lattice_free_energy.dat", "green",
                         "Hollow 1", "0_Lattice/F_Graphene-Borophene_Hollow1/lattice_free_energy.dat", "violet",
                         "Hollow 2", "0_Lattice/F_Graphene-Borophene_Hollow2/lattice_free_energy.dat", "purple",
                         "0_Lattice/selected/F_Graphene-Borophene_Top_a4.979_d3.540",
                         "0_Lattice/selected/F_Graphene-Borophene_Bridge_a4.979_d3.530",
                         "0_Lattice/selected/F_Graphene-Borophene_Hollow1_a4.979_d3.530",
                         "0_Lattice/selected/F_Graphene-Borophene_Hollow2_a4.979_d3.530",)

# %%
# Graphene - B₄C₃

plot_lattice_free_energy(4, "Graphene-B₄C₃", 11,
                         "Top", "0_Lattice/G_Graphene-B4C3_Top/lattice_free_energy.dat", "blue", 
                         "Bridge", "0_Lattice/G_Graphene-B4C3_Bridge/lattice_free_energy.dat", "green",
                         "Hollow 1", "0_Lattice/G_Graphene-B4C3_Hollow1/lattice_free_energy.dat", "violet",
                         "Hollow 2", "0_Lattice/G_Graphene-B4C3_Hollow2/lattice_free_energy.dat", "purple",
                         "0_Lattice/selected/G_Graphene-B4C3_Top_a4.846_d3.512",
                         "0_Lattice/selected/G_Graphene-B4C3_Bridge_a4.846_d3.520",
                         "0_Lattice/selected/G_Graphene-B4C3_Hollow1_a4.846_d3.520",
                         "0_Lattice/selected/G_Graphene-B4C3_Hollow2_a4.846_d3.520")
