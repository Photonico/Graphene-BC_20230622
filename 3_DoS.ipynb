# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# BC₃

from Store.DoS import extract_dos, plot_dos

dos_BC3_Gaussian = extract_dos("4_PDOS_PBE/A_BC3_K11_Gaussian/vasprun.xml")
dos_BC3_Tetrahedron = extract_dos("4_PDOS_PBE/A_BC3_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_BC3_Gaussian, "blue"],["Tetrahedron", dos_BC3_Tetrahedron, "purple"]]

plot_dos("BC₃", 6, 12, "PBE","total", matters)

# %%
# Borophene

dos_Borophene_Gaussian = extract_dos("4_PDOS_PBE/B_Borophene_K11_Gaussian/vasprun.xml")
dos_Borophene_Tetrahedron = extract_dos("4_PDOS_PBE/B_Borophene_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_Borophene_Gaussian, "blue"],["Tetrahedron", dos_Borophene_Tetrahedron, "purple"]]

plot_dos("Borophene",6, 12, "PBE","total", matters)

# %%
# B₄C₃

dos_B4C3_Gaussian = extract_dos("4_PDOS_PBE/C_B4C3_K11_Gaussian/vasprun.xml")
dos_B4C3_Tetrahedron = extract_dos("4_PDOS_PBE/C_B4C3_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_B4C3_Gaussian, "blue"],["Tetrahedron", dos_B4C3_Tetrahedron, "purple"]]

plot_dos("B₄C₃", 6, 12, "PBE","total", matters)

# %%
# Graphene

dos_Graphene_Gaussian = extract_dos("4_PDOS_PBE/D_Graphene_K11_Gaussian/vasprun.xml")
dos_Graphene_Tetrahedron = extract_dos("4_PDOS_PBE/D_Graphene_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_Graphene_Gaussian, "blue"],["Tetrahedron", dos_Graphene_Tetrahedron, "purple"]]

plot_dos("Graphene", 6, 3, "PBE","total", matters)

# %%
# Graphene - BC₃

dos_E_Gaussian = extract_dos("4_PDOS_PBE/E_Graphene-BC3_Hollow_K11_Gaussian/vasprun.xml")
dos_E_Tetrahedron = extract_dos("4_PDOS_PBE/E_Graphene-BC3_Hollow_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_E_Gaussian, "blue"],["Tetrahedron", dos_E_Tetrahedron, "purple"]]

plot_dos("Graphene-BC₃: Hollow", 6, 12, "PBE","total", matters)

# %%
# Graphene - Borophene

dos_F_Gaussian = extract_dos("4_PDOS_PBE/F_Graphene-Borophene_Top_K11_Gaussian/vasprun.xml")
dos_F_Tetrahedron = extract_dos("4_PDOS_PBE/F_Graphene-Borophene_Top_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_F_Gaussian, "blue"],["Tetrahedron", dos_F_Tetrahedron, "purple"]]

plot_dos("Graphene-Borophene: Top", 6, 12, "PBE","total", matters)

# %%
# Graphene - B₄C₃

dos_G_Gaussian = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K11_Gaussian/vasprun.xml")
dos_G_Tetrahedron = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K11_Tetrahedron/vasprun.xml")

matters = [["Gaussian", dos_G_Gaussian, "blue"],["Tetrahedron", dos_G_Tetrahedron, "purple"]]

plot_dos("Graphene-B₄C₃: Top", 6, 12, "PBE","total", matters)

# %%
# Graphene - B₄C₃: DoS versus kpoints

dos_G_K11 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K11_Gaussian/vasprun.xml")
dos_G_K21 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K21_Gaussian/vasprun.xml")
dos_G_K31 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K31_Gaussian/vasprun.xml")

matters = [["11 Kpoints", dos_G_K11, "blue"], ["21 Kpoints", dos_G_K21, "violet"], ["31 Kpoints", dos_G_K31, "purple"]]

plot_dos("Graphene-B₄C₃: Top", 6, 16, "PBE(Gaussian)","total", matters)

# %%
# Graphene - B₄C₃: DoS versus kpoints

dos_G_K11 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K11_Tetrahedron/vasprun.xml")
dos_G_K21 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K21_Tetrahedron/vasprun.xml")
dos_G_K31 = extract_dos("4_PDOS_PBE/G_Graphene-B4C3_Top_K31_Tetrahedron/vasprun.xml")

matters = [["11 Kpoints", dos_G_K11, "blue"], ["21 Kpoints", dos_G_K21, "violet"], ["31 Kpoints", dos_G_K31, "purple"]]

plot_dos("Graphene-B₄C₃: Top", 6, 16, "PBE(Tetrahedron)","total", matters)
