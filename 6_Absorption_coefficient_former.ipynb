# %% [markdown]
# # Absorption Coefficient

# %%
#### 1.1 Absorption Coefficient for Single layer BC3

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import absorption_in

opt_11 = optical_properties_extracting("Single_BC3/6_Optical_properties/vasprun.xml")
absorption_in(opt_11, "BC₃", 0, 40)

# %%
#### 1.2 Absorption Coefficient for Single layer Graphene

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import absorption_in

opt_12 = optical_properties_extracting("Single_Graphene/6_Optical_properties/vasprun.xml")
absorption_in(opt_12, "Graphene", 0, 40)

# %%
#### 2.1 Absorption Coefficient for Double Graphene-BC3

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import absorption_in

opt_12 = optical_properties_extracting("Double_Graphene-BC3/6_Optical_properties/vasprun.xml")
absorption_in(opt_12, "Graphene - BC₃", 0, 40)

# %%
#### 2.1 Absorption Coefficient for Double Graphene-BC3 comparing with single layer BC3 and single layer Graphene

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import absorption_inplane_comparing

opt_Graphene_BC3 = optical_properties_extracting("Double_Graphene-BC3/6_Optical_properties/vasprun.xml")
opt_BC3 = optical_properties_extracting("Single_BC3/6_Optical_properties/vasprun.xml")
opt_Graphene = optical_properties_extracting("Single_Graphene/6_Optical_properties/vasprun.xml")

absorption_inplane_comparing("Graphene - BC₃", opt_Graphene_BC3, "BC3", opt_BC3,  "Graphene", opt_Graphene, 0, 40)
