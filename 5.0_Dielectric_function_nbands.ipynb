# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus nbands

# %%
# Graphene-BC₃ (Hollow)

# %%
# Graphene-Borophene (Top)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["nbands 32", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_32", "red",     1.0, 2.0],
                   ["nbands 64", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_64", "orange",  1.0, 2.0],
                   ["nbands 128", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_64", "green",  1.0, 1.6],
                   ["nbands 256", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_64", "blue",   1.0, 1.2],
                   ["nbands 512", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_64", "violet", 1.0, 0.8]]

# dielectric_list = [["nbands 32", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_32", "red"],
#                    ["nbands 128", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_64", "blue"]]

plot_dielectric_function_XZ("Graphene-B₄C₃ (Top)", dielectric_list, 40)
