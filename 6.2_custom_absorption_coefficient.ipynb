# %% [markdown]
# # Custom absorption coefficient
#
# We define the absorption coefficient of a system as:
#
# $$ I(\omega) = \sqrt{2}\omega\left[\sqrt{\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)}-\varepsilon_R(\omega)\right] $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# * Linear Optical Properties
#   * absorption coefficient
#   * refractive index
#   * extinction coefficient
#   * reflectivity
#   * energy loss spectrum
#
# References:
#
#     10.1039/C7RA10570C

# %%
# Prework

from vmatplot.absorption_coefficient import plot_absorption_XZ

import matplotlib.pyplot as plt

# %%
# Absorption coefficient (custom) for Graphene-BC₃

absorption_list = [["GGA-PBE", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
                   ["HSE06 17 k-points", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_absorption_XZ("for Graphene-BC₃", absorption_list, "eV", "custom", 40, 40, (4,12), (4,12))

# %%
# Absorption coefficient for (custom) Graphene-Borophene

absorption_list = [["GGA-PBE", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
                   ["HSE06", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_absorption_XZ("for Graphene-Borophene", absorption_list, "eV", "custom", 40, 40, (4,12), (4,12))

# %%
# Absorption coefficient (custom) for Graphene-B₄C₃

absorption_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
                   ["HSE06 17 k-points", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_absorption_XZ("for Graphene-B₄C₃", absorption_list, "eV", "custom", 40, 40, (4,12), (4,12))
