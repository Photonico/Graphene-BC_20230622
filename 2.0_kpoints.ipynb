# %% [markdown]
# # Kpoints
#
# Free energy versus K-points

# %%
# Prework

from vmatplot.kpoints import summarize_kpoints_free_energy, plot_kpoints_free_energy_data

# %%
# BC3

summarize_kpoints_free_energy("1_Kpoints/BC3")

plot_kpoints_free_energy_data("g-BC₃","1_Kpoints/BC3/kpoints_energy.dat","X",(11,59))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # BC3
# ----> 3 summarize_kpoints_free_energy("1_Kpoints/BC3")
#       5 plot_kpoints_free_energy_data("g-BC₃","1_Kpoints/BC3/kpoints_energy.dat","X", (11,59))
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\kpoints.py:140, in summarize_kpoints_free_energy(directory, lattice_boundary)
#     137 # Check if lattice constant is within the specified range
#     138 TOLERANCE = 1e-6
# --> 140 lattice_start = lattice_boundary[0]
#     141 lattice_end = lattice_boundary[1]
#     142 lattice_within_start = lattice_start in [None,""] or lattice_constant >= lattice_start - TOLERANCE
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Graphene - BC3: Hollow

summarize_kpoints_free_energy("1_Kpoints/Graphene_BC3_Hollow")

plot_kpoints_free_energy_data("Graphene-BC₃ (Hollow)","1_Kpoints/Graphene_BC3_Hollow/kpoints_energy.dat","X", 9, 61, "violet")
