# %% [markdown]
# # Absorption coefficient
#
# Comparison between PBE and HSE

# %%
# Prework

from vmatplot.absorption_coefficient import plot_absorption_XZ

# %%
# Graphene-B₄C₃ (Top)

absorption_list = [["PBE algorithm", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                   ["HSE algorithm", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_absorption_XZ("for Graphene-B₄C₃ comparison PBE and HSE", absorption_list, 800, 200)
