# %% [markdown]
# # DOS Demonstration
#
# Electronic density versus energy

# %%
#### 1.1 Single layer: BC3

from Store.DOS_extracting import extract_dos
from Store.DOS_plotting import plot_dos

pos_data_BC3 = extract_dos("Single_BC3/4_PDOS/vasprun.xml")
plot_dos(pos_data_BC3, "BC₃", 8)

# %%
#### 1.2 Single layer: Graphene

from Store.DOS_extracting import extract_dos
from Store.DOS_plotting import plot_dos

pos_data_Graphene = extract_dos("Single_Graphene/4_PDOS/vasprun.xml")
plot_dos(pos_data_Graphene, "Graphene", 8)

# %%
#### 2.1 Double layer: Graphene - BC3

from Store.DOS_extracting import extract_dos
from Store.DOS_plotting import plot_dos

pos_data_Graphene = extract_dos("Double_Graphene-BC3/4_PDOS/vasprun.xml")
plot_dos(pos_data_Graphene, "Graphene - BC₃", 10)
