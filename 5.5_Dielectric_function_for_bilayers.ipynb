# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# Graphene-BC₃ (Hollow)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_K17", "orange"],
                   ["PBE 65 kpoints", "5_Dielectric_function/E_Graphene-BC3_Hollow_PBE_K65", "blue"]]

plot_dielectric_function_XZ("Graphene-BC₃ (Top)", dielectric_list, 24, 24)

# %%
from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_K17", "orange"],
                   ["PBE 65 kpoints", "5_Dielectric_function/E_Graphene-BC3_Hollow_PBE_K65", "blue"]]

plot_dielectric_function_XZ("Graphene-BC₃ (Top)", dielectric_list, 8)

# %%
# Graphene-Borophene (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/F_Graphene-Borophene_HSE_K17", "orange"],
                   ["HSE 65 kpoints", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "yellow"],
                   ["PBE 65 kpoints", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65", "green"]]

plot_dielectric_function_XZ("for Graphene-Borophene (Top)", dielectric_list, 24, 24)

# %%
import py4vasp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import py4vasp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\__init__.py:3
#       1 # Copyright © VASP Software GmbH,
#       2 # Licensed under the Apache License 2.0 (http://www.apache.org/licenses/LICENSE-2.0)
# ----> 3 from py4vasp._calculation import Calculation
#       4 from py4vasp._third_party.graph import plot
#       5 from py4vasp._third_party.interactive import set_error_handling
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\_calculation.py:6
#       3 import inspect
#       4 import pathlib
# ----> 6 from py4vasp import _data, control, data, exception
#       7 from py4vasp._util import convert
# ...

# %%
from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE_K17", "orange"],
                   ["PBE 65 kpoints", "5_Dielectric_function/F_Graphene-Borophene_Top_PBE_K65", "green"]]

plot_dielectric_function_XZ("for Graphene-Borophene (Top)", dielectric_list, 6)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K17", "orange"],
                   ["PBE 65 kpoints", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K65", "violet"]]

plot_dielectric_function_XZ("for Graphene-B₄C₃ (Top)", dielectric_list, 24, 24)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["HSE 17 kpoints", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K17", "orange"],
                   ["PBE 65 kpoints", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K65", "violet"]]

plot_dielectric_function_XZ("for Graphene-B₄C₃ (Top)", dielectric_list, 8)

# %%
# Dielectric function

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block
import matplotlib.pyplot as plt

dielectric_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K17", "violet"],
                   ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE_K17", "green"],
                   ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_K17", "blue"]
                   ]

plot_dielectric_function_XZ_block("", dielectric_list, 6, 40)
# plt.savefig("Figures/5_dielectric_function.pdf")
