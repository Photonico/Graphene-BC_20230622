# %% [markdown]
# # DoS kpoints
#
# Electronic density of state versus energy in different

# %%
# Prework

from vmatplot.DoS import plot_dos

alpha = 0.4
solid = 1.0

# %%
# Graphene-BC₃ PBE

matters_dir = [["17 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K17", "grey",   solid],
               ["19 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K19", "orange", solid],
               ["21 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K21", "yellow", solid],
               ["23 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K21", "green",  solid],
               ["25 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K25", "blue",   solid],
               ["33 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K33", "violet", solid],
               ["65 Kpoints", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K65", "wine",   solid]]

plot_dos("Graphene-BC₃ (Hollow) in PBE", 6, 10, "total", matters_dir)

# %%
# Graphene-Borophene PBE

matters_dir = [["17 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K17", "grey",   solid],
               ["19 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K19", "orange", solid],
               ["21 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K21", "yellow", solid],
               ["23 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K21", "green",  solid],
               ["25 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K25", "blue",   solid],
               ["33 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K33", "violet", solid],
               ["65 Kpoints (PBE)", "4_PDoS_PBE/F_Graphene-Borophene_Top_K65", "wine",   solid]]

plot_dos("Graphene-Borophene: Top (PBE) in PBE", 6, 10, "total", matters_dir)

# %%
# Graphene-BC₃ PBE

matters_dir = [["17 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K17", "grey",   solid],
               ["19 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K19", "orange", solid],
               ["21 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K21", "yellow", solid],
               ["23 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K21", "green",  solid],
               ["25 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K25", "blue",   solid],
               ["33 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K33", "violet", solid],
               ["65 Kpoints", "4_PDoS_PBE/G_Graphene-B4C3_Top_K65", "wine",   solid]]

plot_dos("Graphene-B₄C₃: Top (PBE) in PBE", 6, 10, "total", matters_dir)
