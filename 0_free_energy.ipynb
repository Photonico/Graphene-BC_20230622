# %% [markdown]
# # Lattice
#
# Total energy versus lattice constant

# %% [markdown]
# ## Selected Results
#
# ### BC₃
#
# * Most stable Lattice constant: 5.169 Angstrom
# * Minimal free energy: -67.90772214 eV
# * B-C bond: 1.563 Angstrom
# * C-C bond: 1.421 Angstrom
#
# ### Borophene
#
# * Most stable Lattice constant: 5.051 Angstrom
# * Minimal free energy: -51.13821750 eV
# * B-B bond: 1.689×4, 1.707×1, 1.672×2 Angstrom
#
# ### B₄C₃
#
# * Most stable Lattice constant: 4.690 Angstrom
# * Minimal free energy: -52.83670482 eV
# * B-B bond: 1.689×1 Angstrom
# * B-C bond: 1.548×1, 1.592×2 Angstrom
#
# ### Graphene
#
# * Most stable Lattice constant: 2.467 Angstrom
# * Minimal free energy: -74.52125928 eV
# * C-C bond: 1.424 Angstrom

# %%
# BC3

from Store.lattice_free_energy import plot_lattice_free_energy_single

plot_lattice_free_energy_single("BC₃", "0_Lattice_Single/A_BC3/lattice_free_energy.dat", "1_Lattice_Selected/A_BC3_a5.169", 11, "blue")

# %%
# Borophene

plot_lattice_free_energy_single("Borophene", "0_Lattice_Single/B_Borophene/lattice_free_energy.dat", "1_Lattice_Selected/B_Borophene_a5.051", 11, "green")

# %%
# B₄C₃

plot_lattice_free_energy_single("B₄C₃", "0_Lattice_Single/C_B4C3/lattice_free_energy.dat", "1_Lattice_Selected/C_B4C3_a4.690", 11, "violet")

# %%
# Graphene

plot_lattice_free_energy_single("Graphene", "0_Lattice_Single/D_Graphene/lattice_free_energy.dat", "1_Lattice_Selected/D_Graphene_fullsize_a2.467", 11, "red")
