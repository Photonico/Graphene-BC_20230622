# %% [markdown]
# # Universal settings demo

# %%
# Check VASP work

from vmatplot.output import vasprun_directory, plot_color_families

Dir = "1_Self_Consistent"

vasprun_directory(Dir)
# Out:
# ['1_Self_Consistent\\A_BC3',
#  '1_Self_Consistent\\B_Borophene',
#  '1_Self_Consistent\\C_B4C3',
#  '1_Self_Consistent\\D_Graphene',
#  '1_Self_Consistent\\E_Graphene-BC3_Hollow',
#  '1_Self_Consistent\\F_Graphene-Borophene_Top',
#  '1_Self_Consistent\\G_Graphene-B4C3_Top']

# %%
# Colors demo

plot_color_families()
