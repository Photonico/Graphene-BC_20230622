# %% [markdown]
# # Lattice
#
# Total energy versus lattice constant

# %% [markdown]
# ## Results
#
# ### Solo layer
#
# * BC₃
#   * Most stable Lattice constant: 5.169 Angstrom
#   * Minimal free energy: -67.90772214 eV
#   * B-C bond: 1.563 Angstrom
#   * C-C bond: 1.421 Angstrom
#
# * Borophene
#   * Most stable Lattice constant: 5.051 Angstrom
#   * Minimal free energy: -51.13821750 eV
#   * B-B bond: 1.689×4, 1.707×1, 1.672×2 Angstrom
#
# * B₄C₃
#   * Most stable Lattice constant: 4.690 Angstrom
#   * Minimal free energy: -52.83670482 eV
#   * B-B bond: 1.689×1 Angstrom
#   * B-C bond: 1.548×1, 1.592×2 Angstrom
#
# * Graphene
#   * Most stable Lattice constant: 2.467 Angstrom
#   * Minimal free energy: -74.52125928 eV
#   * C-C bond: 1.424 Angstrom
#
# ### Graphene - BC₃
#
# * Top (shift 0)
#   * Most stable Lattice constant: 5.044 (Å)
#   * Most stable distance:
#   * Minimal free energy: -142.27484692 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge (shift 1/12)
#   * Most stable Lattice constant: 5.044(Å)
#   * Most stable distance:
#   * Minimal free energy: -142.29046554 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow (shift 1/6)
#   * Most stable Lattice constant: 5.044(Å)
#   * Most stable distance:
#   * Minimal free energy: -142.2925088 (eV)
#   * B-C bond:
#   * C-C bond:
#
# ### Graphene - Borophene
#
# * Top  (shift 0)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.92712719 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge  (shift 1/12)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.92124473 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow1  (shift 1/9)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.91420009(eV).
#   * B-C bond:
#   * C-C bond:
#
# * Hollow2  (shift 1/6)
#   * Most stable Lattice constant: 4.979 (Å)
#   * Most stable distance:
#   * Minimal free energy: -125.90933841(eV).
#   * B-C bond:
#   * C-C bond:
#
# ### Graphene - B₄C₃
#
# * Top (shift -1/6)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.1380817 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Bridge (shift -1/12)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.13482934 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow1 (shift -1/18)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.13283516 (eV)
#   * B-C bond:
#   * C-C bond:
#
# * Hollow2 (shift 0)
#   * Most stable Lattice constant: 4.846 (Å)
#   * Most stable distance:
#   * Minimal free energy: -127.12438981 (eV)
#   * B-C bond:
#   * C-C bond:

# %%
# BC3

from Store.lattice_free_energy import plot_lattice_free_energy_solo, plot_lattice_free_energy

# plot_lattice_free_energy_solo("BC₃", "0_Lattice/A_BC3/lattice_free_energy.dat", "blue", 11, "0_Lattice/selected/A_BC3_a5.169")
plot_lattice_free_energy(1, "BC₃", "0_Lattice/A_BC3/lattice_free_energy.dat", "blue", 11)
# plot_lattice_free_energy(1, "BC₃", "0_Lattice/A_BC3/lattice_free_energy.dat", "blue", 11)

# %%
# Borophene

plot_lattice_free_energy_solo("Borophene", "0_Lattice/B_Borophene/lattice_free_energy.dat", "green", 11, "0_Lattice/selected/B_Borophene_a5.051")

# %%
# B₄C₃

plot_lattice_free_energy_solo("B₄C₃", "0_Lattice/C_B4C3/lattice_free_energy.dat", "violet", 11, "0_Lattice/selected/C_B4C3_a4.690")

# %%
# Graphene

from Store.lattice_free_energy import summarize_free_energy_directory

summarize_free_energy_directory("0_Lattice/D_Graphene")

plot_lattice_free_energy_solo("Graphene", "0_Lattice/D_Graphene/lattice_free_energy.dat", "grey", 11, "0_Lattice/selected/D_Graphene_a2.467")

# %%
# Graphene (Full size)

from Store.lattice_free_energy import summarize_free_energy_directory

summarize_free_energy_directory("0_Lattice/D_Graphene_fullsize")

plot_lattice_free_energy_solo("Graphene", "0_Lattice/D_Graphene_fullsize/lattice_free_energy.dat", "red", 11, "0_Lattice/selected/D_Graphene_fullsize_a2.467")
