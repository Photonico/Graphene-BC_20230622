# %% [markdown]
# # Work checking

# %%
# Check VASP work

from vmatplot.output import vasprun_directory, plot_color_families

Dir = "1_Self_Consistent"

vasprun_directory(Dir)
# Out:
# ['1_Self_Consistent/A_BC3_K17',
#  '1_Self_Consistent/B_Borophene_K17',
#  '1_Self_Consistent/C_B4C3_K17',
#  '1_Self_Consistent/D_Graphene_K33',
#  '1_Self_Consistent/E_Graphene-BC3_Hollow_K17',
#  '1_Self_Consistent/F_Graphene-Borophene_Top_K17',
#  '1_Self_Consistent/G_Graphene-B4C3_Top_K17']

# %%
# Colors demo

plot_color_families()
