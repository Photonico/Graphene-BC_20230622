# %% [markdown]
# # Dielectric function algorithms
#
# Dielectric function versus Photon energy comparison between GGA-PBE and HSE06

# %%
# Prework

from vmatplot.dielectric_function_plotting import plot_dielectric_function_XZ_block

import matplotlib.pyplot as plt

# %%
# Graphene-B₄C₃ (Top): comparse between GGA-PBE and HSE06

dielectric_list = [["(GGA-PBE)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "blue"],
                   ["(HSE06)", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top) comparison GGA-PBE and HSE06", dielectric_list, 6, 24)

plt.savefig("Figures/S5.3_dielectric_PBE_and_HSE.pdf")
