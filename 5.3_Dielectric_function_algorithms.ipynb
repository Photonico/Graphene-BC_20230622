# %% [markdown]
# # Dielectric function algorithms
#
# Dielectric function versus Photon energy comparison between GGA-PBE and HSE06

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block

dielectric_list = [["(PBE 17 Kpoints)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "red"],
                   ["(PBE 25 Kpoints Normal)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K25_Normal", "orange"],
                   ["(PBE 25 Kpoints Exact)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K25", "yellow"],
                   ["(PBE 33 Kpoints Normal)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K33", "green"],
                   ["(HSE06)", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "wine"]]

plot_dielectric_function_XZ_block("Graphene-B₄C₃ (Top)", dielectric_list, 6, 24)
