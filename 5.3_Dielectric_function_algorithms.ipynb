# %% [markdown]
# # Dielectric function algorithms
#
# Dielectric function versus Photon energy comparison between GGA-PBE and HSE06

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["(PBE)", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                   ["(HSE06)", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "yellow"]]

# dielectric_list = [["(PBE)", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "blue"]]

plot_dielectric_function_XZ("Graphene-B₄C₃ (Top)", dielectric_list, 6, 24)
