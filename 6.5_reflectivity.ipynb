# %% [markdown]
# # Reflectivity
#
# We define the Reflectivity of a system as:
#
# $$ R(\omega)=\frac{(n-1)^2+k^2}{(n+1)^2+k^2} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $n$ is refractive index;
#
# $k$ is extinction coefficient.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.reflectivity import plot_reflectivity_XZ

import matplotlib.pyplot as plt

# %%
# Reflectivity comparison GGA-PBE and HSE06

matters_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                ["HSE06", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_reflectivity_XZ("for Graphene-B₄C₃ comparison GGA-PBE and HSE06", matters_list, "eV", 40, 40, (4,12), (4,12))

# plot_reflectivity_XZ("for Graphene-B₄C₃ comparison GGA-PBE and HSE06", matters_list, "nm", 200, 200, 50, 50)

# %%
# Reflectivity coefficient in eV

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_reflectivity_XZ("", matters_list, "eV", 40, 40, (0.88, 10.16), (0.88, 10.16))

plt.savefig("Figures/6.5_reflectivity_coefficient.pdf")

# %%
# Reflectivity coefficient in nm

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_reflectivity_XZ("", matters_list, "nm", 1000, 200, 400, 100)
