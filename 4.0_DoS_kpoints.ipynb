# %% [markdown]
# # DoS kpoints
#
# Electronic density of state versus energy in different kpoints

# %%
# Prework

from vmatplot.DoS import plot_dos

alpha = 0.4
solid = 1.0

# %%
# Graphene-BC₃ PBE

matters_dir = [["(PBE 17 kpoints)", "4_PDoS/G_Graphene-B4C3_Top_PBE_K17", "grey",   solid],
               ["(PBE 25 kpoints)", "4_PDoS/G_Graphene-B4C3_Top_PBE_K25", "blue",   solid],
               ["(PBE 33 kpoints)", "4_PDoS/G_Graphene-B4C3_Top_PBE_K33", "violet", solid],
               ["(HSE06 33 kpoints)", "4_PDoS/G_Graphene-B4C3_Top_HSE", "orange",   solid]]

plot_dos("for Graphene-B₄C₃ (Top) with PBE", 6, 10, "total", matters_dir)
