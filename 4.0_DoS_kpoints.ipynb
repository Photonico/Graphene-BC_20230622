# %% [markdown]
# # DoS verse kpoints
#
# Electronic density of state versus energy in different kpoints

# %%
# Prework

from vmatplot.DoS import plot_dos
import matplotlib.pyplot as plt

alpha = 0.4
solid = 1.0

# %%
# Graphene-BC₃ PBE

matters_dir = [["(PBE 17 kpoints)", "4_PDoS/G_Graphene-B4C3_PBE_K17", "grey",   solid],
               ["(PBE 25 kpoints)", "4_PDoS/G_Graphene-B4C3_PBE_K25", "blue",   solid],
               ["(PBE 33 kpoints)", "4_PDoS/G_Graphene-B4C3_PBE_K33", "violet", solid],
               ["(HSE06 33 kpoints)", "4_PDoS/G_Graphene-B4C3_HSE", "orange",   solid]]

plot_dos("for Graphene-B₄C₃ (Top) by GGA-PBE", 6, 10, "total", matters_dir)

plt.savefig("Figures/4.0_DoS_in_kpoints.pdf")
