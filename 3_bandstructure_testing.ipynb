# %%
# Monolayer BC₃ GGA-PBE

from vmatplot.bandstructure_plotting import plot_bandstructure
from vmatplot.bandgap import extract_bandgap_outcar

system_PBE = "Monolayer BC₃ (PBE)"; gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/A_BC3")

bandstructure_list = [["bands", "PBE", "3_Bandstructure_PBE/A_BC3/", "orbital"]]

plot_bandstructure("BC₃", 6, bandstructure_list, "upper right")

# %%
# Monolayer BC₃ HSE06 Testing

from vmatplot.bandstructure import *

PBE_dir = "3_Bandstructure_PBE/A_BC3"
HSE_dir = "3_Bandstructure_HSE06/A_BC3"

# print(len(extract_highsym(PBE_dir)))
# print(len(extract_highsym(HSE_dir)))

# print(extract_kpoints_count(PBE_dir))
# print(extract_kpoints_count(HSE_dir))

# print(len(extract_eigenvalues_kpoints(PBE_dir,"spin 1")))
# print(len(extract_eigenvalues_kpoints(HSE_dir,"spin 1")))

# Monolayer BC₃ HSE06

from vmatplot.bandstructure_plotting import plot_bandstructure
from vmatplot.bandgap import extract_bandgap_outcar

system_PBE = "Monolayer BC₃ (HSE06)"; gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/A_BC3")

bandstructure_list = [["bands", "HSE", "3_Bandstructure_HSE06/A_BC3/", "violet"]]

plot_bandstructure("BC₃", 6, bandstructure_list, "upper right")
