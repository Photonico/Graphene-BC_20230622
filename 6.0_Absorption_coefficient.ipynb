# %% [markdown]
# # Absorption coefficient
#
# We define the absorption coefficient of a system as
#
# $$ I(\omega) = \sqrt{2}\omega[\sqrt{\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)}-\varepsilon_R(\omega)] $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.

# %%
# Prework

from vmatplot.absorption_coefficient import plot_absorption_XZ_col

# %%
# Graphene-BC₃ (Hollow)

# %%
# Graphene-Borophene (Top)

# %%
# Graphene-B₄C₃ (Top)

absorption_list = [["PBE", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"]]

plot_absorption_XZ_col("Graphene-B₄C₃ (Top)", absorption_list,800,200)
