# %% [markdown]
# # Lattice plotting
#
# Total energy versus lattice constant
#
# ## Article information
#
# Title: Electronic and optical properties of Graphene-Boron-based bilayers: BC3, Borophene, B4C3

# %%
# Prework

from vmatplot.lattice_plotting import plot_free_energy_lattice

# %%
# BC₃

lattice_list = [[None,"0_Lattice/A_BC3/free_energy_lattice.dat", "0_Lattice_Reference/A_BC3", "blue", 11]]

plot_free_energy_lattice("BC₃", lattice_list)

# %%
# Borophene

lattice_list = [[None,"0_Lattice/B_Borophene/free_energy_lattice.dat", "0_Lattice_Reference/B_Borophene_2", "green", 11]]

plot_free_energy_lattice("Borophene", lattice_list)

# %%
# B₄C₃

# plot_free_energy_lattice(1, "B₄C₃", 11, "0_Lattice/C_B4C3/lattice_free_energy.dat", "violet")
lattice_list = [[None,"0_Lattice/C_B4C3/free_energy_lattice.dat", "0_Lattice_Reference/C_B4C3", "violet", 11]]

plot_free_energy_lattice("B₄C₃", lattice_list)

# %%
# Graphene

# plot_free_energy_lattice(1, "Graphene", 11, "0_Lattice/D_Graphene/lattice_free_energy.dat", "grey")

lattice_list = [[None,"0_Lattice/D_Graphene/free_energy_lattice.dat", "0_Lattice_Reference/D_Graphene", "grey", 11]]

plot_free_energy_lattice("Graphene", lattice_list)

# %%
# Graphene-BC₃

# plot_lattice_free_energy(3, "Graphene-BC₃", 11,
#                          "Top", "0_Lattice/E_Graphene-BC3_Top/lattice_free_energy.dat", "blue", 
#                          "Bridge", "0_Lattice/E_Graphene-BC3_Bridge/lattice_free_energy.dat", "green",
#                          "Hollow", "0_Lattice/E_Graphene-BC3_Hollow/lattice_free_energy.dat", "violet",
#                          )

lattice_list = [["Top","0_Lattice/E_Graphene-BC3_Top/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Top", "blue", 11],
                ["Bridge","0_Lattice/E_Graphene-BC3_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Bridge", "green", 11],
                ["Hollow","0_Lattice/E_Graphene-BC3_Hollow/free_energy_lattice.dat", "0_Lattice_Reference/E_Graphene-BC3_Hollow", "violet", 11]]

plot_free_energy_lattice("Graphene-BC₃", lattice_list)

# %%
# Graphene-Borophene

lattice_list = [["Top","0_Lattice/F_Graphene-Borophene_Top/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Top", "blue", 11],
                ["Bridge","0_Lattice/F_Graphene-Borophene_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Bridge", "green", 11],
                ["Hollow 1","0_Lattice/F_Graphene-Borophene_Hollow1/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Hollow1", "violet", 11],
                ["Hollow 2","0_Lattice/F_Graphene-Borophene_Hollow2/free_energy_lattice.dat", "0_Lattice_Reference/F_Graphene-Borophene_Hollow2", "wine", 11]]

plot_free_energy_lattice("Graphene-Borophene", lattice_list)

# %%
# Graphene-B₄C₃

# plot_lattice_free_energy(4, "Graphene-B₄C₃", 11,
#                          "Top", "0_Lattice/G_Graphene-B4C3_Top/lattice_free_energy.dat", "blue", 
#                          "Bridge", "0_Lattice/G_Graphene-B4C3_Bridge/lattice_free_energy.dat", "green",
#                          "Hollow 1", "0_Lattice/G_Graphene-B4C3_Hollow1/lattice_free_energy.dat", "violet",
#                          "Hollow 2", "0_Lattice/G_Graphene-B4C3_Hollow2/lattice_free_energy.dat", "purple",
#                          )

lattice_list = [["Top","0_Lattice/G_Graphene-B4C3_Top/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Top", "blue", 11],
                ["Bridge","0_Lattice/G_Graphene-B4C3_Bridge/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Bridge", "green", 11],
                ["Hollow 1","0_Lattice/G_Graphene-B4C3_Hollow1/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Hollow1", "violet", 11],
                ["Hollow 2","0_Lattice/G_Graphene-B4C3_Hollow2/free_energy_lattice.dat", "0_Lattice_Reference/G_Graphene-B4C3_Hollow2", "wine", 11]]

plot_free_energy_lattice("Graphene-B₄C₃", lattice_list)
