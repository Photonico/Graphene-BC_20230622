# %% [markdown]
# # Bandgap

# %%
from vmatplot.bandgap import *

# Monolayer: BC₃

system_PBE = "Monolayer BC₃ (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/A_BC3")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")

print(gap_PBE)
# Out:
# Matter: Monolayer BC₃ (PBE)
# LUMO band: -3.157700;
# HOMO band: -3.791800;
# Band gap: 0.634100.
# (0.6340999999999997, -3.7918, -3.1577)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/lu/Repos/Graphene-BC 2023/3_bandgap.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandgap.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> print(f"Band gap: {gap_PBE[0]:.6f}.")
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandgap.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> print(gap_PBE)
# ---> <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandgap.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> gap_PBE_v = extract_bandgap("3_Bandstructure_PBE/A_BC3")
#      <a href='vscode-notebook-cell:/home/lu/Repos/Graphene-BC%202023/3_bandgap.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> print(gap_PBE_v)
#
# File ~/Repos/Graphene-BC 2023/vmatplot/bandgap.py:67, in extract_bandgap(directory)
#      64 for eigenvalue in eigenvalue_set:
#      65     # Extract occupation and energy
#      66     fields = eigenvalue.text.strip().split()
# ---> 67     occupation = float(fields[1])
#      68     energy = float(fields[0])
#      70     # Update valence band maximum and conduction band minimum
#
# IndexError: list index out of range

# %%
# Monolayer: Borophene

system_PBE = "Monolayer Borophene (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/B_Borophene")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Monolayer Borophene (PBE)
# LUMO band: -2.286900;
# HOMO band: -1.730100;
# Band gap: -0.556800.

# %%
# Monolayer: B4C3

system_PBE = "Monolayer B₄C₃ (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/C_B4C3")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Monolayer B₄C₃ (PBE)
# LUMO band: -1.209400;
# HOMO band: -2.855900;
# Band gap: 1.646500.

# %%
# Monolayer: Graphene

system_PBE = "Monolayer Graphene (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/D_Graphene")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Monolayer Graphene (PBE)
# LUMO band: -2.243900;
# HOMO band: -2.262400;
# Band gap: 0.018500.

# %%
# Bilayer: Graphene - BC₃ Hollow

system_PBE = "Bilayer Graphene-BC₃ Hollow (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/E_Graphene-BC3_Hollow")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene-BC₃ Hollow (PBE)
# LUMO band: -0.925600;
# HOMO band: -0.928400;
# Band gap: 0.002800.

# %%
# Bilayer: Graphene - Borophene Top

system_PBE = "Bilayer Graphene-Borophene Top (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/F_Graphene-Borophene_Top")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene-Borophene Top (PBE)
# LUMO band: -0.511000;
# HOMO band: -0.310900;
# Band gap: -0.200100.

# %%
# Bilayer: Graphene - B₄C₃ Top

system_PBE = "Bilayer Graphene-B₄C₃ Top (PBE)"
gap_PBE = extract_bandgap_outcar("3_Bandstructure_PBE/G_Graphene-B4C3_Top")

print(f"Matter: {system_PBE}")
print(f"LUMO band: {gap_PBE[2]:.6f};")
print(f"HOMO band: {gap_PBE[1]:.6f};")
print(f"Band gap: {gap_PBE[0]:.6f}.")
# Out:
# Matter: Bilayer Graphene-B₄C₃ Top (PBE)
# LUMO band: -0.314600;
# HOMO band: -0.331300;
# Band gap: 0.016700.
