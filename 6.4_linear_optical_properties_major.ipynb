# %% [markdown]
# # Linear optical properties for each component
#
#
# * Absorption coefficient
#   * title: "Absorption coefficient"
#   * label: "absorption"
#
# * Refractive index
#   * title: "Refractive index"
#   * label: "refractive"
#
# * Extinction coefficient
#   * title: "Extinction coefficient"
#   * label: "extinction"
#
# * Reflectivity
#   * title: "Reflectivity"
#   * label: "reflectivity"
#
# * Energy-loss spectrum
#   * title: "Energy-loss spectrum"
#   * label: "energy-loss"

# %%
# prework

from vmatplot.linear_optical_properties import plot_linear_optical_property

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"}, {"zz":"out-of-plane"}]
# components = [{"xx":"in-plane"}, "yy", {"zz":"out-of-plane"}, "xy", "yz", "zx", "yx","zy","xz"]

boundary = 24
layout = "hor"

systems_PBE = [["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
               ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
               ["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"]]

systems_HSE = [["Graphene-BC₃ (17 k-points)", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "blue"],
               ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "green"],
               ["Graphene-B₄C₃ (17 k-points)", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "violet"]]

# %%
# Absorption coefficient by GGA-PBE

plot_linear_optical_property("for bilayers by GGA-PBE", systems_PBE, "absorption", components, layout, "eV", boundary)

plt.savefig("Figures/6.31_absorption_bilayer_PBE.pdf")

# %%
# Absorption coefficient by HSE06

plot_linear_optical_property("for bilayers by HSE06", systems_HSE, "absorption", components, layout, "eV", boundary)

plt.savefig("Figures/6.31_absorption_bilayer_HSE.pdf")

# %%
# Refractive index by GGA-PBE

plot_linear_optical_property("for bilayers by GGA-PBE", systems_PBE, "refractive", components, layout, "eV", boundary)

plt.savefig("Figures/6.32_refractive_bilayer_PBE.pdf")

# %%
# Refractive index by HSE06

plot_linear_optical_property("for bilayers by HSE06", systems_HSE, "refractive", components, layout, "eV", boundary)

plt.savefig("Figures/6.32_refractive_bilayer_HSE.pdf")

# %%
# Extinction coefficient by GGA-PBE

plot_linear_optical_property("for bilayers by GGA-PBE", systems_PBE, "extinction", components, layout, "eV", boundary)

plt.savefig("Figures/6.33_extinction_bilayer_PBE.pdf")

# %%
# Extinction coefficient by HSE06

plot_linear_optical_property("for bilayers by HSE06", systems_HSE, "extinction", components, layout, "eV", boundary)

plt.savefig("Figures/6.33_extinction_bilayer_HSE.pdf")

# %%
# Reflectivity by GGA-PBE

plot_linear_optical_property("for bilayers by GGA-PBE", systems_PBE, "reflectivity", components, layout, "eV", boundary)

plt.savefig("Figures/6.34_reflectivity_bilayer_PBE.pdf")

# %%
# Reflectivity by HSE06

plot_linear_optical_property("for bilayers by HSE06", systems_HSE, "reflectivity", components, layout, "eV", boundary)

plt.savefig("Figures/6.34_reflectivity_bilayer_HSE.pdf")

# %%
# Energy-loss spectrum by GGA-PBE

plot_linear_optical_property("for bilayers by GGA-PBE", systems_PBE, "energy-loss", components, layout, "eV", boundary)

plt.savefig("Figures/6.35_energy-loss_bilayer_PBE.pdf")

# %%
# Energy-loss spectrum by HSE06

plot_linear_optical_property("for bilayers by HSE06", systems_HSE, "energy-loss", components, layout, "eV", boundary)

plt.savefig("Figures/6.35_energy-loss_bilayer_HSE.pdf")
