# %% [markdown]
# # Kpoints
#
# Free energy versus kpoints constant

# %%
#### 1.1 Single layer - BC3

## Read data
import numpy as np
from Store.kpoints_extracting import read_kpoints

start = 9
end = 61

kpoints, free_energy = read_kpoints("1_Kpoints/Single_BC3/Kpoints.dat")
kpoints = kpoints[int((start-1)/2):]
free_energy = free_energy[int((start-1)/2):]

## Source data specific features
free_energy_min = np.min(free_energy)
min_kpoints = kpoints[np.argmin(free_energy)]
free_energy_scale = np.max(free_energy)-np.min(free_energy)

## Plot
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

plt.figure(dpi=256, figsize=(10,6))
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)
plt.tick_params(direction="in", which="both", top=True, right=True, bottom=True, left=True)
plt.title("Free energy versus kpoints for BC₃"); plt.xlabel(r"K-points"); plt.ylabel(r"Energy (eV)")

plt.scatter(kpoints, free_energy, color="#1473D2", label="Source data", zorder=1)

formatter = ScalarFormatter(useMathText=True, useOffset=False)
plt.gca().yaxis.set_major_formatter(formatter)

plt.ticklabel_format(style="sci", axis="y", scilimits=(-3,3))

plt.xlim(start-2, end+2)
plt.xticks(np.arange(start, end+2, 2))
plt.ylim(np.min(free_energy)-free_energy_scale*0.2, np.max(free_energy)+free_energy_scale*0.2)

plt.legend(loc="best")

# %%
#### 1A Double layers Graphene - BC3: Hollow

## Read data
import numpy as np
from Store.kpoints_extracting import read_kpoints

start = 3
end = 61

kpoints, free_energy = read_kpoints("1_Kpoints/Twin_Graphene_BC3_Hollow/Kpoints.dat")
kpoints = kpoints[int((start-1)/2):]
free_energy = free_energy[int((start-1)/2):]

## Source data specific features
free_energy_min = np.min(free_energy)
min_kpoints = kpoints[np.argmin(free_energy)]
free_energy_scale = np.max(free_energy)-np.min(free_energy)

## Plot
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

plt.figure(dpi=256, figsize=(10,6))
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)
plt.tick_params(direction="in", which="both", top=True, right=True, bottom=True, left=True)
plt.title("Free energy versus kpoints for Graphene-BC₃"); plt.xlabel(r"K-points"); plt.ylabel(r"Energy (eV)")

plt.scatter(kpoints, free_energy, color="#1473D2", label="Source data", zorder=1)

formatter = ScalarFormatter(useMathText=True, useOffset=False)
plt.gca().yaxis.set_major_formatter(formatter)

plt.ticklabel_format(style="sci", axis="y", scilimits=(-3,3))

plt.xlim(start-2, end+2)
plt.xticks(np.arange(start, end+2, 2))
plt.ylim(np.min(free_energy)-free_energy_scale*0.2, np.max(free_energy)+free_energy_scale*0.2)

plt.legend(loc="best")
