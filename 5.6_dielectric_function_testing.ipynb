# %%
# components = {"xx":"in-plane","zz":"out-of-plane"}


from vmatplot.dielectric_function import plot_dielectric_function
# from vmatplot.dielectric_function import plot_dielectric_function_rescaled

# components = {"xx":"in-plane"}
components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]
# components = ["xx","zz","xz"]

layout = "hor"

boundary = (24,8)
boundary = (8,24)
boundary = 24

monolayers = [["for BC₃", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
              ["for Borophene", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
              ["for B₄C₃", "5_Dielectric_function/C_B4C3_PBE_K65","violet"]]

plot_dielectric_function("for Testing", monolayers, components, layout, False, "eV", boundary)

# plot_dielectric_function_rescaled("for Testing", monolayers, components, layout,"eV", boundary)
