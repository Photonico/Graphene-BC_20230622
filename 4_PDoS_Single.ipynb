# %% [markdown]
# # PDOS for single layer matters
#
# Projected electronic density of state versus energy

# %%
#### Single layer: BC3 PBE

from Store.PDOS_extracting import pdos_total_extracting, pdos_element_extracting
from Store.PDOS_plotting import pdos_element_plotting

pdos_BC3_total = pdos_total_extracting("4_PDOS_PBE/A_BC3_K11/vasprun.xml")
pdos_BC3_B = pdos_element_extracting("4_PDOS_PBE/A_BC3_K11/vasprun.xml","B")
pdos_BC3_C = pdos_element_extracting("4_PDOS_PBE/A_BC3_K11/vasprun.xml","C")
pdos_element_plotting("BC₃", pdos_BC3_total, "Boron", pdos_BC3_B, "Carbon", pdos_BC3_C, 6, 12, "PBE")

# %%
#### Single layer: Borophene PBE

from Store.PDOS_extracting import pdos_total_extracting, pdos_element_extracting
from Store.PDOS_plotting import pdos_element_plotting

pdos_Borophene_total = pdos_total_extracting("4_PDOS_PBE/B_Borophene/vasprun.xml")
pdos_Borophene_B = pdos_element_extracting("4_PDOS_PBE/B_Borophene/vasprun.xml","B")
pdos_element_plotting("Borophene", pdos_Borophene_total, "Boron", pdos_Borophene_B, 6, 12, "PBE")

# %%
#### Single layer: B4C3 PBE

from Store.PDOS_extracting import pdos_total_extracting, pdos_element_extracting
from Store.PDOS_plotting import pdos_element_plotting

pdos_B4C3_total = pdos_total_extracting("4_PDOS_PBE/C_B4C3/vasprun.xml")
pdos_B4C3_B = pdos_element_extracting("4_PDOS_PBE/C_B4C3/vasprun.xml","B")
pdos_B4C3_C = pdos_element_extracting("4_PDOS_PBE/C_B4C3/vasprun.xml","C")
pdos_element_plotting("B₄C₃", pdos_B4C3_total, "Boron", pdos_B4C3_B, "Carbon", pdos_B4C3_C, 6, 12, "PBE")

# %%
#### Single layer: Graphene PBE

from Store.PDOS_extracting import pdos_total_extracting, pdos_element_extracting
from Store.PDOS_plotting import pdos_element_plotting

pdos_Graphene_total = pdos_total_extracting("4_PDOS_PBE/D_Graphene/vasprun.xml")
pdos_Graphene_C = pdos_element_extracting("4_PDOS_PBE/D_Graphene/vasprun.xml","C")
pdos_element_plotting("Graphene", pdos_Graphene_total, "Carbon", pdos_Graphene_C, 6, 2, "PBE")
