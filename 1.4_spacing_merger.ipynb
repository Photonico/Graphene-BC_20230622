# %% [markdown]
# # Interlayer spacing
#
# Free energy versus lattice constant and interlayer spacing for bilayers

# %%
# Prework

from vmatplot.lattice_bilayer import plot_bilayer_lattice

import matplotlib.pyplot as plt

# %%
# Graphene-BC₃

plot_bilayer_lattice(3, "for Graphene-BC₃",
                     ["Bridge","0_Lattice_Distance/E_Graphene-BC3_bridge/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/E_Graphene-BC3_bridge"],
                     ["Hollow","0_Lattice_Distance/E_Graphene-BC3_hollow/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/E_Graphene-BC3_hollow"],
                     ["Top","0_Lattice_Distance/E_Graphene-BC3_top/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/E_Graphene-BC3_top"])

# plt.savefig("Figures/1.41_spacing_Graphene-BC3.svg")

# %%
# Graphene-Borophene

plot_bilayer_lattice(3, "for Graphene-Borophene",
                     ["Bridge","0_Lattice_Distance/F_Graphene-Borophene_bridge/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_bridge"],
                     ["Hollow 1","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_hollow1"],
                     ["Hollow 2","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_hollow1"],
                     ["Top","0_Lattice_Distance/F_Graphene-Borophene_top/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_top"])

# plt.savefig("Figures/1.42_spacing_Graphene-Borophene.svg")

# %%
# Graphene-B4C3

plot_bilayer_lattice(3, "for Graphene-B₄C₃",
                     ["Bridge","0_Lattice_Distance/F_Graphene-Borophene_bridge/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_bridge"],
                     ["Hollow 1","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_hollow1"],
                     ["Hollow 2","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_hollow1"],
                     ["Top","0_Lattice_Distance/F_Graphene-Borophene_top/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/F_Graphene-Borophene_top"])

# plt.savefig("Figures/1.43_spacing_Graphene-B4C3.svg")

# %%
# Ideal sets

plot_bilayer_lattice(3, "",
                     ["Graphene-BC₃","0_Lattice_Distance/E_Graphene-BC3_hollow/lattice_distance.dat", "Blues_r", "blue", "0_Lattice_Reference/E_Graphene-BC3_hollow"],
                     ["Graphene-Borophene","0_Lattice_Distance/F_Graphene-Borophene_top/lattice_distance.dat", "Greens_r", "green", "0_Lattice_Reference/F_Graphene-Borophene_top"],
                     ["Graphene-B₄C₃","0_Lattice_Distance/G_Graphene-B4C3_top/lattice_distance.dat", "Purples_r", "violet", "0_Lattice_Reference/G_Graphene-B4C3_top"])

# plt.savefig("Figures/1.44_spacing_ideal_bilayers.pdf")
