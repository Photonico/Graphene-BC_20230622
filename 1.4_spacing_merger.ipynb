# %% [markdown]
# # Interlayer spacing
#
# Free energy versus lattice constant and interlayer spacing for bilayers

# %%
# Prework

from vmatplot.lattice_bilayer import specify_bilayer_lattice, plot_bilayer_lattice
import matplotlib.pyplot as plt

selected_G_BC3 = specify_bilayer_lattice("0_Lattice_Reference/E_Graphene-BC3_Hollow")
selected_G_Borophene = specify_bilayer_lattice("0_Lattice_Reference/F_Graphene-Borophene_Top")
selected_G_B4C3 = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")
selected_G_B4C3_re = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")


plot_bilayer_lattice(2, "Suptitle",
                     "0_Lattice_Distance/E_Graphene-BC3_Hollow/lattice_distance.dat", "0_Lattice_Distance/F_Graphene-Borophene_Top/lattice_distance.dat", 
                     "subtitle 1", "subtitle 2",
                     "Blues_r", "Oranges_r",
                     "blue", "orange",
                     "0_Lattice_Reference/E_Graphene-BC3_Hollow", "0_Lattice_Reference/F_Graphene-Borophene_Top")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       8 selected_G_B4C3 = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")
#       9 selected_G_B4C3_re = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")
# ---> 12 plot_bilayer_lattice(2, "Suptitle",
#      13                      "0_Lattice_Distance/E_Graphene-BC3_Hollow/lattice_distance.dat", "0_Lattice_Distance/F_Graphene-Borophene_Top/lattice_distance.dat",
#      14                      "subtitle 1", "subtitle 2",
#      15                      "Blues_r", "Oranges_r",
#      16                      "blue", "orange",
#      17                      "0_Lattice_Reference/E_Graphene-BC3_Hollow", "0_Lattice_Reference/F_Graphene-Borophene_Top")
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\lattice_bilayer.py:422, in plot_bilayer_lattice(subfigures_amount, *args)
#     420     return plot_bilayer_lattice_single(*args)
#     421 elif subfigures_amount == 2:
# --> 422     return plot_bilayer_lattice_double(*args)
#     423 elif subfigures_amount == 3:
#     424     return plot_bilayer_lattice_triple(*args)
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\lattice_bilayer.py:348, in plot_bilayer_lattice_double(suptitle, source_data_1, source_data_2, subtitle_1, subtitle_2, colormap_1, colormap_2, point_color_1, point_color_2, additional_work_1, additional_work_2, legend_loc)
#     346 # Colormap
#     347 cp = ax.pcolormesh(lattice_grid_fine, distance_grid_fine, free_energy_grid_fine, shading="auto", cmap=colormap_set[supplot_index], alpha = 0.75, vmax = energy_demo, zorder=1)
# --> 348 cbar = ax.colorbar(cp)
#     349 formatter = ScalarFormatter(useMathText=True, useOffset=False)
#     350 formatter.set_powerlimits((-3, 3))
#
# AttributeError: 'Axes' object has no attribute 'colorbar'
