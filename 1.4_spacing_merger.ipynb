# %% [markdown]
# # Interlayer spacing
#
# Free energy versus lattice constant and interlayer spacing for bilayers

# %%
# Prework

# from vmatplot.lattice_bilayer import specify_bilayer_lattice, plot_bilayer_lattice_double, plot_bilayer_lattice_double
# import matplotlib.pyplot as plt
from vmatplot.lattice_bilayer import *

selected_G_BC3 = specify_bilayer_lattice("0_Lattice_Reference/E_Graphene-BC3_Hollow")
selected_G_Borophene = specify_bilayer_lattice("0_Lattice_Reference/F_Graphene-Borophene_Top")
selected_G_B4C3 = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")
selected_G_B4C3_re = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")

# plot_bilayer_lattice_double("",
#                      "0_Lattice_Distance/E_Graphene-BC3_Hollow/lattice_distance.dat",
#                      "0_Lattice_Distance/F_Graphene-Borophene_Top/lattice_distance.dat", 
#                      "Graphene-BC₃", "Graphene-Borophene",
#                      "Blues_r", "Oranges_r",
#                      "blue", "orange",
#                      "0_Lattice_Reference/E_Graphene-BC3_Hollow",
#                      "0_Lattice_Reference/F_Graphene-Borophene_Top"
#                      )

plot_bilayer_lattice_triple_row("",
                     "0_Lattice_Distance/E_Graphene-BC3_Hollow/lattice_distance.dat",
                     "0_Lattice_Distance/F_Graphene-Borophene_Top/lattice_distance.dat", 
                     "0_Lattice_Distance/G_Graphene-B4C3_Top/lattice_distance.dat", 
                     "Graphene-BC₃", "Graphene-Borophene","Graphene-B₄C₃",
                     "Blues_r", "Oranges_r","Purples_r",
                     "blue", "orange","purple",
                     "0_Lattice_Reference/E_Graphene-BC3_Hollow",
                     "0_Lattice_Reference/F_Graphene-Borophene_Top",
                     "0_Lattice_Reference/G_Graphene-B4C3_Top"
                     )
