# %% [markdown]
# # Interlayer spacing
#
# Free energy versus lattice constant and interlayer spacing for bilayers

# %%
# Prework

from vmatplot.lattice_bilayer import plot_bilayer_lattice

import matplotlib.pyplot as plt

# %%
# Graphene-BC₃

plot_bilayer_lattice(3, "for Graphene-BC₃",
                     ["Bridge","0_Lattice_Distance/E_Graphene-BC3_bridge/lattice_distance.dat", "Blues_r", "blue", None],
                     ["Hollow","0_Lattice_Distance/E_Graphene-BC3_hollow/lattice_distance.dat", "Blues_r", "blue", None],
                     ["Top","0_Lattice_Distance/E_Graphene-BC3_top/lattice_distance.dat", "Blues_r", "blue", None])

# plt.savefig("Figures/1.41_spacing_Graphene-BC3.svg")

# %%
# Graphene-Borophene

plot_bilayer_lattice(4, "for Graphene-Borophene",
                     ["Bridge","0_Lattice_Distance/F_Graphene-Borophene_bridge/lattice_distance.dat", "Greens_r", "green", None],
                     ["Hollow 1","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Greens_r", "green", None],
                     ["Hollow 2","0_Lattice_Distance/F_Graphene-Borophene_hollow1/lattice_distance.dat", "Greens_r", "green", None],
                     ["Top","0_Lattice_Distance/F_Graphene-Borophene_top/lattice_distance.dat", "Greens_r", "green", None])

# plt.savefig("Figures/1.42_spacing_Graphene-Borophene.svg")

# %%
# Graphene-B4C3

plot_bilayer_lattice(4, "for Graphene-B₄C₃",
                     ["Bridge","0_Lattice_Distance/G_Graphene-B4C3_bridge/lattice_distance.dat", "Purples_r", "violet", None],
                     ["Hollow 1","0_Lattice_Distance/G_Graphene-B4C3_hollow1/lattice_distance.dat", "Purples_r", "violet", None],
                     ["Hollow 2","0_Lattice_Distance/G_Graphene-B4C3_hollow1/lattice_distance.dat", "Purples_r", "violet", None],
                     ["Top","0_Lattice_Distance/G_Graphene-B4C3_top/lattice_distance.dat", "Purples_r", "violet", None])

# plt.savefig("Figures/1.43_spacing_Graphene-B4C3.svg")

# %%
# Ideal sets

plot_bilayer_lattice(3, "",
                     ["Graphene-BC₃","0_Lattice_Distance/E_Graphene-BC3_hollow/lattice_distance.dat", "Blues_r", "blue", None],
                     ["Graphene-Borophene","0_Lattice_Distance/F_Graphene-Borophene_top/lattice_distance.dat", "Greens_r", "green", None],
                     ["Graphene-B₄C₃","0_Lattice_Distance/G_Graphene-B4C3_top/lattice_distance.dat", "Purples_r", "violet", None])

# plt.savefig("Figures/1.44_spacing_ideal_bilayers.pdf")
