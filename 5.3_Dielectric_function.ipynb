# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
# Graphene-BC₃ (Hollow)

# %%
# Graphene-Borophene (Top)

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["PBE", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N128", "blue"],
                   ["HSE06", "5_Dielectric_function/G_Graphene_B4C3_Top_HSE_K03_N128", "yellow"]]

plot_dielectric_function_XZ("Graphene-B₄C₃ (Top)", dielectric_list, 24)
