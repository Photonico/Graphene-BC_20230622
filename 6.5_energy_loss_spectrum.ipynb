# %% [markdown]
# # Energy loss spectrum
#
# The energy loss spectrum is a measure of the energy loss experienced by electrons due to photon interactions within a system.
#
# We define the energy loss spectrum of a system as:
#
# $$ L(\omega) = \frac{\varepsilon_I(\omega)}{\varepsilon^2_R(\omega)+\varepsilon_I^2(\omega)} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.energy_loss_spectrum import plot_energy_loss_XXZZ

import matplotlib.pyplot as plt

# %%
# Energy loss spectrum for Graphene-BC₃

matters_list = [["GGA-PBE", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
                ["HSE06 17 k-points", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_energy_loss_XXZZ("for Graphene-BC₃", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Energy loss spectrum for Graphene-Borophene

matters_list = [["GGA-PBE", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
                ["HSE06", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_energy_loss_XXZZ("for Graphene-Borophene", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Energy loss spectrum for Graphene-B₄C₃

matters_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
                ["HSE06 17 k-points", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_energy_loss_XXZZ("for Graphene-B₄C₃", matters_list, "eV", 40, 40, (4,12), (4,12))
