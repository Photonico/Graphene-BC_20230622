# %% [markdown]
# # Dielectric Function versus components
#
# Dielectric function versus Photon energy in different components

# %%
# Prework

from vmatplot.dielectric_function import plot_dielectric_function

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"},{"zz":"out-of-plane"}]

layout = "hor"
boundary = 24

# %%
# BC3

systems = [["", "5_Dielectric_function/A_BC3_PBE_K65", "blue"]]

plot_dielectric_function("for BC₃", systems, components, layout, False, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.13a.pdf")

# %%
# Borophene

systems = [["", "5_Dielectric_function/B_Borophene_PBE_K65", "green"]]

plot_dielectric_function("for Borophene", systems, components, layout, False, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.13b.pdf")

# %%
# B4C3

systems = [["", "5_Dielectric_function/C_B4C3_PBE_K65", "violet"]]

plot_dielectric_function("for B₄C₃", systems, components, layout, False, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.13c.pdf")

# %%
# Graphene

systems = [["", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]

plot_dielectric_function("for Graphene", systems, components, layout, False, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.13d.pdf")
