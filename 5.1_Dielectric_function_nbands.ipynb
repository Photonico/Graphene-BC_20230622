# %% [markdown]
# # Dielectric Function versus NBANDS
#
# Dielectric function versus Photon energy in different NBANDS

# %%
# Prework

from vmatplot.dielectric_function import plot_dielectric_function

import matplotlib.pyplot as plt

# %%
# Graphene-B₄C₃ (Top)

dielectric_list = [["(32 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N32", "red",      "solid", 1.0, 3.2],
                   ["(64 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N64", "orange",   "solid", 1.0, 2.8],
                   ["(128 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128", "green",  "solid", 1.0, 2.4],
                   ["(256 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N256", "blue",   "solid", 1.0, 2.0],
                   ["(512 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N512", "purple", "solid", 1.0, 1.6]]

plot_dielectric_function("for Graphene-B₄C₃ by GGA-PBE", dielectric_list, [{"xx":"in-plane"},{"zz":"out-of-plane"}], "hor", True, "eV", 24)

plt.savefig("Figures/5.1_dielectric_nbands.pdf")
