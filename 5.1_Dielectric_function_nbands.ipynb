# %% [markdown]
# # Dielectric Function versus NBANDS
#
# Dielectric function versus Photon energy in different NBANDS

# %%
# Prework

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ_block

import matplotlib.pyplot as plt

# %%
# Graphene-B₄C₃ (Top)

dielectric_list = [["(32 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N32", "red",     1.0, 3.0],
                   ["(64 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N64", "orange",  1.0, 3.0],
                   ["(128 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128", "green",  1.0, 2.6],
                   ["(256 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N256", "blue",   1.0, 2.2],
                   ["(512 nbands)", "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N512", "violet", 1.0, 1.8]]

plot_dielectric_function_XZ_block("for Graphene-B₄C₃ (Top)", dielectric_list, 20, 40)

plt.savefig("Figures/S5.1_Dielectric_nbands.pdf")
