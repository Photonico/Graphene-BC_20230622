# %% [markdown]
# # Dielectric Function versus NBANDS
#
# Dielectric function versus Photon energy in different NBANDS

# %%
# Graphene-B₄C₃ (Top)

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XZ

dielectric_list = [["nbands 32", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N32", "red",     1.0, 3.0],
                   ["nbands 64", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N64", "orange",  1.0, 2.5],
                   ["nbands 128", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N128", "green",  1.0, 2.0],
                   ["nbands 256", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N256", "blue",   1.0, 1.5],
                   ["nbands 512", "5_Dielectric_function/G_Graphene_B4C3_Top_PBE_K17_N512", "violet", 1.0, 1.0]]

plot_dielectric_function_XZ("Graphene-B₄C₃ (Top)", dielectric_list, 24)
