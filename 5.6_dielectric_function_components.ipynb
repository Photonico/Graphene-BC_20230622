# %% [markdown]
# # Dielectric Function versus components
#
# Dielectric function versus Photon energy in different components

# %%
# Prework

from vmatplot.dielectric_function import plot_dielectric_function

# import matplotlib.pyplot as plt

monolayers = [["for Graphene by PBE", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]


components = [{"xx":"in-plane"}, {"zz":"out-of-plane"}, "xy", "yx"]
layout = "hor"
boundary = 24

# %%
# Graphene (monocomp testing)

from vmatplot.dielectric_function import *

def plot_dielectric_monocomp(suptitle, systems=None, component=None,
                             layout="horizontal", rescale_label=True,
                             unit=None, boundary=(None,None), figure_size=(None,None)):
    ## Help information
    dielectric_help =  plot_dielectric_help()
    if suptitle in ["help", "Help"]:
        print(dielectric_help)

    print("test")

monolayers = [["for Graphene by PBE", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]

monocomp = [{"xx":"in-plane"}]
# print(type(monocomp),len(monocomp))
monocomp = {"xx":"in-plane"}
# print(type(monocomp),len(monocomp))
monocomp = "xx"
# print(type(monocomp),len(monocomp))
layout = "hor"
boundary = 24

# plot_dielectric_function("for Graphene", monolayers, monocomp, layout, False,"eV", boundary)
plot_dielectric_function("help")

# %%
# Graphene

monolayers = [["for Graphene by PBE", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]

plot_dielectric_function("for Graphene", monolayers, components, layout, False,"eV", boundary)

# %%
# bottom layers

monolayers = [["for BC₃", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
              ["for Borophene", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
              ["for B₄C₃", "5_Dielectric_function/C_B4C3_PBE_K65","violet"]]

plot_dielectric_function("for bottom layers", monolayers, components, layout, False, "eV", boundary)

# %%
# Monolayers

monolayers = [["for BC₃", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
              ["for Borophene", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
              ["for B₄C₃", "5_Dielectric_function/C_B4C3_PBE_K65","violet"],
              ["for Graphene", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"]]

plot_dielectric_function("for monolayers by PBE", monolayers, components, layout, False, "eV", boundary)

# %%
# Graphene-BC₃ (Hollow)

systems = [["by GGA-PBE", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
           ["by HSE06 (17 k-points)", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, False, "eV", boundary)

# %%
# Graphene-Borophene (Top)

systems = [["GGA-PBE", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
           ["HSE06", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, False, "eV", boundary)

# %%
# Graphene-B₄C₃ (Top)

systems = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
           ["HSE06 (17 k-points)", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, False, "eV", boundary)
