# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

re = extract_pdos("4_PDoS_PBE/E_Graphene-BC3_Hollow_K65")

print(len(re[8]))
print(len(re[6]))
print(len(re[5]))

print((re[8]))
print((re[6]))
print((re[5]))
# Out:
# 4000
# 4000
# 4000
# [-20.25143372 -20.24373372 -20.23593372 ...  10.84976628  10.85746628
#   10.86526628]
# [0. 0. 0. ... 0. 0. 0.]
# [-20.25143372 -20.24373372 -20.23593372 ...  10.84976628  10.85746628
#   10.86526628]

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

plot_total_pdos_data("Graphene-Borphene (Hollow)", 6, 11, "total", "4_PDoS_PBE/F_Graphene-Borophene_Top_K25", "Orbital")
# Out:
# [-20.91063008 -20.90293008 -20.89513008 ...  10.06646992  10.07416992
#   10.08196992]
# [0. 0. 0. ... 0. 0. 0.]

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

plot_total_pdos_data("Graphene-Borphene (Hollow)", 6, 11, "total", "4_PDoS_HSE06/F_Graphene-Borophene_Top_K25", "Orbital")
# Out:
# [-24.59970158 -24.58570158 -24.57180158 ...  30.98839842  31.00229842
#   31.01619842]
# [0. 0. 0. ... 0. 0. 0.]

# %%
from vmatplot.PDoS import *

# extract_element_pdos("4_PDoS_HSE06/F_Graphene-Borophene_Top_K25","B")

# extract_element_pdos("4_PDoS_PBE/F_Graphene-Borophene_Top_K25","B")

# extract_kpoints_number("4_PDoS_PBE/F_Graphene-Borophene_Top_K25")

extract_kpoints_number("4_PDoS_HSE06/F_Graphene-Borophene_Top_K25")
# Out:
# 16
