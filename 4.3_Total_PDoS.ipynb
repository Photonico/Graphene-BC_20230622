# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
# Prework

from vmatplot.PDoS import plot_totpdos

import matplotlib.pyplot as plt

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["(GGA-PBE)",      "4_PDoS/E_Graphene-BC3_PBE", "blue", 0.8, "dotted"],
               ["(HSE06)",    "4_PDoS/E_Graphene-BC3_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-BC₃ (Hollow)", 6, 12, "Total", matters_dir)

plt.savefig("Figures/4.31_total_PDoS_for_Graphene-BC3.pdf")

# %%
# Graphene-Borophene (Top)

matters_dir = [["(GGA-PBE)",      "4_PDoS/F_Graphene-Borophene_PBE", "blue", 0.8, "dotted"],
               ["(HSE06)",    "4_PDoS/F_Graphene-Borophene_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-Borophene (Top)", 6, 10, "Total", matters_dir)

plt.savefig("Figures/4.32_total_PDoS_for_Graphene-Borophene.pdf")

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["(GGA-PBE)",      "4_PDoS/G_Graphene-B4C3_PBE_K33", "blue", 0.8, "dotted"],
               ["(HSE06)",    "4_PDoS/G_Graphene-B4C3_HSE", "blue", 1.0]]

plot_totpdos("for Graphene-B₄C₃ (Top)", 6, 10, "Total", matters_dir)

plt.savefig("Figures/4.33_total_PDoS_for_Graphene-B4C3.pdf")
