# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
# Graphene-BC₃ (Hollow)

from vmatplot.PDoS_plotting import plot_totpdos

matters_dir = [["PBE", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K65", "blue", 1.0, "dotted"],
               ["HSE06", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "blue", 1.0]]

plot_totpdos("Graphene-BC₃ (Hollow)", 6, 10, "total", matters_dir)

# %%
# Graphene-Borophene (Top)

matters_dir = [["PBE 25 Kpoints", "4_PDoS_PBE/F_Graphene-Borophene_Top_K25", "blue", 0.5, "dotted"],
               ["PBE 65 Kpoints", "4_PDoS_PBE/F_Graphene-Borophene_Top_K65", "blue", 1.0, "dotted"],
               ["HSE06", "4_PDoS_HSE06/F_Graphene-Borophene_Top_K25", "blue", 1.0]]

plot_totpdos("Graphene-Borophene (Top)", 6, 10, "total", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["PBE", "4_PDoS_PBE/G_Graphene-B4C3_Top_K33", "blue", 1.0, "dotted"],
               ["HSE06", "4_PDoS_HSE06/G_Graphene-B4C3_Top", "blue", 1.0]]

plot_totpdos("Graphene-B₄C₃ (Top)", 6, 10, "total", matters_dir)
