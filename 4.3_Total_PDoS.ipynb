# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
# Prework

from vmatplot.PDoS_plotting import plot_totpdos

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["PBE",      "4_PDoS/E_Graphene-BC3_Hollow_PBE", "blue", 0.8, "dotted"],
               ["HSE06",    "4_PDoS/E_Graphene-BC3_Hollow_HSE", "blue", 1.0]]

plot_totpdos("Graphene-BC₃ (Hollow)", 6, 10, "Total", matters_dir)

# %%
# Graphene-Borophene (Top)

matters_dir = [["PBE",      "4_PDoS/F_Graphene-Borophene_Top_PBE", "blue", 0.8, "dotted"],
               ["HSE06",    "4_PDoS/F_Graphene-Borophene_Top_HSE", "blue", 1.0]]

plot_totpdos("Graphene-Borophene (Top)", 6, 10, "Total", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["PBE",      "4_PDoS/G_Graphene-B4C3_Top_PBE_K33", "blue", 0.8, "dotted"],
               ["HSE06",    "4_PDoS/G_Graphene-B4C3_Top_HSE", "blue", 1.0]]

plot_totpdos("Graphene-B₄C₃ (Top)", 6, 10, "Total", matters_dir)
