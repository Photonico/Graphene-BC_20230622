# %% [markdown]
# # Linear optical properties for each component
#
#
# * Absorption coefficient
#   * title: "Absorption coefficient"
#   * label: "absorption"
#
# * Refractive index
#   * title: "Refractive index"
#   * label: "refractive"
#
# * Extinction coefficient
#   * title: "Extinction coefficient"
#   * label: "extinction"
#
# * Reflectivity
#   * title: "Reflectivity"
#   * label: "reflectivity"
#
# * Energy-loss spectrum
#   * title: "Energy-loss spectrum"
#   * label: "energy-loss"

# %%
# prework

from vmatplot.linear_optical_properties import plot_linear_optical_property

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"}, {"yy":"yy-component"}, {"zz":"out-of-plane"}]

boundary = 24
layout = "hor"

systems_PBE = [["BC₃", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
               ["Borophene", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
               ["B₄C₃", "5_Dielectric_function/C_B4C3_PBE_K65", "violet"],
               ["Graphene", "5_Dielectric_function/D_Graphene_PBE_K129", "grey"]]

# %%
# Absorption coefficient by GGA-PBE

plot_linear_optical_property("for monolayers by PBE", systems_PBE, "absorption", components, layout, "eV", boundary)

plt.savefig("Figures/6.31_absorption_monolayers_PBE.pdf")

# %%
# Refractive index by GGA-PBE

plot_linear_optical_property("for monolayers by PBE", systems_PBE, "refractive", components, layout, "eV", boundary)

plt.savefig("Figures/6.32_refractive_monolayers_PBE.pdf")

# %%
# Extinction coefficient

plot_linear_optical_property("for monolayers by PBE", systems_PBE, "extinction", components, layout, "eV", boundary)

plt.savefig("Figures/6.33_extinction_monolayers_PBE.pdf")

# %%
# Reflectivity

plot_linear_optical_property("for monolayers by PBE", systems_PBE, "reflectivity", components, layout, "eV", boundary)

plt.savefig("Figures/6.34_reflectivity_monolayers_PBE.pdf")

# %%
# Energy-loss spectrum

plot_linear_optical_property("for monolayers by PBE", systems_PBE, "energy-loss", components, layout, "eV", boundary)

plt.savefig("Figures/6.35_energy-loss_monolayers_PBE.pdf")
