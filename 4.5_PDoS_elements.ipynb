# %% [markdown]
# # PDoS elements
#
# Projected electronic density of state versus energy for each elements

# %%
# Prework

from vmatplot.PDoS import extract_pdos, extract_segment_pdos
from vmatplot.PDoS_plotting import plot_segment_pdos

import matplotlib.pyplot as plt

# %%
# Graphene-BC₃ (Hollow)

HSE_total = extract_pdos("4_PDoS/E_Graphene-BC3_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/E_Graphene-BC3_HSE", 1, 2)
HSE_C_top = extract_segment_pdos("4_PDoS/E_Graphene-BC3_HSE", 3, 8)
HSE_C_bot = extract_segment_pdos("4_PDoS/E_Graphene-BC3_HSE", 9, 16)

title_total = "Total PDoS"
title_C_top = "PDoS for Carbon in Graphene"
title_B_BC3 = "PDoS for Boron in BC₃"
title_C_BC3 = "PDoS for Carbon in BC₃"

matters_dir = [
    [title_total, 6, 10,    "", HSE_total],
    [title_C_top, 6, 3.0,   "", HSE_C_top],
    [title_B_BC3, 6, 3.0,   "", HSE_B],
    [title_C_BC3, 6, 3.0,   "", HSE_C_bot],
    ["blue", 1.0, "solid"]
]

plot_segment_pdos("for Graphene-BC₃ by HSE06", matters_dir)

plt.savefig("Figures/4_pdos_Graphene-BC3.pdf")

# %%
# Graphene-Borophene (Top)

HSE_total = extract_pdos("4_PDoS/F_Graphene-Borophene_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/F_Graphene-Borophene_HSE", 1, 8)
HSE_C_top = extract_segment_pdos("4_PDoS/F_Graphene-Borophene_HSE", 9, 16)

title_total = "Total PDoS"
title_C_top = "PDoS for Carbon in Graphene"
title_B     = "PDoS for Boron in Borophene"

matters_dir = [
    [title_total, 6, 10,    "", HSE_total],
    [title_C_top, 6, 4.0,   "", HSE_C_top],
    [title_B,     6, 4.0,   "", HSE_B],
    ["blue", 1.0, "solid"]
]

plot_segment_pdos("for Graphene-Borophene by HSE06", matters_dir)

plt.savefig("Figures/4_pdos_Graphene-Borophene.pdf")

# %%
# Graphene-B₄C₃ (Top)

HSE_total = extract_pdos("4_PDoS/G_Graphene-B4C3_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_HSE", 1, 4)
HSE_C_top = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_HSE", 5, 7)
HSE_C_bot = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_HSE", 8, 15)

title_total  = "Total PDoS"
title_C_top  = "PDoS for Carbon in Graphene"
title_B_B4C3 = "PDoS for Boron in B₄C₃"
title_C_B4C3 = "PDoS for Carbon in B₄C₃"

matters_dir = [
    [title_total, 6, 10,    "", HSE_total],
    [title_C_top, 6,2.5,    "", HSE_C_top],
    [title_B_B4C3,6,2.5,    "", HSE_B],
    [title_C_B4C3,6,2.5,    "", HSE_C_bot],
    ["blue", 1.0, "solid"]
]

plot_segment_pdos("for Graphene-B₄C₃ by HSE06", matters_dir)

plt.savefig("Figures/4_pdos_Graphene-B4C3.pdf")
