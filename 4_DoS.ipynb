# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# BC₃ DoS

from vmatplot.DoS import plot_dos

matters_dir = [["PBE", "4_PDoS_PBE/A_BC3_K65", "orbital"],
               ["HSE06", "4_PDoS_HSE06/A_BC3_K17", "orange"]]

plot_dos("BC₃", 6, 9, "total", matters_dir)
