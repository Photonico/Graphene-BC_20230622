# %% [markdown]
# # DoS and total PDoS
#
# Electronic density of state versus energy and total Projected electronic density of state versus energy

# %%
# Graphene-Borophene: Top DoS

from vmatplot.DoS import plot_dos

matters_dir = [["PBE", "4_PDoS_PBE/F_Graphene-Borophene_Top_K65", "orbital"],
               ["HSE06", "4_PDoS_HSE06/F_Graphene-Borophene_Top", "orange"]]

plot_dos("Graphene-Borophene: Top", 6, 9, "total", matters_dir)

# %%
# Graphene-B₄C₃: Top DoS

matters_dir = [["PBE", "4_PDoS_PBE/G_Graphene-B4C3_Top_K65", "orbital"],
               ["HSE06", "4_PDoS_HSE06/G_Graphene-B4C3_Top_K11", "orange"]]

plot_dos("Graphene-B₄C₃: Top", 6, 10, "total", matters_dir)
