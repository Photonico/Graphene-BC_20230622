# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# BC₃ DoS

from vmatplot.DoS import plot_dos

matters_dir = [["17 Kpoints", "4_PDoS_PBE/A_BC3_K17", "grey"],
               ["33 Kpoints", "4_PDoS_PBE/A_BC3_K33", "Blue"],
               ["65 Kpoints", "4_PDoS_PBE/A_BC3_K33", "purple"],]

plot_dos("BC₃ (PBE)", 6, 9, "total", matters_dir)
