# %% [markdown]
# # Optical Properties
#
# The correlation between optical properties and energy with fixed vacant energy bands.

# %%
#### 1.1 Single layer: BC3

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import density_plotting, density_plotting_in

opt_11 = optical_properties_extracting("Single_BC3/6_Optical_properties/vasprun.xml")
density_plotting(opt_11, "BC₃", -10, 25)
density_plotting_in(opt_11, "BC₃", -10, 25)

# %%
#### 1.2 Single layer: Graphene

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import density_plotting, density_plotting_in

opt_12 = optical_properties_extracting("Single_Graphene/6_Optical_properties/vasprun.xml")
density_plotting(opt_12, "Graphene", -10, 25)
density_plotting_in(opt_12, "Graphene", -10, 25)

# %%
#### 2.1 Double layer: Graphene - BC3

from Store.optical_properties_extracting import optical_properties_extracting
from Store.optical_properties_plotting import density_plotting, density_plotting_in

opt_21 = optical_properties_extracting("Double_Graphene-BC3/6_Optical_properties/vasprun.xml")
density_plotting(opt_21, "Graphene - BC₃", -10, 25)
density_plotting_in(opt_21, "Graphene - BC₃", -10, 25)
