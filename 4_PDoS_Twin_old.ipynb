# %% [markdown]
# # PDOS for double layer matter - BC3
#
# Projected electronic density of state versus energy

# %%
#### 2.1 Double layer: Graphene - BC3 - Total

from Store.PDOS_extracting import pdos_total_extracting
from Store.PDOS_plotting import pdos_total_plotting

pdos_Graphene_BC3 = pdos_total_extracting("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_total_plotting(pdos_Graphene_BC3, "Graphene - BC₃", 12)

# %%
#### 2.1 Double layer: Graphene - BC3

from Store.PDOS_extracting import *
from Store.PDOS_plotting import pdos_element_plotting

pdos_Graphene_BC3_B = pdos_B_of_BC3_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_Graphene_BC3_C_top = pdos_C_of_BC3_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_Graphene_BC3_C_bot = pdos_C_of_Graphene_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")

pdos_element_plotting(pdos_Graphene_BC3_B, "Boron in Graphene - BC3", 4)
pdos_element_plotting(pdos_Graphene_BC3_C_top, "Carbon in Graphene - BC3", 4)
pdos_element_plotting(pdos_Graphene_BC3_C_bot, "Carbon in Graphene - BC3", 4)

# %%
#### 2.1 Double layer: Graphene - BC3 - Comparsing

from Store.PDOS_extracting import *
from Store.PDOS_comparing import pdos_tri_element

pdos_Graphene_BC3_sum = pdos_total_extracting("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_Graphene_BC3_B = pdos_B_of_BC3_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_Graphene_BC3_C_top = pdos_C_of_BC3_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")
pdos_Graphene_BC3_C_bot = pdos_C_of_Graphene_in_Graphene_BC3("Double_Graphene-BC3/4_PDOS/vasprun.xml")

pdos_tri_element("Graphene - BC₃", pdos_Graphene_BC3_sum,
                 "Boron in the BC₃", pdos_Graphene_BC3_B,
                 "Carbon in the BC₃", pdos_Graphene_BC3_C_top,
                 "Carbon in the Graphene", pdos_Graphene_BC3_C_bot, 
                 12, 2, 4, 4)
