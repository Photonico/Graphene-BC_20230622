# %% [markdown]
# # Dielectric Function for abs demo
#
# Dielectric function versus Photon energy in different components

# %%
# Prework

from vmatplot.dielectric_function import plot_dielectric_function

layout = "hor"
boundary = 16

# %%
# Graphene-BC₃ (Hollow) in plane

components = [{"xx":""}]

systems = [["", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "blue"]]

plot_dielectric_function("for Graphene-BC₃", systems, components, layout, False, "eV", boundary)

# %%
# Graphene-Borophene (Top) in plane

components = [{"xx":""}]

systems = [["", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "green"]]

plot_dielectric_function("for Graphene-Borophene", systems, components, layout, False, "eV", boundary)

# %%
# Graphene-B₄C₃ (Top) in plane

components = [{"xx":"in-plane"}]

systems = [["", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "violet"]]

plot_dielectric_function("for Graphene-B₄C₃", systems, components, layout, False, "eV", boundary)
