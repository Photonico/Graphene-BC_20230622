# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
from vmatplot.commons import identify_algorithm

paths = ["3_Bandstructure/G_Graphene-B4C3_top_PBE",
         "3_Bandstructure/G_Graphene-B4C3_top_HSE",
         "4_PDoS/G_Graphene-B4C3_PBE_K33",
         "4_PDoS/G_Graphene-B4C3_HSE",
         "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128",
         "5_Dielectric_function/G_Graphene-B4C3_HSE_K03"]

for path in paths:
    result = identify_algorithm(path)
    print(result)
# Out:
# GGA-PBE
# HSE06
# GGA-PBE
# HSE06
# GGA-PBE
# HSE06

# %%
from vmatplot.dielectric_function import extract_dielectric_vasprun

path_PBE = "5_Dielectric_function/E_Graphene-BC3_PBE_K65"
path_HSE = "5_Dielectric_function/F_Graphene-Borophene_HSE_K17"

result_PBE = extract_dielectric_vasprun(path_PBE)
result_HSE = extract_dielectric_vasprun(path_HSE)

print(result_PBE)
print(result_HSE)

print(max(result_HSE["density_energy_imag"]))
print(max(result_HSE["density_energy_real"]))
print(max(result_HSE["current_energy_imag"]))
print(max(result_HSE["current_energy_real"]))

print(len(result_HSE["density_energy_imag"]))
print(len(result_HSE["density_energy_real"]))
print(len(result_HSE["current_energy_imag"]))
print(len(result_HSE["current_energy_real"]))
# Out:
# Error: The file vasprun.xml does not exist in the directory 5_Dielectric_function/E_Graphene-BC3_PBE_K65.
# None
# {'nedos and nbands': (4000, 128), 'density_energy_imag': array([0.0000e+00, 1.5000e-02, 3.0000e-02, ..., 5.9939e+01, 5.9954e+01,
#        5.9969e+01]), 'density_xx_imag': array([0.000e+00, 2.838e-01, 5.725e-01, ..., 3.000e-04, 3.000e-04,
#        3.000e-04]), 'density_yy_imag': array([0.000e+00, 2.838e-01, 5.725e-01, ..., 3.000e-04, 3.000e-04,
#        3.000e-04]), 'density_zz_imag': array([0.    , 0.0001, 0.0002, ..., 0.0002, 0.0002, 0.0002]), 'density_xy_imag': array([ 0., -0., -0., ..., -0., -0., -0.]), 'density_yz_imag': array([ 0., -0., -0., ..., -0., -0., -0.]), 'density_zx_imag': array([0., 0., 0., ..., 0., 0., 0.]), 'current_energy_imag': array([0.0000e+00, 1.5000e-02, 3.0000e-02, ..., 5.9939e+01, 5.9954e+01,
#        5.9969e+01]), 'current_xx_imag': array([354.4551, 354.4551, 177.8975, ...,   0.    ,   0.    ,   0.    ]), 'current_yy_imag': array([354.4551, 354.4551, 177.8975, ...,   0.    ,   0.    ,   0.    ]), 'current_zz_imag': array([13.5392, 13.5392,  6.7699, ...,  0.    ,  0.    ,  0.    ]), 'current_xy_imag': array([-0., -0., -0., ..., -0., -0., -0.]), 'current_yz_imag': array([-0., -0., -0., ...,  0.,  0.,  0.]), 'current_zx_imag': array([-0., -0., -0., ..., -0., -0., -0.]), 'density_energy_real': array([0.0000e+00, 1.5000e-02, 3.0000e-02, ..., 5.9939e+01, 5.9954e+01,
