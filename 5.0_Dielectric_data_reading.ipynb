# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
from vmatplot.commons import identify_algorithm

paths = ["3_Bandstructure/G_Graphene-B4C3_Top_PBE",
         "3_Bandstructure/G_Graphene-B4C3_Top_HSE",
         "4_PDoS/G_Graphene-B4C3_Top_PBE_K33",
         "4_PDoS/G_Graphene-B4C3_Top_HSE_S11",
         "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128",
         "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K03"]

for path in paths:
    result = identify_algorithm(path)
    print(result)
# Out:
# GGA-PBE
# HSE06
# GGA-PBE
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       3 paths = ["3_Bandstructure/G_Graphene-B4C3_Top_PBE",
#       4          "3_Bandstructure/G_Graphene-B4C3_Top_HSE",
#       5          "4_PDoS/G_Graphene-B4C3_Top_PBE_K33",
#       6          "4_PDoS/G_Graphene-B4C3_Top_HSE_S11",
#       7          "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128",
#       8          "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K03"]
#      10 for path in paths:
# ---> 11     result = identify_algorithm(path)
#      12     print(result)
#
# File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\commons.py:15, in identify_algorithm(directory)
#      13 file_name = "INCAR"
#      14 file_path = os.path.join(directory, file_name)
# ---> 15 with open(file_path, "r", encoding="utf-8") as file:
# ...

# %%
from vmatplot.dielectric_function_plotting import extract_dielectric_function

path_PBE = "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128"
path_HSE = "5_Dielectric_function/G_Graphene-B4C3_Top_HSE_K03"

result_PBE = extract_dielectric_function(path_PBE)
result_HSE = extract_dielectric_function(path_HSE)

print(result_PBE)
print(result_HSE)
