# %% [markdown]
# # Dielectric Function
#
# Dielectric function versus Photon energy

# %%
from vmatplot.commons import identify_algorithm

paths = ["3_Bandstructure/G_Graphene-B4C3_PBE",
         "3_Bandstructure/G_Graphene-B4C3_HSE",
         "4_PDoS/G_Graphene-B4C3_PBE_K33",
         "4_PDoS/G_Graphene-B4C3_HSE",
         "5_Dielectric_function/G_Graphene-B4C3_PBE_K17_N128",
         "5_Dielectric_function/G_Graphene-B4C3_HSE_K03"]

for path in paths:
    result = identify_algorithm(path)
    print(result)
# Out:
# GGA-PBE
# HSE06
# GGA-PBE
# HSE06
# GGA-PBE
# HSE06

# %%
from vmatplot.dielectric_function_plotting import extract_dielectric_function

path_PBE = "5_Dielectric_function/G_Graphene-B4C3_PBE_K65"
path_HSE = "5_Dielectric_function/G_Graphene-B4C3_HSE_K03"

result_PBE = extract_dielectric_function(path_PBE)
result_HSE = extract_dielectric_function(path_HSE)

print(result_PBE)
print(result_HSE)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     from vmatplot.dielectric_function_plotting import extract_dielectric_function
#
#   File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\dielectric_function_plotting.py:8
#     from vmatplot.dielectric_function import extract_dielectric_function
#
#   File c:\Users\LukeN\Repos\Graphene-BC_20230622\vmatplot\dielectric_function.py:250
#     def extract_dielectric_function(directory):
#     ^
# IndentationError: expected an indented block after function definition on line 241
