# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# Prework

from vmatplot.DoS import plot_dos

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["PBE", "4_PDoS/E_Graphene-BC3_Hollow_PBE_K33", "blue"],
               ["HSE06", "4_PDoS/E_Graphene-BC3_Hollow_HSE", "orange"]]

plot_dos("Graphene-BC₃ (Hollow)", 6, 10, "total", matters_dir)

# %%
# Graphene-Borophene (Top)

matters_dir = [["PBE", "4_PDoS/F_Graphene-Borophene_Top_PBE_K33", "blue"],
               ["HSE06", "4_PDoS/F_Graphene-Borophene_Top_HSE", "orange"]]

plot_dos("Graphene-Borophene (Top)", 6, 9, "total", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["PBE", "4_PDoS/G_Graphene-B4C3_Top_PBE_K33", "orbital"],
               ["HSE06", "4_PDoS/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_dos("Graphene-B₄C₃ (Top)", 6, 10, "total", matters_dir)
