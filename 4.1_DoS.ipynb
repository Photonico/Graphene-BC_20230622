# %% [markdown]
# # DoS
#
# Electronic density of state versus energy

# %%
# Prework

from vmatplot.DoS import plot_dos

import matplotlib.pyplot as plt

# %%
# Graphene-BC₃ (Hollow)

matters_dir = [["(GGA-PBE)", "4_PDoS/E_Graphene-BC3_PBE", "blue"],
               ["(HSE06)", "4_PDoS/E_Graphene-BC3_HSE", "orange"]]

plot_dos("for Graphene-BC₃ (Hollow)", 6, 12, "total", matters_dir)

plt.savefig("Figures/4.11_DoS_for_Graphene-BC3.pdf")

# %%
# Graphene-Borophene (Top)

matters_dir = [["(GGA-PBE)", "4_PDoS/F_Graphene-Borophene_PBE", "blue"],
               ["(HSE06)", "4_PDoS/F_Graphene-Borophene_HSE", "orange"]]

plot_dos("for Graphene-Borophene (Top)", 6, 9, "total", matters_dir)

plt.savefig("Figures/4.12_DoS_for_Graphene-Borophene.pdf")

# %%
# Graphene-B₄C₃ (Top)

matters_dir = [["(GGA-PBE)", "4_PDoS/G_Graphene-B4C3_PBE_K33", "orbital"],
               ["(HSE06)", "4_PDoS/G_Graphene-B4C3_HSE", "orange"]]

plot_dos("for Graphene-B₄C₃ (Top)", 6, 10, "total", matters_dir)

plt.savefig("Figures/4.13_DoS_for_Graphene-B4C3.pdf")
