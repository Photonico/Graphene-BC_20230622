# %%
# Bandstrcutre reference: py4vasp and pymatgen

# %%
# Plot Graphene bandstructure: basic information

from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.plotter import BSPlotter
import matplotlib.pyplot as plt

vasprun = Vasprun("3_Bandstructure_PBE/D_Graphene/vasprun.xml")

band_structure = vasprun.get_band_structure(kpoints_filename=None, efermi=None, line_mode=True)

bands = band_structure.bands

e_fermi = band_structure.efermi

kpoints = band_structure.kpoints

# %%
# Plot Graphene bandstructure: basic information

import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasprun_PBE = Vasprun("3_Bandstructure_PBE/D_Graphene/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/D_Graphene/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasprun_PBE = Vasprun("3_Bandstructure_HSE06/A_BC3/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_HSE06/A_BC3/KPOINTS_OPT"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for BC3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/B_Borophene/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/B_Borophene/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Borophene",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/C_B4C3/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/C_B4C3/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for B4C3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
vasprun_PBE = Vasprun("3_Bandstructure_PBE/G_Graphene-B4C3_Top/vasprun.xml", parse_potcar_file = False, parse_projected_eigen = True)
kpoints_file = "3_Bandstructure_PBE/G_Graphene-B4C3_Top/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

# Extract the Fermi energy
fermi_energy_PBE = vasprun_PBE.efermi

# Extract the bandstructre
bandstructure_PBE = vasprun_PBE.get_band_structure(kpoints_filename = kpoints_file, line_mode=True)

# Extract VBM (Valence band maximum) and CBM (Conduction band minimum)
vbm_info_PBE = bandstructure_PBE.get_vbm()
cbm_info_PBE = bandstructure_PBE.get_cbm()
vbm_energy_PBE = vbm_info_PBE["energy"]
cbm_energy_PBE = cbm_info_PBE["energy"]

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter = BSPlotter(bandstructure_PBE)
plot_data = plotter.bs_plot_data()
plotter.get_plot(ylim=(-6, 6))

plt.axhline(y = cbm_energy_PBE - fermi_energy_PBE, color="#B95FF5", alpha = 0.4, label = "CBM (PBE)")
plt.axhline(y = vbm_energy_PBE - fermi_energy_PBE, color="#37B44B", alpha = 0.4, label = "VBM (PBE)")
plt.axhline(y = 0, color="#EB731E", alpha = 0.4, label=f"Fermi energy\n{fermi_energy_PBE:.3f} (eV)")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene-B4C3",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")
# plt.axhline(y = fermi_energy, linestyle="--", color="#EB731E", label="Fermi Energy")

plt.legend().remove()
# plt.tight_layout()
plt.legend(loc="upper right")
plt.show()

# %%
# py4vasp testing space

import py4vasp

Path= "3_Bandstructure_HSE06\A_BC3"

calc = py4vasp.Calculation.from_path(Path)

calc.band.to_dict(selection="KPOINTS_OPT")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\lniu6305\Repos\Graphene-BC_20230622\3_bandstructure_reference.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_reference.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # py4vasp testing space
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_reference.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> import py4vasp
#       <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_reference.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> Path= "3_Bandstructure_HSE06\A_BC3"
#       <a href='vscode-notebook-cell:/c%3A/Users/lniu6305/Repos/Graphene-BC_20230622/3_bandstructure_reference.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> calc = py4vasp.Calculation.from_path(Path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\__init__.py:3
#       1 # Copyright © VASP Software GmbH,
#       2 # Licensed under the Apache License 2.0 (http://www.apache.org/licenses/LICENSE-2.0)
# ----> 3 from py4vasp._calculation import Calculation
#       4 from py4vasp._third_party.graph import plot
#       5 from py4vasp._third_party.interactive import set_error_handling
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\_calculation.py:6
#       3 import inspect
#       4 import pathlib
# ----> 6 from py4vasp import _data, control, data, exception
#       7 from py4vasp._util import convert
#      10 class Calculation:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\control.py:11
#       9 from py4vasp._control.incar import INCAR
#      10 from py4vasp._control.kpoints import KPOINTS
# ---> 11 from py4vasp._control.poscar import POSCAR
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\_control\poscar.py:4
#       1 # Copyright © VASP Software GmbH,
#       2 # Licensed under the Apache License 2.0 (http://www.apache.org/licenses/LICENSE-2.0)
#       3 from py4vasp._control import base
# ----> 4 from py4vasp.data import Structure
#       7 class POSCAR(base.InputFile):
#       8     """The POSCAR file defining the structure used in the VASP calculation.
#       9
#      10     Parameters
#    (...)
#      14         in memory.
#      15     """
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\data.py:23
#       3 """ Refine the raw data produced by VASP for plotting or analysis.
#       4
#       5 Usually one is not directly interested in the raw data that is produced but
#    (...)
#      19 the documentation of the individual classes.
#      20 """
#      22 from py4vasp._data.band import Band
# ---> 23 from py4vasp._data.born_effective_charge import BornEffectiveCharge
#      24 from py4vasp._data.density import Density
#      25 from py4vasp._data.dielectric_function import DielectricFunction
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\_data\born_effective_charge.py:3
#       1 # Copyright © VASP Software GmbH,
#       2 # Licensed under the Apache License 2.0 (http://www.apache.org/licenses/LICENSE-2.0)
# ----> 3 from py4vasp._data import base, structure
#       6 class BornEffectiveCharge(base.Refinery, structure.Mixin):
#       7     """The Born effective charge tensors coupling electric field and atomic displacement.
#       8
#       9     You can use this class to extract the Born effective charges of a linear
#      10     response calculation.
#      11     """
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\py4vasp\_data\structure.py:8
#       5 from dataclasses import dataclass
#       7 import ase.io
# ----> 8 import mdtraj
#       9 import numpy as np
#      10 from IPython.lib.pretty import pretty
#
# ModuleNotFoundError: No module named 'mdtraj'
