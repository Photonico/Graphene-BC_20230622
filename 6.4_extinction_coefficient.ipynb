# %% [markdown]
# # Extinction coefficient
#
# The extinction coefficient, also known as the imaginary refractive index, indicates the attenuation of light in a system.
#
# We define the extinction spectrum of a system as:
#
# $$ k(\omega)=\frac{1}{\sqrt{2}}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.extinction_coefficient import plot_extinction_XZ

import matplotlib.pyplot as plt

# %%
# Extinction coefficient for Graphene-BC₃

matters_list = [["GGA-PBE", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
                ["HSE06 17 k-points", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_extinction_XZ("for Graphene-BC₃", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Extinction coefficient for Graphene-Borophene

matters_list = [["GGA-PBE", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
                ["HSE06", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_extinction_XZ("for Graphene-Borophene", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Extinction coefficient for Graphene-BC₃

matters_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
                ["HSE06 17 k-points", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_extinction_XZ("for Graphene-B₄C₃", matters_list, "eV", 40, 40, (4,12), (4,12))
