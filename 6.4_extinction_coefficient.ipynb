# %% [markdown]
# # Extinction coefficient
#
# The extinction coefficient, also known as the imaginary refractive index, indicates the attenuation of light in a system.
#
# We define the extinction spectrum of a system as:
#
# $$ k(\omega)=\frac{1}{\sqrt{2}}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.extinction_coefficient import plot_extinction_XZ

import matplotlib.pyplot as plt

# %%
# Extinction coefficient comparison GGA-PBE and HSE06

matters_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                ["HSE06", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_extinction_XZ("for Graphene-B₄C₃ comparison GGA-PBE and HSE06", matters_list, "eV", 40, 40, (4,12), (4,12))

# %%
# Extinction coefficient in eV

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_extinction_XZ("", matters_list, "eV", 40, 40, (0.88, 10.16), (0.88, 10.16))

plt.savefig("Figures/6.4_extinction_coefficient.pdf")

# %%
# Extinction coefficient in nm

matters_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                ]

plot_extinction_XZ("", matters_list, "nm", 1000, 200, 400, 100)
