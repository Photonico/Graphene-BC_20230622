# %% [markdown]
# # Kpoints
#
# Free energy versus K-points

# %%
# Prework

from vmatplot.kpoints import summarize_kpoints_free_energy, plot_kpoints_free_energy_data
import matplotlib.pyplot as plt

# %%
# BC3

summarize_kpoints_free_energy("1_Kpoints/BC3")

plot_kpoints_free_energy_data("for BC₃","1_Kpoints/BC3/energy_kpoint.dat","X", (11, 59))

# %%
# Graphene - BC3: Hollow

summarize_kpoints_free_energy("1_Kpoints/Graphene_BC3_Hollow")

plot_kpoints_free_energy_data("for Graphene-BC₃ (Hollow)","1_Kpoints/Graphene_BC3_Hollow/energy_kpoint.dat","X", (9, 61), "violet")

plt.savefig("Figures/S1.4_kpoints.pdf")
