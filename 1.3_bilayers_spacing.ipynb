# %% [markdown]
# # Interlayer spacing
#
# Free energy versus lattice constant and interlayer spacing for bilayers

# %%
# Selected cases

from vmatplot.lattice_bilayer import specify_bilayer_lattice, plot_bilayer_lattice

selected_G_BC3 = specify_bilayer_lattice("0_Lattice_Reference/E_Graphene-BC3_Hollow")
selected_G_Borophene = specify_bilayer_lattice("0_Lattice_Reference/F_Graphene-Borophene_Top")
selected_G_B4C3 = specify_bilayer_lattice("0_Lattice_Reference/G_Graphene-B4C3_Top")

# %%
# Graphene - BC₃ Hollow

plot_bilayer_lattice(1, "for Graphene-BC₃ (Hollow)", ["0_Lattice_Distance/E_Graphene-BC3_Hollow/lattice_distance.dat", "Blues_r", "blue", None])

# %%
# Graphene - Borophene Top

plot_bilayer_lattice(1, "for Graphene-Borophene (Top)", ["0_Lattice_Distance/F_Graphene-Borophene_Top/lattice_distance.dat", "Oranges_r", "orange", None])

# %%
# Graphene - B₄C₃ Top

plot_bilayer_lattice(1, "for Graphene-B₄C₃ (Top)", ["0_Lattice_Distance/G_Graphene-B4C3_Top/lattice_distance.dat", "Purples_r", "violet", None, "upper left"])
