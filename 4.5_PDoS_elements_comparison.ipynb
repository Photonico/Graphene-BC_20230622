# %% [markdown]
# # PDoS elements comparison
#
# Projected electronic density of state versus energy for each elements

# %%
# Prework

from vmatplot.PDoS import extract_pdos, extract_segment_pdos
from vmatplot.PDoS_plotting import plot_segment_pdos

# %%
# Graphene-BC₃ (Hollow)

PBE_total = extract_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE")
PBE_B     = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE", 1, 2)
PBE_C_top = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE", 3, 8)
PBE_C_bot = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE", 9, 16)

HSE_total = extract_pdos("4_PDoS/E_Graphene-BC3_Hollow_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_HSE", 1, 2)
HSE_C_top = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_HSE", 3, 8)
HSE_C_bot = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_HSE", 9, 16)

title_total = "Total PDoS"
title_C_top = "PDoS for Carbon in Graphene"
title_B_BC3 = "PDoS for Boron in BC₃"
title_C_BC3 = "PDoS for Carbon in BC₃"

matters_dir = [
    [title_total, 6, 10,    "HSE06", HSE_total, "PBE", PBE_total],
    [title_C_top, 6, 3,     "HSE06", HSE_C_top, "PBE", PBE_C_top],
    [title_B_BC3, 6, 3,     "HSE06", HSE_B,     "PBE", PBE_B],
    [title_C_BC3, 6, 3,     "HSE06", HSE_C_bot, "PBE", PBE_C_bot],
    ["blue", 1.0, "solid", "blue", 1.0, "dashed"]
]

plot_segment_pdos("Graphene-BC₃ (Hollow)", matters_dir)

# %%
# Graphene-Borophene (Top)

PBE_total = extract_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE")
PBE_B     = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE", 1, 8)
PBE_C_top = extract_segment_pdos("4_PDoS/E_Graphene-BC3_Hollow_PBE", 9, 16)

HSE_total = extract_pdos("4_PDoS/F_Graphene-Borophene_Top_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/F_Graphene-Borophene_Top_HSE", 1, 8)
HSE_C_top = extract_segment_pdos("4_PDoS/F_Graphene-Borophene_Top_HSE", 9, 16)

title_total = "Total PDoS"
title_C_top = "PDoS for Carbon in Graphene"
title_B     = "PDoS for Boron in Borophene"

matters_dir = [
    [title_total, 6, 10,    "HSE06", HSE_total, "PBE", PBE_total],
    [title_C_top, 6, 4.5,   "HSE06", HSE_C_top, "PBE", PBE_C_top],
    [title_B,     6, 4.5,   "HSE06", HSE_B,     "PBE", PBE_B],
    ["blue", 1.0, "solid", "blue", 1.0, "dashed"]
]

plot_segment_pdos("Graphene-Borophene (Top)", matters_dir)

# %%
# Graphene-B₄C₃ (Top)

PBE_total = extract_pdos("4_PDoS/G_Graphene-B4C3_Top_PBE_K33")
PBE_B     = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_PBE_K33", 1, 4)
PBE_C_top = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_PBE_K33", 5, 7)
PBE_C_bot = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_PBE_K33", 8, 15)

HSE_total = extract_pdos("4_PDoS/G_Graphene-B4C3_Top_HSE")
HSE_B     = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_HSE", 1, 4)
HSE_C_top = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_HSE", 5, 7)
HSE_C_bot = extract_segment_pdos("4_PDoS/G_Graphene-B4C3_Top_HSE", 8, 15)

title_total  = "Total PDoS"
title_C_top  = "PDoS for Carbon in Graphene"
title_B_B4C3 = "PDoS for Boron in B₄C₃"
title_C_B4C3 = "PDoS for Carbon in B₄C₃"

matters_dir = [
    [title_total, 6, 10,    "HSE06", HSE_total, "PBE", PBE_total],
    [title_C_top, 6, 10,    "HSE06", HSE_C_top, "PBE", PBE_C_top],
    [title_B_B4C3, 6, 3,    "HSE06", HSE_B,     "PBE", PBE_B],
    [title_C_B4C3, 6, 3,    "HSE06", HSE_C_bot, "PBE", PBE_C_bot],
    ["blue", 1.0, "solid", "blue", 1.0, "dashed"]
]

plot_segment_pdos("Graphene-B₄C₃ (Hollow)", matters_dir)
