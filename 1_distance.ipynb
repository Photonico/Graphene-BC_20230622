# %% [markdown]
# # Distance
#
# Free energy versus lattice constant and distance

# %% [markdown]
# ## Results
#
# ### Graphene - BC₃: Hollow
#
# * Most stable Lattice constant: 5.044(Å)
# * Most stable distance: 3.375 (Å)
# * Minimal free energy: -142.295 (eV)
# * B-C bond:
# * C-C bond:
#
# ### Graphene - Borophene: Top
#
# * Most stable Lattice constant: 4.979 (Å)
# * Most stable distance: 3.496 (Å)
# * Minimal free energy: -125.924 (eV)
# * B-C bond:
# * C-C bond:
#
# ### Graphene - B₄C₃: Top
#
# * Most stable Lattice constant: 4.846 (Å)
# * Most stable distance: 3.514 (Å)
# * Minimal free energy: -127.142 (eV)
# * B-C bond:
# * C-C bond:

# %%
# Selected cases

from Store.lattice_biolayer import specify_biolayer_lattice

selected_G_BC3 = specify_biolayer_lattice("2_Self_Consistent/E_Graphene-BC3_Hollow_K11")
print(selected_G_BC3)

selected_G_Borophene = specify_biolayer_lattice("2_Self_Consistent/F_Graphene-Borophene_Top_K11")
print(selected_G_Borophene)

selected_G_B4C3 = specify_biolayer_lattice("2_Self_Consistent/G_Graphene-B4C3_Top_K11")
print(selected_G_B4C3)

# %%
# Graphene - BC₃ Hollow

from  Store.lattice_plotting import plot_biolayer_lattice

plot_biolayer_lattice("Graphene-BC₃ (Hollow)","0_Lattice_distance/E_Graphene-BC3_Hollow/lattice_distance.dat", "Blues_r", "blue")

# %%
# Graphene - Borophene Top

plot_biolayer_lattice("Graphene-Borophene (Top)","0_Lattice_distance/F_Graphene-Borophene_Top/lattice_distance.dat", "Oranges_r", "orange")

# %%
# Graphene - B₄C₃ Top

plot_biolayer_lattice("Graphene-B₄C₃ (Top)","0_Lattice_distance/G_Graphene-B4C3_Top/lattice_distance.dat", "Purples_r", "violet")
