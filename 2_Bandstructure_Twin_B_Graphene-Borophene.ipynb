# %% [markdown]
# # Bandstructure for Double Layers : Graphene - Borophene
#
# The band structure is demonstrated with Energy (in eV) versus K-point distance (in Å).

# %%
#### Graphene-Borophene Top PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Twin_B1_Graphene-Borophene_Top/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Twin_B1_Graphene-Borophene_Top/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - Borophene Top (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Graphene-Borophene Bridge PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Twin_B2_Graphene-Borophene_Bridge/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Twin_B2_Graphene-Borophene_Bridge/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - Borophene Bridge (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### Graphene-Borophene Hollow 1 PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Twin_B3_Graphene-Borophene_Hollow_1/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Twin_B3_Graphene-Borophene_Hollow_1/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - Borophene Hollow 1 (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#### 4.1 Graphene-Borophene Hollow 2 PBE

# Plot 2D matter bandstructure
import matplotlib.pyplot as plt
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.io.vasp import Vasprun
from pymatgen.io.vasp.inputs import Kpoints

vasp_run = Vasprun("3_Bandstructure_PBE/Twin_B4_Graphene-Borophene_Hollow_2/vasprun.xml", parse_potcar_file=False)
kpoints_file = "3_Bandstructure_PBE/Twin_B4_Graphene-Borophene_Hollow_2/KPOINTS"
kpoints = Kpoints.from_file(kpoints_file)

bandstructure = vasp_run.get_band_structure(kpoints_filename=kpoints_file, line_mode=True)

plotter = BSPlotter(bandstructure)
plot_data = plotter.bs_plot_data()

# Plot
params = {"text.usetex": False, "font.family": "serif", "mathtext.fontset": "cm",
          "axes.titlesize": 18, "axes.labelsize": 14, "figure.facecolor": "w"}
plt.rcParams.update(params)

plotter.get_plot(ylim=(-6, 6))
plt.axhline(y=0,linestyle="--",color="k")

ax = plt.gca()
ax.figure.set_dpi(196)
ax.figure.set_size_inches(10, 6)

ax.set_title("Bandstructure for Graphene - Borophene Hollow 2 (PBE)",fontsize =1.0*params["axes.titlesize"])
ax.set_xlabel(r"Wave Vector", fontsize =1.0*params["axes.labelsize"])
ax.set_ylabel(r"Energy (eV)", fontsize =1.0*params["axes.labelsize"])
ax.tick_params(axis="both", labelsize=params["axes.labelsize"],direction="in")

plt.legend().remove()
# plt.tight_layout()
# plt.legend(loc="best")
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
