# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

re = extract_pdos("4_PDoS_PBE/E_Graphene-BC3_Hollow_K65")

print(len(re[8]))
print(len(re[6]))
print(len(re[5]))

print((re[8]))
print((re[6]))
print((re[5]))

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

plot_total_pdos_data("Graphene-BC₃: Hollow (PBE)", 6, 11, "total", "4_PDoS_PBE/E_Graphene-BC3_Hollow_K65", "Orbital")
# Out:
# [-20.25143372 -20.24373372 -20.23593372 ...  10.84976628  10.85746628
#   10.86526628]
# [0. 0. 0. ... 0. 0. 0.]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(re[8],re[6])
plt.plot(re[8],re[5])
