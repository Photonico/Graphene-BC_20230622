# %% [markdown]
# # Total PDoS
#
# Total electronic partial density of state versus energy

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

re = extract_pdos("4_PDoS_PBE/E_Graphene-BC3_Hollow_K65")

print(len(re[8]))
print(len(re[6]))
print(len(re[5]))

print((re[8]))
print((re[6]))
print((re[5]))

# %%
from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data

plot_total_pdos_data("Graphene-BC₃: Hollow", 6, 11, "total", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "Orbital")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from vmatplot.PDoS import extract_pdos, plot_total_pdos, plot_total_pdos_data
# ----> 3 plot_total_pdos_data("Graphene-BC₃: Hollow", 6, 11, "total", "4_PDoS_HSE06/E_Graphene-BC3_Hollow", "Orbital")
#
# File c:\Users\lniu6305\Repos\Graphene-BC_20230622\vmatplot\PDoS.py:484, in plot_total_pdos_data(matter, x_range, y_top, pdos_type, data_path, color_family)
#     481 y_limit = y_top
#     483 # Data plotting
# --> 484 pdos_data = extract_pdos(data_path)
#     485 # testing term
#     486 print(pdos_data[8])
#
# File c:\Users\lniu6305\Repos\Graphene-BC_20230622\vmatplot\PDoS.py:53, in extract_pdos(directory_path)
#      51     eigen_values = list(map(float, eigen_occ_element.text.split()))
#      52     eigen_column = np.append(eigen_column, eigen_values[0])
# ---> 53     occu_column = np.append(occu_column, eigen_values[1])
#      54 if kpoints_index == 1 :
#      55     eigen_matrix = eigen_column.reshape(-1, 1)
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(re[8],re[6])
plt.plot(re[8],re[5])
