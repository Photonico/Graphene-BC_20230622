# %% [markdown]
# # Linear optical properties for each component

# %%
# prework

from vmatplot.linear_optical_properties import plot_linear_optical_property

import matplotlib.pyplot as plt

components = [{"xx":"in-plane"}, {"yy":"yy-component"}, {"zz":"out-of-plane"}]

boundary = 24
layout = "hor"

systems = [["BC₃", "5_Dielectric_function/A_BC3_PBE_K65", "blue"],
           ["Borophene", "5_Dielectric_function/B_Borophene_PBE_K65", "green"],
           ["B₄C₃", "5_Dielectric_function/C_B4C3_PBE_K65", "violet"],
           ["Graphene", "5_Dielectric_function/D_Graphene_PBE_K129", "silver"],]

# %%
# Absorption coefficient by GGA-PBE

plot_linear_optical_property("for bilayers by PBE", systems, "absorption", components, layout, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.14a.pdf")

# %%
# Refractive index by GGA-PBE

plot_linear_optical_property("for bilayers by PBE", systems, "refractive", components, layout, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.14c.pdf")

# %%
# Extinction coefficient by GGA-PBE

plot_linear_optical_property("for bilayers by PBE", systems, "extinction", components, layout, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.14e_c.pdf")

# %%
# Reflectivity by GGA-PBE

plot_linear_optical_property("for bilayers by PBE", systems, "reflectivity", components, layout, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.14d_c.pdf")

# %%
# Energy-loss spectrum by GGA-PBE

plot_linear_optical_property("for bilayers by PBE", systems, "energy-loss", components, layout, "eV", boundary)

plt.savefig("Figures_for_supplementary/S1.14b.pdf")
