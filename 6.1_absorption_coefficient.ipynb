# %% [markdown]
# # Absorption coefficient
#
# We define the absorption coefficient of a system as:
#
# $$ \alpha(\omega)=\frac{\sqrt{2}\omega}{c}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# It has the following relationship with the custom absorption coefficient $I(\omega)$:
#
# $$ \alpha(\omega) =\frac{\left[\sqrt{2}\omega I(\omega)\right]^{\frac{1}{2}}}{c} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.absorption_coefficient import plot_absorption_XZ

import matplotlib.pyplot as plt

# %%
# Absorption coefficient comparison GGA-PBE and HSE06

absorption_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_Top_PBE_K17_N128", "blue"],
                   ["HSE06", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "orange"]]

plot_absorption_XZ("for Graphene-B₄C₃ comparison GGA-PBE and HSE06", absorption_list, "eV", "", 40, 40, (4,12), (4,12))

# %%
# Absorption coefficient in eV

absorption_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                   ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                   ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                   ]

plot_absorption_XZ("", absorption_list, "eV", "", 40, 40, (0.88, 10.16), (0.88, 10.16))

plt.savefig("Figures/6.1_absorption_coefficient.pdf")

# %%
# Absorption coefficient in nm

absorption_list = [["Graphene-B₄C₃", "5_Dielectric_function/G_Graphene-B4C3_Top_HSE", "violet"],
                   ["Graphene-Borophene", "5_Dielectric_function/F_Graphene-Borophene_Top_HSE", "green"],
                   ["Graphene-BC₃", "5_Dielectric_function/E_Graphene-BC3_Hollow_HSE_down", "blue"]
                   ]

plot_absorption_XZ("", absorption_list, "nm", "", 1000, 200, 400, 100)
