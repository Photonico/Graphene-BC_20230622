# %% [markdown]
# # Absorption coefficient
#
# We define the absorption coefficient of a system as:
#
# $$ \alpha(\omega)=\frac{\sqrt{2}\omega}{c}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# It has the following relationship with the custom absorption coefficient $I(\omega)$:
#
# $$ \alpha(\omega) =\frac{\left[\sqrt{2}\omega I(\omega)\right]^{\frac{1}{2}}}{c} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.absorption_coefficient import plot_absorption_XXZZ

import matplotlib.pyplot as plt

# %%
# Absorption coefficient for Graphene-BC₃

absorption_list = [["GGA-PBE", "5_Dielectric_function/E_Graphene-BC3_PBE_K65_Normal", "blue"],
                   ["HSE06 17 k-points", "5_Dielectric_function/E_Graphene-BC3_HSE_K17", "orange"]]

plot_absorption_XXZZ("for Graphene-BC₃", absorption_list, "eV", "", 40, 40, (4,12), (4,12))

# %%
# Absorption coefficient for Graphene-Borophene

absorption_list = [["GGA-PBE", "5_Dielectric_function/F_Graphene-Borophene_PBE_K65_Normal", "green"],
                   ["HSE06", "5_Dielectric_function/F_Graphene-Borophene_HSE_K65_Accurate", "orange"]]

plot_absorption_XXZZ("for Graphene-Borophene", absorption_list, "eV", "", 40, 40, (4,12), (4,12))

# %%
# Absorption coefficient for Graphene-B₄C₃

absorption_list = [["GGA-PBE", "5_Dielectric_function/G_Graphene-B4C3_PBE_K65_Normal", "violet"],
                   ["HSE06 17 k-points", "5_Dielectric_function/G_Graphene-B4C3_HSE_K17", "orange"]]

plot_absorption_XXZZ("for Graphene-B₄C₃", absorption_list, "eV", "", 40, 40, (4,12), (4,12))
