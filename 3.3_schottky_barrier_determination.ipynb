# %% [markdown]
# # Schottky barrier determination

# %%
from vmatplot.bandstructure import *

E = "3_Bandstructure/E_Graphene-BC3_HSE"

c = kpoints_path(E)

k = extract_high_sym(E)

d = high_symmetry_path(E)
# Out:
# [0, 0.4709331162702405, 0.8434623097571708]
