# %% [markdown]
# # Schottky barrier determination

# %%
from vmatplot.bandstructure import *

E = "3_Bandstructure/E_Graphene-BC3_HSE"

c = kpoints_path(E)

print(c)

print(c["K"])

k = extract_high_symlines(E)

print(k[2])
# Out:
# {'Γ': 0, 'K': 0.4709331162702405, 'M': 0.8434623097571708}
# 0.4709331162702405
# {'K', 'Γ', 'M'}
