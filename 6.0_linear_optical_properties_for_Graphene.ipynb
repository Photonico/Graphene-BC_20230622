# %% [markdown]
# # Linear optical properties
#
# This note is used for checking linear optical properties with calculating monolayer Graphene.
#
# ## Linear Optical Properties
#
# * absorption coefficient (official)
#
# $$ \alpha(\omega)=\frac{\sqrt{2}\omega}{c}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# * absorption coefficient (custom)
#
# $$ I(\omega) = \sqrt{2}\omega\left[\sqrt{\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)}-\varepsilon_R(\omega)\right] $$
#
# * refractive index
#
# $$ n(\omega)=\frac{1}{\sqrt{2}}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}+\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# * extinction coefficient
#
# $$ k(\omega)=\frac{1}{\sqrt{2}}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}-\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# * reflectivity
#
# $$ n(\omega)=\frac{1}{\sqrt{2}}\left\{\left[\varepsilon_R^2(\omega)+\varepsilon_I^2(\omega)\right]^{\frac{1}{2}}+\varepsilon_R(\omega)\right\}^{\frac{1}{2}} $$
#
# * energy loss spectrum
#
# $$ L(\omega) = \frac{\varepsilon_I(\omega)}{\varepsilon^2_R(\omega)+\varepsilon_I^2(\omega)} $$
#
# where:
#
# $\omega$ is the given frequency;
#
# $\varepsilon_R$ is real part dielectric function;
#
# $\varepsilon_I$ is real part dielectric function.
#
# References:
#
#     10.1039/C7RA10570C
#
#     vaspkit.com/tutorials.html#linear-optical-properties

# %%
# Prework

from vmatplot.dielectric_function_plotting import  plot_dielectric_function_XXZZ_block
from vmatplot.absorption_coefficient import plot_absorption_XXZZ
from vmatplot.refractive_index import plot_refractive_XXZZ
from vmatplot.extinction_coefficient import plot_extinction_XXZZ
from vmatplot.reflectivity import plot_reflectivity_XXZZ
from vmatplot.energy_loss_spectrum import plot_energy_loss_XXZZ

matters_list = [["GGA-PBE (33 k-points)", "5_Dielectric_function/D_Graphene_PBE_K33", "blue"],
                ["GGA-PBE (65 k-points)", "5_Dielectric_function/D_Graphene_PBE_K65", "violet"],
                ["GGA-PBE (129 k-points)", "5_Dielectric_function/D_Graphene_PBE_K129", "wine"],
                # ["HSE06 (129 k-points)", "5_Dielectric_function/D_Graphene_HSE", "orange"],
               ]

# %%
# dielectric function

plot_dielectric_function_XXZZ_block("for Graphene", matters_list, 8, 8)

# %%
# absorption coefficient (official)

plot_absorption_XXZZ("Graphene", matters_list, "eV", "official", 25, 25)

# %%
# absorption coefficient (custom)

plot_absorption_XXZZ("for Graphene", matters_list, "eV", "custom", 40, 40)

# %%
# refractive index

plot_refractive_XXZZ("for Graphene", matters_list, "eV", 34, 34)

# %%
# extinction coefficient

plot_extinction_XXZZ("for Graphene", matters_list, "eV", 5, 5)

# %%
# reflectivity

plot_reflectivity_XXZZ("for Graphene", matters_list, "eV", 40, 40)

# %%
# energy loss spectrum

plot_energy_loss_XXZZ("for Graphene", matters_list, "eV", 40, 40)
